# %% [markdown]
# ## 📚 Prerequisites
#
# Before executing this notebook, make sure you have properly set up your Azure Services, created your Conda environment, and configured your environment variables as per the instructions provided in the [README.md](README.md) file.
#
# The PDFs used during this case study are publicly available:
#
# - [Fisher EWD/EWS/EWT Valves through NPS 12x8 Instruction Manual](https://www.emerson.com/documents/automation/instruction-manual-fisher-ewd-ews-ewt-valves-through-nps-12x8-en-124788.pdf)
# - [Fieldvue DVC6200 HW2 Digital Valve Controller Instruction Manual](https://www.emerson.com/documents/automation/instruction-manual-fieldvue-dvc6200-hw2-digital-valve-controller-en-123052.pdf)
#
# These documents were chosen due to their complexity, particularly in terms of tables and interpretation of graphs. To follow along with this notebook, please download these files and upload them to your blob storage container.

# %% [markdown]
# ## 📋 Table of Contents
#
# This notebook guides you through the following sections:
#
# 1. [**Optical Character Recognition (OCR) with Azure AI Document Intelligence**](#optical-character-recognition-ocr-with-azure-ai-document-intelligence): Overview of Azure's Document Analysis Client and its pre-trained models for document analysis.
#
# 2. [**Understanding Data Extracted from the Layout Model**](#understanding-data-extracted-from-the-layout-model): Insights into the data extracted from the layout model.
#     - [**Custom Logic for Processing Extracted Information**](#custom-logic-for-processing-extracted-information): Discusses the need for custom logic to process the extracted information based on specific use cases and requirements.
#     - [**Leveraging LangChain Integration**](#leveraging-langchain-integration): Explanation of how Retrieval-Augmented Generation (RAG) works with a pretrained Large Language Model (LLM) and an external data retrieval system for dynamic interaction with documents and content generation.

# %%
import os

# Define the target directory
target_directory = r"C:\Users\pablosal\Desktop\gbbai-azure-ai-search-indexing"  # change your directory here

# Check if the directory exists
if os.path.exists(target_directory):
    # Change the current working directory
    os.chdir(target_directory)
    print(f"Directory changed to {os.getcwd()}")
else:
    print(f"Directory {target_directory} does not exist.")
# Out:
# Directory changed to C:\Users\pablosal\Desktop\gbbai-azure-ai-search-indexing

# %%
from src.ocr.document_intelligence import AzureDocumentIntelligenceManager

document_intelligence_client = AzureDocumentIntelligenceManager()

# %% [markdown]
# ## Optical Character Recognition (OCR) with Azure AI Document Intelligence
#
# Azure's Document Analysis Client provides a variety of pre-trained models that can be used to analyze documents. The `analyze_document` function takes in a document (either a URL or a file path) and the type of pre-trained model to use for analysis.
#
# Here's a brief overview of the available pre-trained models:
#
# - `'prebuilt-layout'`: This is the default model. It extracts text, tables, selection marks, and structure elements from the document.
#
# - `'prebuilt-document'`: This model is used for generic document understanding.
#
# - `'prebuilt-read'`: This model extracts both print and handwritten text.
#
# - `'prebuilt-tax'`: This model is designed to process US tax documents.
#
# - `'prebuilt-invoice'`: This model automates the processing of invoices.
#
# - `'prebuilt-receipt'`: This model scans sales receipts for key data.
#
# - `'prebuilt-id'`: This model processes identity documents.
#
# - `'prebuilt-businesscard'`: This model extracts information from business cards.
#
# - `'prebuilt-contract'`: This model analyzes contractual agreements.
#
# - `'prebuilt-healthinsurancecard'`: This model processes health insurance cards.
#
# In addition to these pre-trained models, Azure also offers custom and composed models. For more details, refer to the [Azure Document Intelligence Model Overview](https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/concept-model-overview?view=doc-intel-4.0.0).
#
# The `analyze_document` function returns the analysis result, which can then be used for further processing or analysis.

# %%
# We will begin with the Fisher EWD/EWS/EWT Valves through NPS 12x8 Instruction Manual,
# which can be found at the following URL:
# https://www.emerson.com/documents/automation/instruction-manual-fisher-ewd-ews-ewt-valves-through-nps-12x8-en-124788.pdf
# We will use the 'prebuilt-layout' model for this task. This is the default model provided by Azure's Document Analysis Client,
# and it is capable of extracting text, tables, selection marks, and structure elements from the document.
# one  the latest feature is the abulity to extract content in a specific format, such as markdown.

document_url = "https://www.emerson.com/documents/automation/instruction-manual-fieldvue-dvc6200-hw2-digital-valve-controller-en-123052.pdf"
document_blob = "https://testeastusdev001.blob.core.windows.net/customskillspdf/instruction-manual-fieldvue-dvc6200-hw2-digital-valve-controller-en-123052.pdf"
document_local = os.path.join(
    os.getcwd(),
    "utils\\data\\instruction-manual-fieldvue-dvc6200-hw2-digital-valve-controller-en-123052.pdf",
)
model_type = "prebuilt-layout"

result_ocr = document_intelligence_client.analyze_document(
    document_input=document_blob,
    model_type=model_type,
    output_format="markdown",
    features=["OCR_HIGH_RESOLUTION"],
)
# Out:
# 2024-02-02 19:14:45,221 - micro - MainProcess - INFO     Blob URL detected. Extracting content. (document_intelligence.py:analyze_document:147)
# 2024-02-02 19:14:47,475 - micro - MainProcess - INFO     Successfully downloaded blob file instruction-manual-fieldvue-dvc6200-hw2-digital-valve-controller-en-123052.pdf (blob_data_extractors.py:extract_content:89)

# %%
result_ocr.api_version
# Out:
# '2023-10-31-preview'

# %%
result_ocr.model_id
# Out:
# 'prebuilt-layout'

# %%
result_ocr.keys()
# Out:
# dict_keys(['apiVersion', 'modelId', 'stringIndexType', 'content', 'pages', 'tables', 'paragraphs', 'styles', 'contentFormat'])

# %%
section_headings = [
    paragraph.content
    for paragraph in result_ocr.paragraphs
    if paragraph.role == "sectionHeading"
]

# %%
# retriving pages from the docuemnt
result_ocr.pages
# Out:
# [{'pageNumber': 1, 'angle': 0, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'DVC6200', 'polygon': [5.614, 0.7356, 6.1833, 0.7318, 6.1827, 0.8762, 5.614, 0.8667], 'confidence': 0.994, 'span': {'offset': 17, 'length': 7}}, {'content': 'Digital', 'polygon': [6.2218, 0.7316, 6.6483, 0.7301, 6.6472, 0.8765, 6.2212, 0.8766], 'confidence': 0.994, 'span': {'offset': 25, 'length': 7}}, {'content': 'Valve', 'polygon': [6.6755, 0.73, 7.018, 0.7295, 7.0166, 0.8723, 6.6744, 0.8764], 'confidence': 0.998, 'span': {'offset': 33, 'length': 5}}, {'content': 'Controller', 'polygon': [7.0475, 0.7294, 7.7007, 0.7302, 7.6986, 0.8537, 7.046, 0.8719], 'confidence': 0.994, 'span': {'offset': 39, 'length': 10}}, {'content': 'December', 'polygon': [6.9239, 0.9178, 7.4304, 0.9169, 7.4283, 1.0289, 6.9218, 1.0326], 'confidence': 0.995, 'span': {'offset': 50, 'length': 8}}, {'content': '2022', 'polygon': [7.4527, 0.9166, 7.7041, 0.9124, 7.702, 1.0317, 7.4506, 1.029], 'confidence': 0.988, 'span': {'offset': 59, 'length': 4}}, {'content': 'Instruction', 'polygon': [0.7911, 0.7323, 1.5941, 0.7253, 1.5915, 0.8767, 0.7852, 0.8743], 'confidence': 0.994, 'span': {'offset': 87, 'length': 11}}, {'content': 'Manual', 'polygon': [1.6562, 0.7245, 2.2329, 0.7159, 2.2329, 0.8767, 1.6539, 0.8767], 'confidence': 0.997, 'span': {'offset': 99, 'length': 6}}, {'content': 'D103605X012', 'polygon': [0.7845, 0.9145, 1.4945, 0.9153, 1.4924, 1.028, 0.7845, 1.03], 'confidence': 0.993, 'span': {'offset': 106, 'length': 11}}, {'content': 'Fisher™', 'polygon': [0.7601, 1.4158, 1.7398, 1.4246, 1.7416, 1.6969, 0.7601, 1.689], 'confidence': 0.706, 'span': {'offset': 124, 'length': 7}}, {'content': 'FIELDVUE™', 'polygon': [1.8025, 1.425, 3.347, 1.4309, 3.3516, 1.712, 1.8044, 1.6974], 'confidence': 0.953, 'span': {'offset': 132, 'length': 9}}, {'content': 'DVC6200', 'polygon': [3.4049, 1.4309, 4.7515, 1.4273, 4.7586, 1.7274, 3.4096, 1.7126], 'confidence': 0.994, 'span': {'offset': 142, 'length': 7}}, {'content': 'Digital', 'polygon': [4.8721, 1.4268, 5.8181, 1.4196, 5.8271, 1.7408, 4.8794, 1.7288], 'confidence': 0.994, 'span': {'offset': 150, 'length': 7}}, {'content': 'Valve', 'polygon': [5.876, 1.4189, 6.6241, 1.4103, 6.6345, 1.7467, 5.8851, 1.7416], 'confidence': 0.998, 'span': {'offset': 158, 'length': 5}}, {'content': 'Controller', 'polygon': [0.7618, 1.8, 2.2248, 1.8061, 2.2248, 2.0627, 0.7514, 2.0767], 'confidence': 0.993, 'span': {'offset': 164, 'length': 10}}, {'content': 'This', 'polygon': [0.8851, 2.4259, 1.1184, 2.4255, 1.1176, 2.5656, 0.8851, 2.5583], 'confidence': 0.993, 'span': {'offset': 180, 'length': 4}}, {'content': 'manual', 'polygon': [1.1464, 2.4255, 1.6035, 2.4262, 1.6013, 2.5733, 1.1455, 2.5662], 'confidence': 0.996, 'span': {'offset': 185, 'length': 6}}, {'content': 'applies', 'polygon': [1.6315, 2.4263, 2.0514, 2.429, 2.0477, 2.5721, 1.6292, 2.5733], 'confidence': 0.997, 'span': {'offset': 192, 'length': 7}}, {'content': 'to', 'polygon': [2.0794, 2.4292, 2.2077, 2.4304, 2.2035, 2.5697, 2.0756, 2.5717], 'confidence': 0.999, 'span': {'offset': 200, 'length': 2}}, {'content': 'Instrument', 'polygon': [0.8886, 2.6349, 1.5442, 2.6326, 1.5372, 2.7643, 0.8797, 2.7667], 'confidence': 0.993, 'span': {'offset': 220, 'length': 10}}, {'content': 'Level', 'polygon': [1.5701, 2.6326, 1.8893, 2.6333, 1.8833, 2.7606, 1.5632, 2.764], 'confidence': 0.997, 'span': {'offset': 231, 'length': 5}}, {'content': 'HC,', 'polygon': [2.2077, 2.6373, 2.4279, 2.6343, 2.4263, 2.77, 2.2056, 2.7662], 'confidence': 0.993, 'span': {'offset': 239, 'length': 3}}, {'content': 'AD,', 'polygon': [2.4544, 2.634, 2.6746, 2.6326, 2.6735, 2.77, 2.4527, 2.77], 'confidence': 0.996, 'span': {'offset': 243, 'length': 3}}, {'content': 'PD,', 'polygon': [2.701, 2.6326, 2.9125, 2.6328, 2.9118, 2.7699, 2.6999, 2.77], 'confidence': 0.995, 'span': {'offset': 247, 'length': 3}}, {'content': 'ODV', 'polygon': [2.9389, 2.6329, 3.201, 2.6353, 3.201, 2.764, 2.9383, 2.7697], 'confidence': 0.994, 'span' ...
#  {'pageNumber': 2, 'angle': 0.13739970326423645, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'DVC6200', 'polygon': [0.7853, 0.7183, 1.3615, 0.71, 1.3593, 0.8667, 0.7823, 0.8559], 'confidence': 0.995, 'span': {'offset': 1934, 'length': 7}}, {'content': 'Digital', 'polygon': [1.3934, 0.7097, 1.8151, 0.7072, 1.8136, 0.8667, 1.3913, 0.8667], 'confidence': 0.996, 'span': {'offset': 1942, 'length': 7}}, {'content': 'Valve', 'polygon': [1.8446, 0.7071, 2.1879, 0.7072, 2.1869, 0.8636, 1.8431, 0.8667], 'confidence': 0.998, 'span': {'offset': 1950, 'length': 5}}, {'content': 'Controller', 'polygon': [2.2173, 0.7073, 2.8647, 0.7128, 2.8647, 0.8443, 2.2164, 0.8632], 'confidence': 0.993, 'span': {'offset': 1956, 'length': 10}}, {'content': 'December', 'polygon': [0.7824, 0.9012, 1.2944, 0.8973, 1.293, 1.0157, 0.7824, 1.015], 'confidence': 0.994, 'span': {'offset': 1967, 'length': 8}}, {'content': '2022', 'polygon': [1.3173, 0.8974, 1.5675, 0.9005, 1.5654, 1.0139, 1.3158, 1.0156], 'confidence': 0.992, 'span': {'offset': 1976, 'length': 4}}, {'content': 'Contents', 'polygon': [0.7617, 1.3743, 1.7315, 1.3764, 1.7293, 1.6065, 0.7557, 1.5778], 'confidence': 0.993, 'span': {'offset': 1998, 'length': 8}}, {'content': '\\(continued\\)', 'polygon': [1.7769, 1.3762, 3.0497, 1.3619, 3.0527, 1.6133, 1.775, 1.6074], 'confidence': 0.987, 'span': {'offset': 2007, 'length': 13}}, {'content': 'Section', 'polygon': [0.7412, 1.6467, 1.261, 1.6445, 1.261, 1.799, 0.7412, 1.793], 'confidence': 0.994, 'span': {'offset': 2026, 'length': 7}}, {'content': '4', 'polygon': [1.3237, 1.6443, 1.4016, 1.6441, 1.4016, 1.7997, 1.3237, 1.7993], 'confidence': 0.996, 'span': {'offset': 2034, 'length': 1}}, {'content': 'Calibration', 'polygon': [1.4443, 1.644, 2.2152, 1.6425, 2.2152, 1.7952, 1.4443, 1.7998], 'confidence': 0.993, 'span': {'offset': 2036, 'length': 11}}, {'content': '39', 'polygon': [3.82, 1.65, 3.9765, 1.65, 3.9777, 1.7819, 3.82, 1.7833], 'confidence': 0.999, 'span': {'offset': 2050, 'length': 2}}, {'content': 'Calibration', 'polygon': [0.7439, 1.8183, 1.3831, 1.8194, 1.3801, 1.9527, 0.7409, 1.9533], 'confidence': 0.994, 'span': {'offset': 2057, 'length': 11}}, {'content': 'Overview', 'polygon': [1.4199, 1.8196, 1.9465, 1.8267, 1.9435, 1.953, 1.417, 1.9527], 'confidence': 0.993, 'span': {'offset': 2069, 'length': 8}}, {'content': '39', 'polygon': [3.848, 1.8203, 3.9857, 1.8231, 3.9832, 1.9464, 3.8455, 1.9436], 'confidence': 0.999, 'span': {'offset': 2080, 'length': 2}}, {'content': 'Travel', 'polygon': [0.8326, 1.9754, 1.1963, 1.9744, 1.1942, 2.1033, 0.8305, 2.1033], 'confidence': 0.996, 'span': {'offset': 2087, 'length': 6}}, {'content': 'Calibration', 'polygon': [1.2211, 1.9744, 1.8637, 1.9801, 1.8616, 2.0989, 1.219, 2.1032], 'confidence': 0.993, 'span': {'offset': 2094, 'length': 11}}, {'content': '40', 'polygon': [3.8507, 1.98, 3.9767, 1.98, 3.9754, 2.0998, 3.8494, 2.0985], 'confidence': 0.999, 'span': {'offset': 2108, 'length': 2}}, {'content': 'Auto', 'polygon': [1.0808, 2.1256, 1.3516, 2.126, 1.3486, 2.2555, 1.0779, 2.2567], 'confidence': 0.993, 'span': {'offset': 2115, 'length': 4}}, {'content': 'Calibration', 'polygon': [1.395, 2.1262, 2.0294, 2.132, 2.0265, 2.2508, 1.392, 2.2553], 'confidence': 0.994, 'span': {'offset': 2120, 'length': 11}}, {'content': '40', 'polygon': [3.8465, 2.13, 3.9846, 2.13, 3.9858, 2.2451, 3.8477, 2.2466], 'confidence': 0.999, 'span': {'offset': 2134, 'length': 2}}, {'content': 'Manual', 'polygon': [1.0851, 2.2823, 1.5227, 2.2808, 1.5219, 2.4059, 1.0851, 2.4059], 'confidence': 0.995, 'span': {'offset': 2141, 'length': 6}}, {'content': 'Calibration', 'polygon': [1.547, 2.2807, 2.1852, 2.2845, 2.1832, 2.4048, 1.5461, 2.4059], 'confidence': 0.993, 'span': {'offset': 2148, 'length': 11}}, {'content': '41', 'polygon': [3.8478, 2.28, 3.98, 2.28, 3.9786, 2.3966, 3.8464, 2.395], 'confidence': 0.999, 'span': {'offset': 2162, 'length': 2}}, {'content': 'Pushbutton', 'polygon': [1.083, 2.4319, 1.7552, 2.4317, 1.752, ...
#  {'pageNumber': 3, 'angle': 0, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'Introduction', 'polygon': [6.9005, 0.7141, 7.6848, 0.7173, 7.6818, 0.8453, 6.8975, 0.8467], 'confidence': 0.993, 'span': {'offset': 4154, 'length': 12}}, {'content': 'December', 'polygon': [6.9176, 0.8964, 7.4254, 0.8991, 7.424, 1.0114, 6.9176, 1.0167], 'confidence': 0.995, 'span': {'offset': 4167, 'length': 8}}, {'content': '2022', 'polygon': [7.4481, 0.8991, 7.6963, 0.8975, 7.6942, 1.0149, 7.4467, 1.0115], 'confidence': 0.988, 'span': {'offset': 4176, 'length': 4}}, {'content': 'Instruction', 'polygon': [0.7882, 0.7161, 1.592, 0.7072, 1.592, 0.86, 0.7882, 0.8555], 'confidence': 0.993, 'span': {'offset': 4204, 'length': 11}}, {'content': 'Manual', 'polygon': [1.6542, 0.7066, 2.2315, 0.7005, 2.2315, 0.8592, 1.6542, 0.86], 'confidence': 0.997, 'span': {'offset': 4216, 'length': 6}}, {'content': 'D103605X012', 'polygon': [0.7838, 0.8985, 1.4923, 0.8974, 1.4881, 1.0116, 0.7838, 1.0133], 'confidence': 0.993, 'span': {'offset': 4223, 'length': 11}}, {'content': 'Section', 'polygon': [0.747, 1.3763, 1.6, 1.3693, 1.598, 1.6067, 0.744, 1.6049], 'confidence': 0.997, 'span': {'offset': 4241, 'length': 7}}, {'content': '1', 'polygon': [1.7286, 1.3685, 1.8493, 1.3678, 1.8476, 1.6067, 1.7267, 1.6067], 'confidence': 0.995, 'span': {'offset': 4249, 'length': 1}}, {'content': 'Introduction', 'polygon': [1.9, 1.3675, 3.3762, 1.364, 3.3762, 1.6027, 1.8983, 1.6067], 'confidence': 0.993, 'span': {'offset': 4251, 'length': 12}}, {'content': 'Installation,', 'polygon': [0.7472, 1.8462, 2.0084, 1.8444, 2.0061, 2.0753, 0.7443, 2.08], 'confidence': 0.982, 'span': {'offset': 4269, 'length': 13}}, {'content': 'Pneumatic', 'polygon': [2.0534, 1.8444, 3.2207, 1.8448, 3.2191, 2.0718, 2.0511, 2.075], 'confidence': 0.993, 'span': {'offset': 4283, 'length': 9}}, {'content': 'and', 'polygon': [3.2695, 1.8448, 3.6561, 1.8454, 3.6547, 2.0717, 3.2679, 2.0718], 'confidence': 0.998, 'span': {'offset': 4293, 'length': 3}}, {'content': 'Electrical', 'polygon': [3.7349, 1.8456, 4.6958, 1.848, 4.695, 2.0736, 3.7336, 2.0717], 'confidence': 0.994, 'span': {'offset': 4297, 'length': 10}}, {'content': 'Connections,', 'polygon': [4.7408, 1.8482, 6.1821, 1.8545, 6.1821, 2.08, 4.74, 2.0738], 'confidence': 0.992, 'span': {'offset': 4308, 'length': 12}}, {'content': 'and', 'polygon': [0.7497, 2.1191, 1.1309, 2.1202, 1.1263, 2.3412, 0.7438, 2.3219], 'confidence': 0.999, 'span': {'offset': 4321, 'length': 3}}, {'content': 'Initial', 'polygon': [1.181, 2.1204, 1.7971, 2.1233, 1.7948, 2.365, 1.1766, 2.3432], 'confidence': 0.968, 'span': {'offset': 4325, 'length': 7}}, {'content': 'Configuration', 'polygon': [1.8433, 2.1236, 3.3181, 2.1362, 3.321, 2.3738, 1.8411, 2.3664], 'confidence': 0.995, 'span': {'offset': 4333, 'length': 13}}, {'content': 'Refer', 'polygon': [0.7409, 2.4606, 1.0539, 2.4602, 1.0509, 2.5983, 0.738, 2.5944], 'confidence': 0.995, 'span': {'offset': 4352, 'length': 5}}, {'content': 'to', 'polygon': [1.0824, 2.4602, 1.2056, 2.46, 1.2027, 2.6001, 1.0794, 2.5986], 'confidence': 0.994, 'span': {'offset': 4358, 'length': 2}}, {'content': 'the', 'polygon': [1.2341, 2.46, 1.4404, 2.4597, 1.4374, 2.6029, 1.2311, 2.6004], 'confidence': 0.999, 'span': {'offset': 4361, 'length': 3}}, {'content': 'DVC6200', 'polygon': [1.4712, 2.4597, 2.0378, 2.4592, 2.0348, 2.6077, 1.4682, 2.6031], 'confidence': 0.994, 'span': {'offset': 4365, 'length': 7}}, {'content': 'Series', 'polygon': [2.0686, 2.4591, 2.4195, 2.4589, 2.4166, 2.6093, 2.0657, 2.6079], 'confidence': 0.994, 'span': {'offset': 4373, 'length': 6}}, {'content': 'Quick', 'polygon': [2.448, 2.4589, 2.7965, 2.4587, 2.7935, 2.61, 2.445, 2.6095], 'confidence': 0.997, 'span': {'offset': 4380, 'length': 5}}, {'content': 'Start', 'polygon': [2.8273, 2.4587, 3.1118, 2.4586, 3.1088, 2.61, 2.8243, 2.61], 'confidence': 0.995, 'span': {'offset': 4386, 'length': 5}}, {'content': 'Guide', 'polygon': [3.1403, 2.4586, 3.4817, 2.4585, 3.4787, 2.609 ...
#  {'pageNumber': 4, 'angle': 0, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'Introduction', 'polygon': [0.7882, 0.7163, 1.571, 0.7154, 1.568, 0.845, 0.7852, 0.8467], 'confidence': 0.993, 'span': {'offset': 6969, 'length': 12}}, {'content': 'December', 'polygon': [0.7817, 0.8988, 1.2924, 0.898, 1.2924, 1.0111, 0.7817, 1.0159], 'confidence': 0.995, 'span': {'offset': 6982, 'length': 8}}, {'content': '2022', 'polygon': [1.315, 0.8979, 1.5609, 0.8962, 1.5609, 1.0121, 1.315, 1.0111], 'confidence': 0.992, 'span': {'offset': 6991, 'length': 4}}, {'content': 'Figure', 'polygon': [0.7851, 1.3689, 1.1634, 1.364, 1.1609, 1.5091, 0.7821, 1.5127], 'confidence': 0.993, 'span': {'offset': 7002, 'length': 6}}, {'content': '1\\-1\\.', 'polygon': [1.1951, 1.3637, 1.4197, 1.3616, 1.4174, 1.5076, 1.1926, 1.5089], 'confidence': 0.993, 'span': {'offset': 7009, 'length': 6}}, {'content': 'FIELDVUE', 'polygon': [1.449, 1.3613, 2.0153, 1.3579, 2.0137, 1.5063, 1.4468, 1.5074], 'confidence': 0.994, 'span': {'offset': 7016, 'length': 8}}, {'content': 'DVC6200', 'polygon': [2.0446, 1.3579, 2.6182, 1.3574, 2.6173, 1.5084, 2.043, 1.5063], 'confidence': 0.993, 'span': {'offset': 7025, 'length': 7}}, {'content': 'Digital', 'polygon': [2.6499, 1.3574, 3.0405, 1.359, 3.0401, 1.512, 2.6491, 1.5085], 'confidence': 0.993, 'span': {'offset': 7033, 'length': 7}}, {'content': 'Valve', 'polygon': [3.0698, 1.3592, 3.3993, 1.3616, 3.3993, 1.5165, 3.0694, 1.5124], 'confidence': 0.997, 'span': {'offset': 7041, 'length': 5}}, {'content': 'Controller', 'polygon': [0.7853, 1.5243, 1.3783, 1.5239, 1.3765, 1.6602, 0.7823, 1.656], 'confidence': 0.995, 'span': {'offset': 7047, 'length': 10}}, {'content': 'Mounted', 'polygon': [1.4061, 1.5239, 1.9596, 1.5234, 1.959, 1.6638, 1.4043, 1.6604], 'confidence': 0.994, 'span': {'offset': 7058, 'length': 7}}, {'content': 'on', 'polygon': [1.9898, 1.5234, 2.1357, 1.5233, 2.1354, 1.6647, 1.9892, 1.6639], 'confidence': 0.999, 'span': {'offset': 7066, 'length': 2}}, {'content': 'a', 'polygon': [2.1751, 1.5233, 2.2399, 1.5232, 2.2398, 1.6653, 2.1749, 1.6649], 'confidence': 0.998, 'span': {'offset': 7069, 'length': 1}}, {'content': 'Fisher', 'polygon': [2.2677, 1.5232, 2.6198, 1.523, 2.6205, 1.667, 2.2677, 1.6654], 'confidence': 0.998, 'span': {'offset': 7071, 'length': 6}}, {'content': 'Sliding\\-Stem', 'polygon': [2.6476, 1.5229, 3.3587, 1.5224, 3.3608, 1.6697, 2.6483, 1.6671], 'confidence': 0.995, 'span': {'offset': 7078, 'length': 13}}, {'content': 'Valve', 'polygon': [3.4351, 1.5224, 3.7663, 1.5221, 3.7693, 1.67, 3.4374, 1.6699], 'confidence': 0.993, 'span': {'offset': 7092, 'length': 5}}, {'content': 'Actuator', 'polygon': [0.7932, 1.684, 1.3193, 1.6886, 1.3192, 1.8133, 0.7875, 1.8133], 'confidence': 0.995, 'span': {'offset': 7098, 'length': 8}}, {'content': 'Figure', 'polygon': [4.5362, 1.3683, 4.9113, 1.3632, 4.9083, 1.5099, 4.5333, 1.5124], 'confidence': 0.997, 'span': {'offset': 7108, 'length': 6}}, {'content': '1\\-2\\.', 'polygon': [4.9436, 1.3628, 5.1622, 1.3606, 5.1592, 1.5088, 4.9406, 1.5097], 'confidence': 0.991, 'span': {'offset': 7115, 'length': 6}}, {'content': 'FIELDVUE', 'polygon': [5.192, 1.3602, 5.7682, 1.3562, 5.7652, 1.5079, 5.189, 1.5087], 'confidence': 0.994, 'span': {'offset': 7122, 'length': 8}}, {'content': 'DVC6200', 'polygon': [5.798, 1.3561, 6.3718, 1.3551, 6.3688, 1.5097, 5.7951, 1.508], 'confidence': 0.994, 'span': {'offset': 7131, 'length': 7}}, {'content': 'Digital', 'polygon': [6.4041, 1.3551, 6.7916, 1.3562, 6.7886, 1.5125, 6.4011, 1.5098], 'confidence': 0.996, 'span': {'offset': 7139, 'length': 7}}, {'content': 'Valve', 'polygon': [6.8214, 1.3564, 7.1493, 1.3585, 7.1463, 1.5159, 6.8184, 1.5128], 'confidence': 0.997, 'span': {'offset': 7147, 'length': 5}}, {'content': 'Controller', 'polygon': [4.5365, 1.5259, 5.1293, 1.5237, 5.125, 1.6699, 4.5305, 1.6649], 'confidence': 0.995, 'span': {'offset': 7153, 'length': 10}}, {'content': 'Integrally', 'polygon': [5.1575, 1.5236, 5.7221, 1.5222, ...
#  {'pageNumber': 5, 'angle': 0, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'Introduction', 'polygon': [6.9005, 0.7141, 7.6848, 0.7173, 7.6818, 0.8453, 6.8975, 0.8467], 'confidence': 0.993, 'span': {'offset': 10089, 'length': 12}}, {'content': 'December', 'polygon': [6.9176, 0.8964, 7.4254, 0.8991, 7.424, 1.0114, 6.9176, 1.0167], 'confidence': 0.995, 'span': {'offset': 10102, 'length': 8}}, {'content': '2022', 'polygon': [7.4481, 0.8991, 7.6963, 0.8975, 7.6942, 1.0149, 7.4467, 1.0115], 'confidence': 0.988, 'span': {'offset': 10111, 'length': 4}}, {'content': 'Instruction', 'polygon': [0.7882, 0.7173, 1.5938, 0.7069, 1.5938, 0.8629, 0.7882, 0.8556], 'confidence': 0.993, 'span': {'offset': 10122, 'length': 11}}, {'content': 'Manual', 'polygon': [1.6462, 0.7063, 2.2249, 0.7006, 2.2249, 0.8593, 1.6462, 0.8629], 'confidence': 0.997, 'span': {'offset': 10134, 'length': 6}}, {'content': 'D103605X012', 'polygon': [0.7838, 0.8987, 1.4948, 0.8963, 1.4926, 1.0115, 0.7838, 1.0133], 'confidence': 0.993, 'span': {'offset': 10141, 'length': 11}}, {'content': 'Specifications', 'polygon': [0.7472, 1.5684, 2.241, 1.5664, 2.241, 1.7626, 0.7472, 1.8233], 'confidence': 0.994, 'span': {'offset': 10157, 'length': 14}}, {'content': 'WARNING', 'polygon': [0.9861, 2.0234, 1.7328, 2.0246, 1.7324, 2.1684, 0.9802, 2.17], 'confidence': 0.994, 'span': {'offset': 10176, 'length': 7}}, {'content': 'A', 'polygon': [0.7938, 2.0267, 0.8738, 2.0267, 0.8766, 2.175, 0.7966, 2.1765], 'confidence': 0.922, 'span': {'offset': 10184, 'length': 1}}, {'content': 'Refer', 'polygon': [0.7705, 2.3221, 1.0692, 2.3223, 1.0711, 2.4505, 0.7726, 2.448], 'confidence': 0.993, 'span': {'offset': 10187, 'length': 5}}, {'content': 'to', 'polygon': [1.0955, 2.3223, 1.2098, 2.3223, 1.2116, 2.4517, 1.0975, 2.4508], 'confidence': 0.999, 'span': {'offset': 10193, 'length': 2}}, {'content': 'table', 'polygon': [1.2361, 2.3224, 1.5414, 2.3225, 1.543, 2.4545, 1.2379, 2.4519], 'confidence': 0.991, 'span': {'offset': 10196, 'length': 5}}, {'content': '1\\-2', 'polygon': [1.5699, 2.3226, 1.7369, 2.3227, 1.7384, 2.4561, 1.5716, 2.4547], 'confidence': 0.998, 'span': {'offset': 10202, 'length': 4}}, {'content': 'for', 'polygon': [1.7632, 2.3227, 1.9301, 2.3227, 1.9315, 2.4573, 1.7647, 2.4564], 'confidence': 0.998, 'span': {'offset': 10207, 'length': 3}}, {'content': 'specifications\\.', 'polygon': [1.9565, 2.3227, 2.7647, 2.3229, 2.7656, 2.4616, 1.9579, 2.4574], 'confidence': 0.993, 'span': {'offset': 10211, 'length': 16}}, {'content': 'Incorrect', 'polygon': [2.7911, 2.3229, 3.3182, 2.3229, 3.3188, 2.4629, 2.792, 2.4617], 'confidence': 0.994, 'span': {'offset': 10228, 'length': 9}}, {'content': 'configuration', 'polygon': [3.3446, 2.3229, 4.1155, 2.3227, 4.1155, 2.4633, 3.3451, 2.463], 'confidence': 0.994, 'span': {'offset': 10238, 'length': 13}}, {'content': 'of', 'polygon': [4.144, 2.3227, 4.267, 2.3226, 4.267, 2.4633, 4.144, 2.4633], 'confidence': 0.999, 'span': {'offset': 10252, 'length': 2}}, {'content': 'a', 'polygon': [4.2934, 2.3226, 4.3549, 2.3226, 4.3548, 2.4633, 4.2933, 2.4633], 'confidence': 0.998, 'span': {'offset': 10255, 'length': 1}}, {'content': 'positioning', 'polygon': [4.3812, 2.3226, 5.0225, 2.3222, 5.022, 2.4617, 4.3811, 2.4633], 'confidence': 0.995, 'span': {'offset': 10257, 'length': 11}}, {'content': 'instrument', 'polygon': [5.0489, 2.3222, 5.6902, 2.3217, 5.6893, 2.4589, 5.0484, 2.4616], 'confidence': 0.994, 'span': {'offset': 10269, 'length': 10}}, {'content': 'could', 'polygon': [5.7166, 2.3217, 6.0307, 2.3213, 6.0295, 2.4566, 5.7156, 2.4587], 'confidence': 0.998, 'span': {'offset': 10280, 'length': 5}}, {'content': 'result', 'polygon': [6.0592, 2.3213, 6.3843, 2.3209, 6.3829, 2.4542, 6.058, 2.4564], 'confidence': 0.994, 'span': {'offset': 10286, 'length': 6}}, {'content': 'in', 'polygon': [6.4106, 2.3209, 6.5138, 2.3208, 6.5124, 2.4533, 6.4092, 2.454], 'confidence': 0.999, 'span': {'offset': 10293, 'length': 2}}, {'content': 'the', 'polygon': [6.5 ...
#  {'pageNumber': 6, 'angle': 0, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'Introduction', 'polygon': [0.7911, 0.7167, 1.5739, 0.7151, 1.5739, 0.8447, 0.7882, 0.8492], 'confidence': 0.993, 'span': {'offset': 12022, 'length': 12}}, {'content': 'December', 'polygon': [0.7817, 0.8992, 1.2954, 0.898, 1.2954, 1.0122, 0.7817, 1.0167], 'confidence': 0.995, 'span': {'offset': 12035, 'length': 8}}, {'content': '2022', 'polygon': [1.318, 0.898, 1.5654, 0.8979, 1.5654, 1.0124, 1.318, 1.0122], 'confidence': 0.992, 'span': {'offset': 12044, 'length': 4}}, {'content': 'Instruction', 'polygon': [6.2542, 0.7132, 7.0686, 0.7073, 7.0673, 0.86, 6.2513, 0.86], 'confidence': 0.994, 'span': {'offset': 12050, 'length': 11}}, {'content': 'Manual', 'polygon': [7.1209, 0.707, 7.6987, 0.7046, 7.6987, 0.8567, 7.1197, 0.86], 'confidence': 0.997, 'span': {'offset': 12062, 'length': 6}}, {'content': 'D103605X012', 'polygon': [6.9921, 0.9003, 7.7011, 0.8956, 7.699, 1.0133, 6.9921, 1.0115], 'confidence': 0.992, 'span': {'offset': 12069, 'length': 11}}, {'content': 'Table', 'polygon': [0.7882, 1.3881, 1.1769, 1.3868, 1.1716, 1.5601, 0.7823, 1.5439], 'confidence': 0.997, 'span': {'offset': 12085, 'length': 5}}, {'content': '1\\-2\\.', 'polygon': [1.2245, 1.3867, 1.5041, 1.3866, 1.4994, 1.5667, 1.2192, 1.5616], 'confidence': 0.991, 'span': {'offset': 12091, 'length': 6}}, {'content': 'Specifications', 'polygon': [1.5376, 1.3866, 2.5331, 1.3917, 2.5302, 1.5474, 1.533, 1.5667], 'confidence': 0.994, 'span': {'offset': 12098, 'length': 14}}, {'content': 'Available', 'polygon': [0.7501, 1.6662, 1.3185, 1.6717, 1.3142, 1.8124, 0.7471, 1.7977], 'confidence': 0.993, 'span': {'offset': 12114, 'length': 9}}, {'content': 'Mounting', 'polygon': [1.346, 1.672, 1.9763, 1.6803, 1.9704, 1.8233, 1.3416, 1.813], 'confidence': 0.994, 'span': {'offset': 12124, 'length': 8}}, {'content': 'DVC6200', 'polygon': [0.8148, 1.899, 1.3814, 1.8982, 1.3784, 2.0433, 0.8118, 2.0433], 'confidence': 0.994, 'span': {'offset': 12134, 'length': 7}}, {'content': 'digital', 'polygon': [1.4117, 1.8982, 1.7754, 1.8978, 1.7725, 2.0433, 1.4087, 2.0433], 'confidence': 0.996, 'span': {'offset': 12142, 'length': 7}}, {'content': 'valve', 'polygon': [1.8034, 1.8978, 2.1205, 1.8975, 2.1175, 2.0424, 1.8004, 2.0433], 'confidence': 0.994, 'span': {'offset': 12150, 'length': 5}}, {'content': 'controller', 'polygon': [2.1485, 1.8974, 2.7268, 1.897, 2.7238, 2.0383, 2.1455, 2.0422], 'confidence': 0.995, 'span': {'offset': 12156, 'length': 10}}, {'content': 'or', 'polygon': [2.7547, 1.8969, 2.8853, 1.8968, 2.8823, 2.0367, 2.7518, 2.038], 'confidence': 0.998, 'span': {'offset': 12167, 'length': 2}}, {'content': 'DVC6215', 'polygon': [2.9133, 1.8968, 3.4892, 1.8965, 3.4862, 2.0297, 2.9103, 2.0364], 'confidence': 0.993, 'span': {'offset': 12170, 'length': 7}}, {'content': 'feedback', 'polygon': [0.8082, 2.0513, 1.3558, 2.0539, 1.3545, 2.1878, 0.8082, 2.1894], 'confidence': 0.995, 'span': {'offset': 12178, 'length': 8}}, {'content': 'unit:', 'polygon': [1.3846, 2.054, 1.6928, 2.0558, 1.6906, 2.19, 1.3832, 2.188], 'confidence': 0.996, 'span': {'offset': 12187, 'length': 5}}, {'content': 'Integral', 'polygon': [1.8641, 2.061, 2.3049, 2.061, 2.3049, 2.1998, 1.8641, 2.1998], 'confidence': 1, 'span': {'offset': 12204, 'length': 8}}, {'content': 'mounting', 'polygon': [2.3535, 2.0693, 2.9252, 2.0693, 2.9252, 2.1998, 2.3535, 2.1998], 'confidence': 1, 'span': {'offset': 12213, 'length': 8}}, {'content': 'to', 'polygon': [2.966, 2.0756, 3.0856, 2.0756, 3.0856, 2.1699, 2.966, 2.1699], 'confidence': 1, 'span': {'offset': 12222, 'length': 2}}, {'content': 'Fisher', 'polygon': [3.1309, 2.061, 3.4713, 2.061, 3.4713, 2.1696, 3.1309, 2.1696], 'confidence': 1, 'span': {'offset': 12225, 'length': 6}}, {'content': '657/667', 'polygon': [0.8145, 2.2046, 1.3228, 2.2044, 1.3199, 2.3467, 0.8124, 2.3426], 'confidence': 0.993, 'span': {'offset': 12232, 'length': 7}}, {'content': 'or', 'polygon': [1.3495, 2.2045, 1.4744, 2.2 ...
#  {'pageNumber': 7, 'angle': 0.04275801032781601, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'Instruction', 'polygon': [0.7911, 0.7167, 1.5961, 0.7069, 1.5948, 0.8626, 0.7882, 0.8556], 'confidence': 0.994, 'span': {'offset': 15398, 'length': 11}}, {'content': 'Manual', 'polygon': [1.6484, 0.7063, 2.2266, 0.7004, 2.2266, 0.8587, 1.6472, 0.8626], 'confidence': 0.993, 'span': {'offset': 15410, 'length': 6}}, {'content': 'D103605X012', 'polygon': [0.7866, 0.8994, 1.4941, 0.8951, 1.4941, 1.0117, 0.7866, 1.0133], 'confidence': 0.991, 'span': {'offset': 15417, 'length': 11}}, {'content': 'Introduction', 'polygon': [6.9005, 0.7141, 7.6848, 0.7173, 7.6818, 0.8453, 6.8975, 0.8467], 'confidence': 0.993, 'span': {'offset': 15435, 'length': 12}}, {'content': 'December', 'polygon': [6.9176, 0.8963, 7.4337, 0.8986, 7.4315, 1.0116, 6.9155, 1.0167], 'confidence': 0.993, 'span': {'offset': 15448, 'length': 8}}, {'content': '2022', 'polygon': [7.4564, 0.8985, 7.7049, 0.8969, 7.7028, 1.0138, 7.4543, 1.0117], 'confidence': 0.992, 'span': {'offset': 15457, 'length': 4}}, {'content': 'Table', 'polygon': [0.7853, 1.3812, 1.1845, 1.3833, 1.1794, 1.557, 0.7794, 1.5518], 'confidence': 0.998, 'span': {'offset': 15466, 'length': 5}}, {'content': '1\\-2\\.', 'polygon': [1.2218, 1.3835, 1.4975, 1.3846, 1.4932, 1.56, 1.2169, 1.5574], 'confidence': 0.992, 'span': {'offset': 15472, 'length': 6}}, {'content': 'Specifications', 'polygon': [1.532, 1.3847, 2.5199, 1.3863, 2.5179, 1.5633, 1.5277, 1.5604], 'confidence': 0.99, 'span': {'offset': 15479, 'length': 14}}, {'content': '\\(continued\\)', 'polygon': [2.5544, 1.3863, 3.4033, 1.3849, 3.4033, 1.559, 2.5524, 1.5633], 'confidence': 0.993, 'span': {'offset': 15494, 'length': 13}}, {'content': 'Lightning', 'polygon': [0.8132, 1.6669, 1.3735, 1.6681, 1.3735, 1.8163, 0.8132, 1.8167], 'confidence': 0.995, 'span': {'offset': 15509, 'length': 9}}, {'content': 'and', 'polygon': [1.405, 1.6681, 1.6257, 1.6684, 1.6257, 1.8154, 1.405, 1.8162], 'confidence': 0.999, 'span': {'offset': 15519, 'length': 3}}, {'content': 'Surge', 'polygon': [1.6573, 1.6684, 1.9968, 1.6685, 1.9968, 1.8144, 1.6573, 1.8153], 'confidence': 0.998, 'span': {'offset': 15523, 'length': 5}}, {'content': 'Protection\\-The', 'polygon': [2.0259, 1.6685, 2.9768, 1.6668, 2.9768, 1.8138, 2.0259, 1.8143], 'confidence': 0.995, 'span': {'offset': 15529, 'length': 15}}, {'content': 'degree', 'polygon': [3.0059, 1.6667, 3.4231, 1.6651, 3.4231, 1.8144, 3.0059, 1.8138], 'confidence': 0.993, 'span': {'offset': 15545, 'length': 6}}, {'content': 'of', 'polygon': [3.4522, 1.665, 3.5977, 1.6644, 3.5977, 1.8147, 3.4522, 1.8145], 'confidence': 0.999, 'span': {'offset': 15552, 'length': 2}}, {'content': 'immunity', 'polygon': [0.8119, 1.8221, 1.3814, 1.8181, 1.376, 1.968, 0.8059, 1.9666], 'confidence': 0.994, 'span': {'offset': 15555, 'length': 8}}, {'content': 'to', 'polygon': [1.4109, 1.818, 1.5288, 1.8174, 1.5235, 1.9683, 1.4055, 1.9681], 'confidence': 0.999, 'span': {'offset': 15564, 'length': 2}}, {'content': 'lightning', 'polygon': [1.5582, 1.8173, 2.0984, 1.8158, 2.0936, 1.9692, 1.553, 1.9684], 'confidence': 0.994, 'span': {'offset': 15567, 'length': 9}}, {'content': 'is', 'polygon': [2.1278, 1.8157, 2.226, 1.8157, 2.2214, 1.9693, 2.1231, 1.9692], 'confidence': 0.999, 'span': {'offset': 15577, 'length': 2}}, {'content': 'specified', 'polygon': [2.2555, 1.8157, 2.7834, 1.8166, 2.7793, 1.9695, 2.2509, 1.9693], 'confidence': 0.994, 'span': {'offset': 15580, 'length': 9}}, {'content': 'as', 'polygon': [2.8153, 1.8167, 2.9429, 1.8172, 2.939, 1.9695, 2.8112, 1.9695], 'confidence': 0.999, 'span': {'offset': 15590, 'length': 2}}, {'content': 'Surge', 'polygon': [2.9724, 1.8173, 3.3063, 1.8192, 3.3027, 1.9693, 2.9685, 1.9695], 'confidence': 0.998, 'span': {'offset': 15593, 'length': 5}}, {'content': 'immunity', 'polygon': [3.3358, 1.8193, 3.925, 1.8242, 3.922, 1.9686, 3.3322, 1.9693], 'confidence': 0.996, 'span': {'offset': 15599, 'length': 8}}, {'conten ...
#  {'pageNumber': 8, 'angle': 0, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'Introduction', 'polygon': [0.7911, 0.717, 1.5743, 0.7151, 1.5713, 0.8453, 0.7882, 0.8492], 'confidence': 0.994, 'span': {'offset': 18483, 'length': 12}}, {'content': 'December', 'polygon': [0.7845, 0.9, 1.2954, 0.8979, 1.2933, 1.0119, 0.7824, 1.0153], 'confidence': 0.995, 'span': {'offset': 18496, 'length': 8}}, {'content': '2022', 'polygon': [1.3179, 0.8978, 1.564, 0.897, 1.5619, 1.0127, 1.3158, 1.0119], 'confidence': 0.992, 'span': {'offset': 18505, 'length': 4}}, {'content': 'Instruction', 'polygon': [6.2572, 0.7128, 7.0626, 0.7068, 7.0613, 0.8601, 6.2542, 0.8629], 'confidence': 0.994, 'span': {'offset': 18528, 'length': 11}}, {'content': 'Manual', 'polygon': [7.125, 0.7065, 7.7033, 0.7046, 7.7033, 0.8558, 7.1238, 0.8598], 'confidence': 0.998, 'span': {'offset': 18540, 'length': 6}}, {'content': 'D103605X012', 'polygon': [6.9921, 0.9005, 7.6943, 0.8962, 7.6922, 1.0133, 6.9921, 1.0131], 'confidence': 0.993, 'span': {'offset': 18547, 'length': 11}}, {'content': 'Table', 'polygon': [0.7853, 1.373, 1.1761, 1.3763, 1.1731, 1.55, 0.7823, 1.5458], 'confidence': 0.997, 'span': {'offset': 18565, 'length': 5}}, {'content': '1\\-2\\.', 'polygon': [1.2253, 1.3766, 1.4916, 1.3781, 1.4886, 1.5526, 1.2223, 1.5504], 'confidence': 0.988, 'span': {'offset': 18571, 'length': 6}}, {'content': 'Specifications', 'polygon': [1.5263, 1.3783, 2.5221, 1.3793, 2.5192, 1.5567, 1.5234, 1.5529], 'confidence': 0.993, 'span': {'offset': 18578, 'length': 14}}, {'content': '\\(continued\\)', 'polygon': [2.5569, 1.3792, 3.4021, 1.3745, 3.3991, 1.5559, 2.5539, 1.5567], 'confidence': 0.989, 'span': {'offset': 18593, 'length': 13}}, {'content': 'Options', 'polygon': [0.7409, 1.661, 1.2444, 1.6621, 1.2444, 1.8067, 0.735, 1.8067], 'confidence': 0.996, 'span': {'offset': 18611, 'length': 7}}, {'content': 'Supply', 'polygon': [0.9616, 1.8734, 1.3697, 1.8735, 1.3692, 2.0185, 0.9615, 2.0156], 'confidence': 0.841, 'span': {'offset': 18620, 'length': 6}}, {'content': 'and', 'polygon': [1.4, 1.8735, 1.6122, 1.8741, 1.6114, 2.0198, 1.3995, 2.0186], 'confidence': 0.999, 'span': {'offset': 18627, 'length': 3}}, {'content': 'output', 'polygon': [1.6518, 1.8742, 2.0528, 1.8762, 2.0517, 2.0216, 1.651, 2.02], 'confidence': 0.994, 'span': {'offset': 18631, 'length': 6}}, {'content': 'pressure', 'polygon': [2.0808, 1.8764, 2.6007, 1.8806, 2.5991, 2.0228, 2.0797, 2.0217], 'confidence': 0.994, 'span': {'offset': 18638, 'length': 8}}, {'content': 'gauges', 'polygon': [2.631, 1.8809, 3.06, 1.8859, 3.058, 2.0227, 2.6294, 2.0228], 'confidence': 0.998, 'span': {'offset': 18647, 'length': 6}}, {'content': 'or', 'polygon': [3.088, 1.8863, 3.2279, 1.8881, 3.2257, 2.0226, 3.086, 2.0227], 'confidence': 0.998, 'span': {'offset': 18654, 'length': 2}}, {'content': 'Tire', 'polygon': [0.969, 2.0263, 1.1905, 2.0259, 1.1875, 2.1581, 0.966, 2.1546], 'confidence': 0.865, 'span': {'offset': 18669, 'length': 4}}, {'content': 'valves', 'polygon': [1.2182, 2.0259, 1.5873, 2.0255, 1.5843, 2.1633, 1.2152, 2.1585], 'confidence': 0.996, 'span': {'offset': 18674, 'length': 6}}, {'content': '\\_', 'polygon': [1.615, 2.0255, 1.6958, 2.0255, 1.6928, 2.1646, 1.612, 2.1637], 'confidence': 0.121, 'span': {'offset': 18681, 'length': 2}}, {'content': 'Integral', 'polygon': [1.7627, 2.0255, 2.2333, 2.0255, 2.2304, 2.1696, 1.7597, 2.1653], 'confidence': 0.989, 'span': {'offset': 18684, 'length': 8}}, {'content': 'mounted', 'polygon': [2.261, 2.0255, 2.8125, 2.026, 2.8095, 2.1731, 2.2581, 2.1698], 'confidence': 0.997, 'span': {'offset': 18693, 'length': 7}}, {'content': 'filter', 'polygon': [2.8425, 2.026, 3.1193, 2.0265, 3.1164, 2.1733, 2.8395, 2.1732], 'confidence': 0.994, 'span': {'offset': 18701, 'length': 6}}, {'content': 'regulator', 'polygon': [3.147, 2.0266, 3.7192, 2.0279, 3.7162, 2.1733, 3.144, 2.1733], 'confidence': 0.995, 'span': {'offset': 18708, 'length': 9}}, {'content': 'Low\\-Bleed', 'polygon': [0.9615, 2 ...

# %%
# retriving tables from the document
result_ocr.tables
# Out:
# [{'rowCount': 6, 'columnCount': 2, 'cells': [{'rowIndex': 0, 'columnIndex': 0, 'content': 'Instrument Level', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.84, 2.5867, 2.0967, 2.5867, 2.0967, 2.7633, 0.8367, 2.7633]}], 'spans': [{'offset': 220, 'length': 16}]}, {'rowIndex': 0, 'columnIndex': 1, 'content': 'HC, AD, PD, ODV', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.0967, 2.5867, 3.2833, 2.5867, 3.2867, 2.7633, 2.0967, 2.7633]}], 'spans': [{'offset': 239, 'length': 15}]}, {'rowIndex': 1, 'columnIndex': 0, 'content': 'Device Type', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.8367, 2.7633, 2.0967, 2.7633, 2.0967, 2.9267, 0.8367, 2.9267]}], 'spans': [{'offset': 259, 'length': 11}]}, {'rowIndex': 1, 'columnIndex': 1, 'content': '1309', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.0967, 2.7633, 3.2867, 2.7633, 3.2867, 2.9267, 2.0967, 2.9267]}], 'spans': [{'offset': 273, 'length': 4}]}, {'rowIndex': 2, 'columnIndex': 0, 'content': 'Hardware Revision', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.8367, 2.9267, 2.0967, 2.9267, 2.1, 3.0767, 0.8367, 3.0767]}], 'spans': [{'offset': 282, 'length': 17}]}, {'rowIndex': 2, 'columnIndex': 1, 'content': '2', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.0967, 2.9267, 3.2867, 2.9267, 3.2867, 3.0767, 2.1, 3.0767]}], 'spans': [{'offset': 302, 'length': 1}]}, {'rowIndex': 3, 'columnIndex': 0, 'content': 'Firmware Revision', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.8367, 3.0767, 2.1, 3.0767, 2.1, 3.2267, 0.8367, 3.2267]}], 'spans': [{'offset': 308, 'length': 17}]}, {'rowIndex': 3, 'columnIndex': 1, 'content': '7', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.1, 3.0767, 3.2867, 3.0767, 3.2867, 3.2267, 2.1, 3.2267]}], 'spans': [{'offset': 328, 'length': 1}]}, {'rowIndex': 4, 'columnIndex': 0, 'content': 'Device Revision', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.8367, 3.2267, 2.1, 3.2267, 2.1, 3.3833, 0.8333, 3.3867]}], 'spans': [{'offset': 334, 'length': 15}]}, {'rowIndex': 4, 'columnIndex': 1, 'content': '1 3', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.1, 3.2267, 3.2867, 3.2267, 3.2867, 3.3867, 2.1, 3.3833]}], 'spans': [{'offset': 352, 'length': 3}]}, {'rowIndex': 5, 'columnIndex': 0, 'content': 'DD Revision', 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.8333, 3.3867, 2.1, 3.3833, 2.1, 3.5467, 0.8333, 3.5467]}], 'spans': [{'offset': 360, 'length': 11}]}, {'rowIndex': 5, 'columnIndex': 1, 'content': '7 1', 'boundingRegions': [{'pageNumber': 1, 'polygon': [2.1, 3.3833, 3.2867, 3.3867, 3.2867, 3.5467, 2.1, 3.5467]}], 'spans': [{'offset': 374, 'length': 3}]}], 'boundingRegions': [{'pageNumber': 1, 'polygon': [0.8237, 2.588, 3.2913, 2.5895, 3.2899, 3.557, 0.822, 3.5556]}], 'spans': [{'offset': 204, 'length': 175}]},
#  {'rowCount': 21, 'columnCount': 2, 'cells': [{'rowIndex': 0, 'columnIndex': 0, 'content': 'Travel/Pressure Control', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4725, 5.896, 7.1658, 5.896, 7.1658, 6.0731, 4.4691, 6.0765]}], 'spans': [{'offset': 1198, 'length': 23}]}, {'rowIndex': 0, 'columnIndex': 1, 'content': '18', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 5.896, 7.7991, 5.896, 7.7991, 6.0765, 7.1658, 6.0731]}], 'spans': [{'offset': 1224, 'length': 2}]}, {'rowIndex': 1, 'columnIndex': 0, 'content': 'Travel/Pressure Select', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4691, 6.0765, 7.1658, 6.0731, 7.1658, 6.2264, 4.4657, 6.2298]}], 'spans': [{'offset': 1231, 'length': 22}]}, {'rowIndex': 1, 'columnIndex': 1, 'content': '18', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 6.0731, 7.7991, 6.0765, 7.7991, 6.2264, 7.1658, 6.2264]}], 'spans': [{'offset': 1256, 'length': 2}]}, {'rowIndex': 2, 'columnIndex': 0, 'content': 'Cutoffs and Limits', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4657, 6.2298, 7.1658, 6.2264, 7.1658, 6.3796, 4.4623, 6.383]}], 'spans': [{'offset': 1263, 'length': 18}]}, {'rowIndex': 2, 'columnIndex': 1, 'content': '19', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 6.2264, 7.7991, 6.2264, 7.7991, 6.3796, 7.1658, 6.3796]}], 'spans': [{'offset': 1284, 'length': 2}]}, {'rowIndex': 3, 'columnIndex': 0, 'content': 'Pressure Control', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4623, 6.383, 7.1658, 6.3796, 7.1658, 6.5295, 4.4623, 6.5329]}], 'spans': [{'offset': 1291, 'length': 16}]}, {'rowIndex': 3, 'columnIndex': 1, 'content': '19', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 6.3796, 7.7991, 6.3796, 7.7991, 6.5295, 7.1658, 6.5295]}], 'spans': [{'offset': 1310, 'length': 2}]}, {'rowIndex': 4, 'columnIndex': 0, 'content': 'Pressure Fallback', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4623, 6.5329, 7.1658, 6.5295, 7.1658, 6.6793, 4.4589, 6.6827]}], 'spans': [{'offset': 1317, 'length': 17}]}, {'rowIndex': 4, 'columnIndex': 1, 'content': '20', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 6.5295, 7.7991, 6.5295, 7.7991, 6.6793, 7.1658, 6.6793]}], 'spans': [{'offset': 1337, 'length': 2}]}, {'rowIndex': 5, 'columnIndex': 0, 'content': 'Control Mode', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4589, 6.6827, 7.1658, 6.6793, 7.1658, 6.836, 4.4555, 6.836]}], 'spans': [{'offset': 1344, 'length': 12}]}, {'rowIndex': 5, 'columnIndex': 1, 'content': '20', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 6.6793, 7.7991, 6.6793, 7.7991, 6.836, 7.1658, 6.836]}], 'spans': [{'offset': 1359, 'length': 2}]}, {'rowIndex': 6, 'columnIndex': 0, 'content': 'Characterization', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4555, 6.836, 7.1658, 6.836, 7.1658, 6.9892, 4.4555, 6.9892]}], 'spans': [{'offset': 1366, 'length': 16}]}, {'rowIndex': 6, 'columnIndex': 1, 'content': '21', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 6.836, 7.7991, 6.836, 7.7991, 6.9892, 7.1658, 6.9892]}], 'spans': [{'offset': 1385, 'length': 2}]}, {'rowIndex': 7, 'columnIndex': 0, 'content': 'Dynamic Response', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4555, 6.9892, 7.1658, 6.9892, 7.1658, 7.1459, 4.4521, 7.1527]}], 'spans': [{'offset': 1392, 'length': 16}]}, {'rowIndex': 7, 'columnIndex': 1, 'content': '23', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 6.9892, 7.7991, 6.9892, 7.7991, 7.1459, 7.1658, 7.1459]}], 'spans': [{'offset': 1411, 'length': 2}]}, {'rowIndex': 8, 'columnIndex': 0, 'content': 'Tuning', 'boundingRegions': [{'pageNumber': 1, 'polygon': [4.4521, 7.1527, 7.1658, 7.1459, 7.1658, 7.2787, 4.4521, 7.2855]}], 'spans': [{'offset': 1418, 'length': 6}]}, {'rowIndex': 8, 'columnIndex': 1, 'content': '24', 'boundingRegions': [{'pageNumber': 1, 'polygon': [7.1658, 7.1459, 7.7991, 7.1459, 7.7991, 7.2719, 7.1658, 7.2787]}], 'spans': [{'offset': 1427, 'length': 2}]}, {'rowIndex': 9, 'columnIndex': 0,  ...
#  {'rowCount': 36, 'columnCount': 2, 'cells': [{'rowIndex': 0, 'columnIndex': 0, 'columnSpan': 2, 'content': 'Contents \\(continued\\)', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6826, 1.2726, 4.0315, 1.2785, 4.0315, 1.6221, 0.6826, 1.6221]}], 'spans': [{'offset': 1998, 'length': 22}]}, {'rowIndex': 1, 'columnIndex': 0, 'content': 'Section 4 Calibration', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6826, 1.6221, 3.581, 1.6162, 3.581, 1.7998, 0.6826, 1.8058]}], 'spans': [{'offset': 2026, 'length': 21}]}, {'rowIndex': 1, 'columnIndex': 1, 'content': '39', 'boundingRegions': [{'pageNumber': 2, 'polygon': [3.581, 1.6162, 4.0315, 1.6221, 4.0315, 1.7998, 3.581, 1.7998]}], 'spans': [{'offset': 2050, 'length': 2}]}, {'rowIndex': 2, 'columnIndex': 0, 'content': 'Calibration Overview', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6826, 1.8058, 3.581, 1.7998, 3.581, 1.9598, 0.6826, 1.9598]}], 'spans': [{'offset': 2057, 'length': 20}]}, {'rowIndex': 2, 'columnIndex': 1, 'content': '39', 'boundingRegions': [{'pageNumber': 2, 'polygon': [3.581, 1.7998, 4.0315, 1.7998, 4.0315, 1.9598, 3.581, 1.9598]}], 'spans': [{'offset': 2080, 'length': 2}]}, {'rowIndex': 3, 'columnIndex': 0, 'content': 'Travel Calibration', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6826, 1.9598, 3.581, 1.9598, 3.581, 2.1138, 0.6826, 2.1138]}], 'spans': [{'offset': 2087, 'length': 18}]}, {'rowIndex': 3, 'columnIndex': 1, 'content': '40', 'boundingRegions': [{'pageNumber': 2, 'polygon': [3.581, 1.9598, 4.0315, 1.9598, 4.0315, 2.102, 3.581, 2.1138]}], 'spans': [{'offset': 2108, 'length': 2}]}, {'rowIndex': 4, 'columnIndex': 0, 'content': 'Auto Calibration', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6826, 2.1138, 3.581, 2.1138, 3.581, 2.262, 0.6826, 2.262]}], 'spans': [{'offset': 2115, 'length': 16}]}, {'rowIndex': 4, 'columnIndex': 1, 'content': '40', 'boundingRegions': [{'pageNumber': 2, 'polygon': [3.581, 2.1138, 4.0315, 2.102, 4.0315, 2.262, 3.581, 2.262]}], 'spans': [{'offset': 2134, 'length': 2}]}, {'rowIndex': 5, 'columnIndex': 0, 'content': 'Manual Calibration', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6826, 2.262, 3.581, 2.262, 3.5869, 2.4101, 0.6826, 2.416]}], 'spans': [{'offset': 2141, 'length': 18}]}, {'rowIndex': 5, 'columnIndex': 1, 'content': '41', 'boundingRegions': [{'pageNumber': 2, 'polygon': [3.581, 2.262, 4.0315, 2.262, 4.0315, 2.4101, 3.5869, 2.4101]}], 'spans': [{'offset': 2162, 'length': 2}]}, {'rowIndex': 6, 'columnIndex': 0, 'content': 'Pushbutton Calibration', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6826, 2.416, 3.5869, 2.4101, 3.5869, 2.57, 0.6826, 2.57]}], 'spans': [{'offset': 2169, 'length': 22}]}, {'rowIndex': 6, 'columnIndex': 1, 'content': '42', 'boundingRegions': [{'pageNumber': 2, 'polygon': [3.5869, 2.4101, 4.0315, 2.4101, 4.0315, 2.57, 3.5869, 2.57]}], 'spans': [{'offset': 2194, 'length': 2}]}, {'rowIndex': 7, 'columnIndex': 0, 'content': 'Sensor Calibration', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6826, 2.57, 3.5869, 2.57, 3.5869, 2.7181, 0.6886, 2.7241]}], 'spans': [{'offset': 2201, 'length': 18}]}, {'rowIndex': 7, 'columnIndex': 1, 'content': '43', 'boundingRegions': [{'pageNumber': 2, 'polygon': [3.5869, 2.57, 4.0315, 2.57, 4.0315, 2.7181, 3.5869, 2.7181]}], 'spans': [{'offset': 2222, 'length': 2}]}, {'rowIndex': 8, 'columnIndex': 0, 'content': 'Pressure Sensors', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6886, 2.7241, 3.5869, 2.7181, 3.5869, 2.8722, 0.6886, 2.8781]}], 'spans': [{'offset': 2229, 'length': 16}]}, {'rowIndex': 8, 'columnIndex': 1, 'content': '43', 'boundingRegions': [{'pageNumber': 2, 'polygon': [3.5869, 2.7181, 4.0315, 2.7181, 4.0374, 2.8722, 3.5869, 2.8722]}], 'spans': [{'offset': 2248, 'length': 2}]}, {'rowIndex': 9, 'columnIndex': 0, 'content': 'Analog Input Calibration', 'boundingRegions': [{'pageNumber': 2, 'polygon': [0.6886, 2.8781, 3.5869, 2.8722, 3.5869, 3.0262, 0.6886, 3.0262]}], 'spans': [{'offset': 2255, 'length': 24}]} ...
#  {'rowCount': 33, 'columnCount': 2, 'cells': [{'rowIndex': 0, 'columnIndex': 0, 'content': 'Submodule Maintenance', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4278, 1.2928, 7.3819, 1.3041, 7.3819, 1.5021, 4.4278, 1.5077]}], 'spans': [{'offset': 3083, 'length': 21}]}, {'rowIndex': 0, 'columnIndex': 1, 'content': '61', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3819, 1.3041, 7.7724, 1.3041, 7.7724, 1.5021, 7.3819, 1.5021]}], 'spans': [{'offset': 3107, 'length': 2}]}, {'rowIndex': 1, 'columnIndex': 0, 'content': 'I/P Converter \\.', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4278, 1.5077, 7.3819, 1.5021, 7.3819, 1.6548, 4.4278, 1.6548]}], 'spans': [{'offset': 3114, 'length': 16}]}, {'rowIndex': 1, 'columnIndex': 1, 'content': '61', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3819, 1.5021, 7.7724, 1.5021, 7.7724, 1.6548, 7.3819, 1.6548]}], 'spans': [{'offset': 3133, 'length': 2}]}, {'rowIndex': 2, 'columnIndex': 0, 'content': 'Printed Wiring Board \\(PWB\\) Assembly', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4278, 1.6548, 7.3819, 1.6548, 7.3819, 1.8189, 4.4278, 1.8132]}], 'spans': [{'offset': 3140, 'length': 37}]}, {'rowIndex': 2, 'columnIndex': 1, 'content': '63', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3819, 1.6548, 7.7724, 1.6548, 7.7724, 1.8189, 7.3819, 1.8189]}], 'spans': [{'offset': 3180, 'length': 2}]}, {'rowIndex': 3, 'columnIndex': 0, 'content': 'Pneumatic Relay', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4278, 1.8132, 7.3819, 1.8189, 7.3819, 1.966, 4.4278, 1.966]}], 'spans': [{'offset': 3187, 'length': 15}]}, {'rowIndex': 3, 'columnIndex': 1, 'content': '65', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3819, 1.8189, 7.7724, 1.8189, 7.7724, 1.966, 7.3819, 1.966]}], 'spans': [{'offset': 3205, 'length': 2}]}, {'rowIndex': 4, 'columnIndex': 0, 'content': 'Gauges, Pipe Plugs or Tire Valves', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4278, 1.966, 7.3819, 1.966, 7.3819, 2.1244, 4.4278, 2.1244]}], 'spans': [{'offset': 3212, 'length': 33}]}, {'rowIndex': 4, 'columnIndex': 1, 'content': '65', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3819, 1.966, 7.7724, 1.966, 7.7724, 2.1244, 7.3819, 2.1244]}], 'spans': [{'offset': 3248, 'length': 2}]}, {'rowIndex': 5, 'columnIndex': 0, 'content': 'Terminal Box', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4278, 2.1244, 7.3819, 2.1244, 7.3819, 2.2659, 4.4278, 2.2659]}], 'spans': [{'offset': 3255, 'length': 12}]}, {'rowIndex': 5, 'columnIndex': 1, 'content': '66', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3819, 2.1244, 7.7724, 2.1244, 7.7724, 2.2659, 7.3819, 2.2659]}], 'spans': [{'offset': 3270, 'length': 2}]}, {'rowIndex': 6, 'columnIndex': 0, 'content': 'Removing the Terminal Box', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4278, 2.2659, 7.3819, 2.2659, 7.3819, 2.4243, 4.4278, 2.4243]}], 'spans': [{'offset': 3277, 'length': 25}]}, {'rowIndex': 6, 'columnIndex': 1, 'content': '66', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3819, 2.2659, 7.7724, 2.2659, 7.7724, 2.4243, 7.3819, 2.4243]}], 'spans': [{'offset': 3305, 'length': 2}]}, {'rowIndex': 7, 'columnIndex': 0, 'content': 'Replacing the Terminal Box', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4278, 2.4243, 7.3819, 2.4243, 7.3763, 2.577, 4.4222, 2.5827]}], 'spans': [{'offset': 3312, 'length': 26}]}, {'rowIndex': 7, 'columnIndex': 1, 'content': '67', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3819, 2.4243, 7.7724, 2.4243, 7.7724, 2.577, 7.3763, 2.577]}], 'spans': [{'offset': 3341, 'length': 2}]}, {'rowIndex': 8, 'columnIndex': 0, 'content': 'Troubleshooting', 'boundingRegions': [{'pageNumber': 2, 'polygon': [4.4222, 2.5827, 7.3763, 2.577, 7.3763, 2.7185, 4.4222, 2.7241]}], 'spans': [{'offset': 3348, 'length': 15}]}, {'rowIndex': 8, 'columnIndex': 1, 'content': '67', 'boundingRegions': [{'pageNumber': 2, 'polygon': [7.3763, 2.577, 7.7724, 2.577, 7.7781, 2.7128, 7.3763, 2.7185]}], 'spans': [{'offset' ...
#  {'rowCount': 14, 'columnCount': 5, 'cells': [{'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 0, 'rowSpan': 2, 'content': 'CAPABILITY', 'boundingRegions': [{'pageNumber': 4, 'polygon': [0.7509, 7.3248, 3.4772, 7.3305, 3.4716, 7.6524, 0.7509, 7.6524]}], 'spans': [{'offset': 8411, 'length': 10}]}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 1, 'columnSpan': 4, 'content': 'DIAGNOSTIC LEVEL\\(2\\)', 'boundingRegions': [{'pageNumber': 4, 'polygon': [3.4772, 7.3305, 6.2317, 7.3361, 6.2317, 7.4829, 3.4772, 7.4829]}], 'spans': [{'offset': 8424, 'length': 21}]}, {'kind': 'columnHeader', 'rowIndex': 1, 'columnIndex': 1, 'content': 'HC', 'boundingRegions': [{'pageNumber': 4, 'polygon': [3.4772, 7.4829, 4.1602, 7.4829, 4.1602, 7.6524, 3.4716, 7.6524]}], 'spans': [{'offset': 8454, 'length': 2}]}, {'kind': 'columnHeader', 'rowIndex': 1, 'columnIndex': 2, 'content': 'AD', 'boundingRegions': [{'pageNumber': 4, 'polygon': [4.1602, 7.4829, 4.8488, 7.4829, 4.8488, 7.6524, 4.1602, 7.6524]}], 'spans': [{'offset': 8459, 'length': 2}]}, {'kind': 'columnHeader', 'rowIndex': 1, 'columnIndex': 3, 'content': 'PD', 'boundingRegions': [{'pageNumber': 4, 'polygon': [4.8488, 7.4829, 5.5375, 7.4829, 5.5375, 7.6524, 4.8488, 7.6524]}], 'spans': [{'offset': 8464, 'length': 2}]}, {'kind': 'columnHeader', 'rowIndex': 1, 'columnIndex': 4, 'content': 'ODV', 'boundingRegions': [{'pageNumber': 4, 'polygon': [5.5375, 7.4829, 6.2317, 7.4829, 6.2317, 7.6524, 5.5375, 7.6524]}], 'spans': [{'offset': 8469, 'length': 3}]}, {'rowIndex': 2, 'columnIndex': 0, 'content': 'Auto Calibration', 'boundingRegions': [{'pageNumber': 4, 'polygon': [0.7509, 7.6524, 3.4716, 7.6524, 3.4716, 7.8105, 0.7509, 7.8105]}], 'spans': [{'offset': 8499, 'length': 16}]}, {'rowIndex': 2, 'columnIndex': 1, 'content': 'X :selected:', 'boundingRegions': [{'pageNumber': 4, 'polygon': [3.4716, 7.6524, 4.1602, 7.6524, 4.1602, 7.8105, 3.4716, 7.8105]}], 'spans': [{'offset': 8518, 'length': 12}]}, {'rowIndex': 2, 'columnIndex': 2, 'content': 'X :selected:', 'boundingRegions': [{'pageNumber': 4, 'polygon': [4.1602, 7.6524, 4.8488, 7.6524, 4.8488, 7.8105, 4.1602, 7.8105]}], 'spans': [{'offset': 8533, 'length': 12}]}, {'rowIndex': 2, 'columnIndex': 3, 'content': 'X :selected:', 'boundingRegions': [{'pageNumber': 4, 'polygon': [4.8488, 7.6524, 5.5375, 7.6524, 5.5375, 7.8105, 4.8488, 7.8105]}], 'spans': [{'offset': 8548, 'length': 12}]}, {'rowIndex': 2, 'columnIndex': 4, 'content': 'X :selected:', 'boundingRegions': [{'pageNumber': 4, 'polygon': [5.5375, 7.6524, 6.2317, 7.6524, 6.2317, 7.8105, 5.5375, 7.8105]}], 'spans': [{'offset': 8563, 'length': 12}]}, {'rowIndex': 3, 'columnIndex': 0, 'content': 'Custom Characterization', 'boundingRegions': [{'pageNumber': 4, 'polygon': [0.7509, 7.8105, 3.4716, 7.8105, 3.4716, 7.9743, 0.7509, 7.9743]}], 'spans': [{'offset': 8580, 'length': 23}]}, {'rowIndex': 3, 'columnIndex': 1, 'content': 'X :selected:', 'boundingRegions': [{'pageNumber': 4, 'polygon': [3.4716, 7.8105, 4.1602, 7.8105, 4.1602, 7.9743, 3.4716, 7.9743]}], 'spans': [{'offset': 8606, 'length': 12}]}, {'rowIndex': 3, 'columnIndex': 2, 'content': 'X :selected:', 'boundingRegions': [{'pageNumber': 4, 'polygon': [4.1602, 7.8105, 4.8488, 7.8105, 4.8488, 7.9743, 4.1602, 7.9743]}], 'spans': [{'offset': 8621, 'length': 12}]}, {'rowIndex': 3, 'columnIndex': 3, 'content': 'X :selected:', 'boundingRegions': [{'pageNumber': 4, 'polygon': [4.8488, 7.8105, 5.5375, 7.8105, 5.5431, 7.9743, 4.8488, 7.9743]}], 'spans': [{'offset': 8636, 'length': 12}]}, {'rowIndex': 3, 'columnIndex': 4, 'content': 'X :selected:', 'boundingRegions': [{'pageNumber': 4, 'polygon': [5.5375, 7.8105, 6.2317, 7.8105, 6.2317, 7.9743, 5.5431, 7.9743]}], 'spans': [{'offset': 8651, 'length': 12}]}, {'rowIndex': 4, 'columnIndex': 0, 'content': 'Burst Communication', 'boundingRegions': [{'pageNumber': 4, 'polygon': [0.7509, 7.9743, 3.4716, 7.9743, 3.4716, 8.1438, 0.7509, 8.1381]}], 'spans': [{'offset': 8668, 'length': 19}]}, {'rowIndex': 4, ' ...
#  {'rowCount': 7, 'columnCount': 5, 'cells': [{'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 0, 'content': 'Port', 'boundingRegions': [{'pageNumber': 8, 'polygon': [0.7513, 6.2948, 1.7153, 6.2948, 1.7153, 6.5751, 0.7513, 6.5751]}], 'spans': [{'offset': 21838, 'length': 4}]}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 1, 'content': 'Phenomenon', 'boundingRegions': [{'pageNumber': 8, 'polygon': [1.7153, 6.2948, 3.1253, 6.2948, 3.1253, 6.5751, 1.7153, 6.5751]}], 'spans': [{'offset': 21845, 'length': 10}]}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 2, 'content': 'Basic Standard', 'boundingRegions': [{'pageNumber': 8, 'polygon': [3.1253, 6.2948, 4.1396, 6.2948, 4.1396, 6.5751, 3.1253, 6.5751]}], 'spans': [{'offset': 21858, 'length': 14}]}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 3, 'content': 'Test Level', 'boundingRegions': [{'pageNumber': 8, 'polygon': [4.1396, 6.2948, 6.8446, 6.2948, 6.8446, 6.5823, 4.1396, 6.5751]}], 'spans': [{'offset': 21875, 'length': 10}]}, {'kind': 'columnHeader', 'rowIndex': 0, 'columnIndex': 4, 'content': 'Performance Criteria\\(1\\)', 'boundingRegions': [{'pageNumber': 8, 'polygon': [6.8446, 6.2948, 7.7438, 6.302, 7.7438, 6.5823, 6.8446, 6.5823]}], 'spans': [{'offset': 21888, 'length': 25}]}, {'rowIndex': 1, 'columnIndex': 0, 'rowSpan': 3, 'content': 'Enclosure', 'boundingRegions': [{'pageNumber': 8, 'polygon': [0.7513, 6.5751, 1.7153, 6.5751, 1.7081, 7.6748, 0.7513, 7.6748]}], 'spans': [{'offset': 21940, 'length': 9}]}, {'rowIndex': 1, 'columnIndex': 1, 'content': 'Electrostatic discharge \\(ESD\\)', 'boundingRegions': [{'pageNumber': 8, 'polygon': [1.7153, 6.5751, 3.1253, 6.5751, 3.1253, 6.8482, 1.7153, 6.8482]}], 'spans': [{'offset': 21952, 'length': 31}]}, {'rowIndex': 1, 'columnIndex': 2, 'content': 'IEC 61000\\-4\\-2', 'boundingRegions': [{'pageNumber': 8, 'polygon': [3.1253, 6.5751, 4.1396, 6.5751, 4.1396, 6.8482, 3.1253, 6.8482]}], 'spans': [{'offset': 21986, 'length': 15}]}, {'rowIndex': 1, 'columnIndex': 3, 'content': '4 kV contact 8 kV air', 'boundingRegions': [{'pageNumber': 8, 'polygon': [4.1396, 6.5751, 6.8446, 6.5823, 6.8446, 6.8482, 4.1396, 6.8482]}], 'spans': [{'offset': 22004, 'length': 21}]}, {'rowIndex': 1, 'columnIndex': 4, 'content': 'A :selected:', 'boundingRegions': [{'pageNumber': 8, 'polygon': [6.8446, 6.5823, 7.7438, 6.5823, 7.7438, 6.8554, 6.8446, 6.8482]}], 'spans': [{'offset': 22028, 'length': 12}]}, {'rowIndex': 2, 'columnIndex': 1, 'content': 'Radiated EM field', 'boundingRegions': [{'pageNumber': 8, 'polygon': [1.7153, 6.8482, 3.1253, 6.8482, 3.1253, 7.3945, 1.7081, 7.3945]}], 'spans': [{'offset': 22046, 'length': 17}]}, {'rowIndex': 2, 'columnIndex': 2, 'content': 'IEC 61000\\-4\\-3', 'boundingRegions': [{'pageNumber': 8, 'polygon': [3.1253, 6.8482, 4.1396, 6.8482, 4.1396, 7.3945, 3.1253, 7.3945]}], 'spans': [{'offset': 22066, 'length': 15}]}, {'rowIndex': 2, 'columnIndex': 3, 'content': '80 to 1000 MHz @ 10 V/m with 1 kHz AM at 80% 1400 to 2000 MHz @ 10 V/m with 1 kHz AM at 80% 2000 to 2700 MHz @ 10 V/m with 1 kHz AM at 80% 2700 to 6000 MHz @ 10V/m with 1 kHz AM at 80%\\(2\\)', 'boundingRegions': [{'pageNumber': 8, 'polygon': [4.1396, 6.8482, 6.8446, 6.8482, 6.8446, 7.3945, 4.1396, 7.3945]}], 'spans': [{'offset': 22084, 'length': 189}]}, {'rowIndex': 2, 'columnIndex': 4, 'content': 'A', 'boundingRegions': [{'pageNumber': 8, 'polygon': [6.8446, 6.8482, 7.7438, 6.8554, 7.7438, 7.3945, 6.8446, 7.3945]}], 'spans': [{'offset': 22276, 'length': 1}]}, {'rowIndex': 3, 'columnIndex': 1, 'content': 'Rated power frequency magnetic field', 'boundingRegions': [{'pageNumber': 8, 'polygon': [1.7081, 7.3945, 3.1253, 7.3945, 3.1253, 7.6748, 1.7081, 7.6748]}], 'spans': [{'offset': 22283, 'length': 36}]}, {'rowIndex': 3, 'columnIndex': 2, 'content': 'IEC 61000\\-4\\-8', 'boundingRegions': [{'pageNumber': 8, 'polygon': [3.1253, 7.3945, 4.1396, 7.3945, 4.1396, 7.6748, 3.1253, 7.6748]}], 'spans': [{'offset': 22322, 'length': 15}]}, {'rowIndex': ...

# %%
print(result_ocr.content)
# Out:
# <!-- PageHeader="DVC6200 Digital Valve Controller December 2022" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Fisher™ FIELDVUE™ DVC6200 Digital Valve Controller
# ===
#
# This manual applies to
#
# |||
# | - | - |
# | Instrument Level | HC, AD, PD, ODV |
# | Device Type | 1309 |
# | Hardware Revision | 2 |
# | Firmware Revision | 7 |
# | Device Revision | 1 3 |
# | DD Revision | 7 1 |
#
#
# # Contents
#
# Section 1 Introduction
#
# 3
#
# Installation, Pneumatic and Electrical Connections,
#
# and Initial Configuration
#
# 3
#
# Scope of Manual
#
# 3
#
# Conventions Used in this Manual
#
# 3
#
# Description
#
# 3
#
# Specifications
#
# 5
#
# Related Documents
#
# 5
#
# HART Filter
#
# 9
#
# Voltage Available
#
# 9
#
# Compliance Voltage
#
# 11
#
# Auxiliary Terminal Wiring Length Guidelines
#
# 12
#
# Maximum Cable Capacitance
#
# 12
#
# Installation in Conjunction with a Rosemount ™
#
# 333 HART Tri\-Loop ™ HART\-to\-Analog
#
# Signal Converter
#
# 13
#
# Section 3 Configuration
#
# 15
#
# Guided Setup
#
# 15
#
# Manual Setup
#
# 15
#
# Mode and Protection
#
# 16
#
# Instrument Mode
#
# 16
#
# Write Protection
#
# 16
#
# Instrument
#
# 16
#
# Identification
#
# 16
#
# Serial Numbers
#
# 17
#
# Units
#
# 17
#
# Terminal Box
#
# 17
#
# Input Range
#
# 17
#
# Spec Sheet
#
# 18
#
# Edit Instrument Time
#
# 18
#
# FIELDVUE Instruments
#
# FISHER
#
# W9713
#
# |||
# | - | - |
# | Travel/Pressure Control | 18 |
# | Travel/Pressure Select | 18 |
# | Cutoffs and Limits | 19 |
# | Pressure Control | 19 |
# | Pressure Fallback | 20 |
# | Control Mode | 20 |
# | Characterization | 21 |
# | Dynamic Response | 23 |
# | Tuning | 24 |
# | Travel Tuning | 24 |
# | Pressure Tuning | 27 |
# | Travel/Pressure Integral Settings | 27 |
# | Valve and Actuator | 28 |
# | Partial Stroke Test | 30 |
# | Outputs | 36 |
# | Output Terminal Configuration | 36 |
# | Switch Configuration | 36 |
# | HART Variable Assignments | 37 |
# | Transmitter Output | 37 |
# | Alert Setup | 38 |
# | Change to HART 5 / HART 7 | 38 |
#
# <!-- PageFooter="www\.Fisher\.com FISHER®" -->
#
# Educational Services
#
# 8
#
# Section 2 Wiring Practices
#
# 9
#
# Control System Requirements
#
# 9
#
# EMERSON TM
#
# DVC6200 Digital Valve Controller December 2022
#
# |||
# | - | - |
# | Contents \(continued\) ||
# | Section 4 Calibration | 39 |
# | Calibration Overview | 39 |
# | Travel Calibration | 40 |
# | Auto Calibration | 40 |
# | Manual Calibration | 41 |
# | Pushbutton Calibration | 42 |
# | Sensor Calibration | 43 |
# | Pressure Sensors | 43 |
# | Analog Input Calibration | 44 |
# | Relay Adjustment | 45 |
# | Double\-Acting Relay | 45 |
# | Single\-Acting Relays | 46 |
# | PST Calibration | 47 |
# | Section 5 Device Information, Alerts, | |
# | and Diagnostics | 48 |
# | Overview | 48 |
# | Status & Primary Purpose Variables | 48 |
# | Device Information | 48 |
# | Service Tools | 49 |
# | Device Status | 49 |
# | Alert Record | 49 |
# | Alert Reporting | 49 |
# | Deadband Principle of Operation | 52 |
# | Diagnostics \. | 54 |
# | Stroke Valve | 54 |
# | Partial Stroke Test \(ODV only\) | 54 |
# | Variables | 56 |
# | Section 6 Maintenance and | |
# | Troubleshooting | 57 |
# | Replacing the Magnetic Feedback Assembly | 58 |
# | Module Base Maintenance | 58 |
# | Tools Required \. | 58 |
# | Component Replacement | 59 |
# | Removing the Module Base | 59 |
# | Replacing the Module Base | 60 |
#
# |||
# | - | - |
# | Submodule Maintenance | 61 |
# | I/P Converter \. | 61 |
# | Printed Wiring Board \(PWB\) Assembly | 63 |
# | Pneumatic Relay | 65 |
# | Gauges, Pipe Plugs or Tire Valves | 65 |
# | Terminal Box | 66 |
# | Removing the Terminal Box | 66 |
# | Replacing the Terminal Box | 67 |
# | Troubleshooting | 67 |
# | Checking Voltage Available | 67 |
# | Restart Processor | 68 |
# | DVC6200 Technical Support Checklist | 70 |
# | Section 7 Parts | 71 |
# | Parts Ordering | 71 |
# | Parts Kits | 71 |
# | PWB Assembly | 71 |
# | Parts List | 73 |
# | Housing | 73 |
# | Common Parts | 73 |
# | Module Base | 73 |
# | I/P Converter Assembly | 73 |
# | Relay \. | 73 |
# | Terminal Box | 74 |
# | Feedback Connection Terminal Box | 74 |
# | Pressure Gauges, Pipe Plugs, or Tire Valve Assemblies | 74 |
# | DVC6215 Feedback Unit | 74 |
# | HART Filters | 74 |
# | Appendix A Principle of Operation | 81 |
# | HART Communication | 81 |
# | DVC6200 Digital Valve Controller | 81 |
# | Appendix B Handheld Communicator Menu Tree | 85 |
# | Glossary | 95 |
# | Index | 101 |
#
# <!-- PageNumber="2" -->
#
# Instruction Manual D103605X012
#
# <!-- PageHeader="Introduction December 2022" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Section 1 Introduction
# ===
#
# Installation, Pneumatic and Electrical Connections, and Initial Configuration
# ===
#
# Refer to the DVC6200 Series Quick Start Guide \(D103556X012\) for DVC6200 installation, connection and initial configuration information\. If a copy of this quick start guide is needed scan or click the QR code at the right, contact your Emerson sales office or visit our website at Fisher\.com\.
#
# Scan or click to access field support
#
#
# # Scope of Manual
#
# This instruction manual is a supplement to the DVC6200 Series Quick Start Guide \(D103556X012\) that ships with every instrument\. This instruction manual includes product specifications, reference materials, custom setup information, maintenance procedures, and replacement part details\.
#
# This instruction manual describes using an Emerson handheld communicator to set up and calibrate the instrument\. You can also use Fisher ValveLink™ software or ValveLink Mobile software to setup, calibrate, and diagnose the valve and instrument\. For information on using ValveLink software with the instrument refer to ValveLink software help or documentation\.
#
# \!
#
# Do not install, operate, or maintain a DVC6200 digital valve controller without being fully trained and qualified in valve, actuator, and accessory installation, operation, and maintenance\. To avoid personal injury or property damage, it is important to carefully read, understand, and follow all of the contents of this manual, including all safety cautions and warnings\. If you have any questions about these instructions, contact your Emerson sales office before proceeding\.
#
#
# # Conventions Used in this Manual
#
# Navigation paths and fast\-key sequences are included for procedures and parameters that can be accessed using the handheld communicator\.
#
# For example, to access Device Setup:
#
# Handheld Communicator
#
# Configure \> Guided Setup \> Device Setup \(2\-1\-1\)
#
# Refer to Appendix B for handheld communicator menu trees\.
#
# Note Fast\-key sequences are only applicable to the 475 Field Communicator\. They do not apply to the Trex™ Device Communicator\.
#
#
# # Description
#
# DVC6200 digital valve controllers \(figures 1\-1 and 1\-2\) are communicating, microprocessor\-based current\-to\-pneumatic instruments\. In addition to the traditional function of converting an input current signal to a pneumatic output pressure, the DVC6200 digital valve controller, using the HART® communications protocol, gives easy access to information critical to process operation\. You can gain information from the principal component of the process, the control valve itself, using the handheld communicator at the valve, or at a field junction box, or by using a
#
# <!-- PageNumber="3" -->
#
# <!-- PageHeader="Introduction December 2022" -->
#
# Figure 1\-1\. FIELDVUE DVC6200 Digital Valve Controller Mounted on a Fisher Sliding\-Stem Valve Actuator
#
# Figure 1\-2\. FIELDVUE DVC6200 Digital Valve Controller Integrally Mounted to a Fisher GX Control Valve
#
# ISHERR
#
# X1182\-1
#
# W9616
#
# personal computer or operator's console within the control room\. Additionally, an option is available which provides isolated circuitry for a valve position transmitter \(for separate valve position feedback\) or an integrated switch that can be set as a limit switch or an alert switch\.
#
# Using a personal computer and ValveLink software or AMS Suite: Intelligent Device Manager, or a handheld communicator, you can perform several operations with the DVC6200 digital valve controller\. You can obtain general information concerning software revision level, messages, tag, descriptor, and date\.
#
# Diagnostic information is available to aid you when troubleshooting\. Input and output configuration parameters can be set, and the digital valve controller can be calibrated\. Refer to table 1\-1 for details on the capabilities of each diagnostic tier\.
#
# Using the HART protocol, information from the field can be integrated into control systems or be received on a single loop basis\.
#
# The DVC6200 digital valve controller is designed to directly replace standard pneumatic and electro\-pneumatic valve mounted positioners\.
#
# Table 1\-1\. Instrument Level Capabilities
#
# | CAPABILITY | DIAGNOSTIC LEVEL\(2\) ||||
# || HC | AD | PD | ODV |
# | - | - | - | - | - |
# | Auto Calibration | X :selected: | X :selected: | X :selected: | X :selected: |
# | Custom Characterization | X :selected: | X :selected: | X :selected: | X :selected: |
# | Burst Communication | X :selected: | X :selected: | X :selected: | X :selected: |
# | Alerts | X :selected: | X :selected: | X :selected: | X :selected: |
# | Step Response, Drive Signal Test & Dynamic Error Band | :unselected: | X :selected: | X :selected: | X :selected: |
# | Advanced Diagnostics \(Valve Signature\) | :unselected: | X :selected: | X :selected: | X :selected: |
# | Performance Tuner\(3\) | :unselected: | X :selected: | X :selected: | X :selected: |
# | Travel Control \- Pressure Fallback | :unselected: | X :selected: | X :selected: | X :selected: |
# | Supply Pressure Sensor | X\(4\) :selected: | X :selected: | X :selected: | X :selected: |
# | Performance Diagnostics | :unselected: | :unselected: | X :selected: | X :selected: |
# | Solenoid Valve Testing | :unselected: | :unselected: | X :selected: | X :selected: |
# | Lead/Lag Set Point Filter\(1\) | :unselected: | :unselected: | :unselected: | X :selected: |
#
# 1\. Refer to brochure part \# D351146X012 for information on Fisher optimized digital valves for compressor antisurge applications\.
#
# 2\. HC = HART Communicating ; AD = Advanced Diagnostics ; PD = Performance Diagnostics ; ODV = Optimized Digital Valve\.
#
# 3\. Performance Tuner is only available in ValveLink software\.
#
# 4\. Supply Pressure Sensor available starting with Firmware 7\.
#
# <!-- PageNumber="4" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" --> :unselected:
#
# <!-- PageHeader="Introduction December 2022" -->
#
# Instruction Manual D103605X012
#
#
# # Specifications
#
#
# # WARNING A
#
# Refer to table 1\-2 for specifications\. Incorrect configuration of a positioning instrument could result in the malfunction of the product, property damage or personal injury\.
#
# Specifications for DVC6200 digital valve controllers are shown in table 1\-2\. Specifications for the Device Communicator can be found in the Device Communicator quick start guide\.
#
#
# # Related Documents
#
# This section lists other documents containing information related to the DVC6200 digital valve controller\. These documents include:
#
# \. Bulletin 62\.1:DVC6200 \- Fisher FIELDVUE DVC6200 Digital Valve Controller \(D103415X012\)
#
# \. Bulletin 62\.1:DVC6200\(S1\) Fisher FIELDUVE DVC6200 Digital Valve Controller Dimensions \(D103543X012\)
#
# \. Bulletin 62\.1:Digital Valve Controller \- Fisher FIELDVUE Digital Valve Controller Product Selection \(D104363X012\)
#
# \. Fisher FIELDVUE DVC6200 Series Digital Valve Controller Quick Start Guide \(D103556X012\)
#
# \. FIELDVUE Digital Valve Controller Split Ranging \(D103262X012\)
#
# \. Using FIELDVUE Instruments with the Smart HART Loop Interface and Monitor \(HIM\) \(D103263X012\)
#
# \. Using FIELDVUE Instruments with the Smart Wireless THUM Adapter and a HART Interface Module \(HIM\) \(D103469X012\)
#
# \. Audio Monitor for HART Communications \(D103265X012\)
#
# \. HART Field Device Specification \- Supplement to Fisher FIELDVUE DVC6200 Digital Valve Controller \(D103639X012\)
#
# \. Using the HART Tri\-Loop HART\-to\-Analog Signal Converter with FIELDVUE Digital Valve Controllers \(D103267X012\)
#
# \. Implementation of Lock\-in\-Last Strategy \(D103261X012\)
#
# \. Fisher HF340 Filter Instruction Manual \(D102796X012\)
#
# · AMS Trex Device Communicator User Guide
#
# · ValveLink Software Help or Documentation
#
# All documents are available from your Emerson sale office or at Fisher\.com\.
#
# <!-- PageNumber="5" -->
#
# Introduction December 2022
#
# Instruction Manual D103605X012
#
#
# # Table 1\-2\. Specifications
#
# Available Mounting
#
# DVC6200 digital valve controller or DVC6215 feedback unit: :selected: Integral mounting to Fisher 657/667 or GX actuators :selected: Window mounting to Fisher rotary actuators :selected: Sliding\-stem linear applications \_ Quarter\-turn rotary applications
#  :selected:
# DVC6205 base unit for 2 inch pipestand or wall mounting \(for remote\-mount\)
#
# The DVC6200 digital valve controller or DVC6215 feedback unit can also be mounted on other actuators that comply with IEC 60534\-6\-1, IEC 60534\-6\-2, VDI/VDE 3845 and NAMUR mounting standards\.
#
# Communication Protocol
#  :selected:
# HART 5 or :selected: HART 7
#
# Input Signal
#
# Point\-to\-Point Analog Input Signal: 4\-20 mA DC, nominal; split ranging available Minimum Voltage Available at Instrument Terminals must be 9\.5 VDC for analog control, 10 VDC for HART communication Minimum Control Current: 4\.0 mA Minimum Current w/o Microprocessor Restart: 3\.5 mA Maximum Voltage: 30 VDC Overcurrent protected Reverse Polarity protected
#
# Multi\-drop Instrument Power: 11 to 30 VDC at 10 mA Reverse Polarity protected
#
# Supply Pressure\(1\)
#
# Minimum Recommended: 0\.3 bar \(5 psig\) higher than maximum actuator requirements Maximum: 10\.0 bar \(145 psig\) or maximum pressure rating of the actuator, whichever is lower
#
# Medium: Air or Natural Gas Supply medium must be clean, dry and noncorrosive\.
#
# Per ISA Standard 7\.0\.01 A maximum 40 micrometer particle size in the air system is acceptable\. Further filtration down to 5 micrometer particle size is recommended\. Lubricant content is not to exceed 1 ppm weight \(w/w\) or volume \(v/v\) basis\. Condensation in the air supply should be minimized\.
#
# Per ISO 8573\-1
#
# Maximum particle density size: Class 7 Oil content: Class 3 Pressure Dew Point: Class 3 or at least 10°C less than the lowest ambient temperature expected
#
# Output Signal
#
# Pneumatic signal, up to full supply pressure Minimum Span: 0\.4 bar \(6 psig\) Maximum Span: 9\.5 bar \(140 psig\)
#
# Action: Double, Single Direct or :selected: :selected: :selected: Reverse
#
# Steady\-State Air Consumption\(2\)\(3\)
#
# Standard Relay At 1\.4 bar \(20 psig\) supply pressure: Less than 0\.38 normal m3/hr \(14 scfh\) At 5\.5 bar \(80 psig\) supply pressure: Less than 1\.3 normal m3/hr \(49 scfh\)
#
# Low Bleed Relay
#
# At 1\.4 bar \(20 psig\) supply pressure: Average value 0\.056 normal m3/hr \(2\.1 scfh\) At 5\.5 bar \(80 psig\) supply pressure: Average value 0\.184 normal m3/hr \(6\.9 scfh\)
#
# Maximum Output Capacity\(2\)\(3\)
#
# At 1\.4 bar \(20 psig\) supply pressure: 10\.0 normal m3/hr \(375 scfh\) At 5\.5 bar \(80 psig\) supply pressure: 29\.5 normal m3/hr \(1100 scfh\)
#
# Operating Ambient Temperature Limits\(1\)\(4\)
#
# \-40 to 85℃ \(\-40 to 185ºF\) \-52 to 85℃ \(\-62 to 185ºF\) for instruments utilizing the Extreme Temperature option \(fluorosilicone elastomers\) \-52 to 125℃ \(\-62 to 257ºF\) for remote\-mount feedback unit
#
# Independent Linearity\(5\)
#
# Typical Value: \+0\.50% of output span
#
# Electromagnetic Compatibility
#
# Meets EN 61326\-1:2021 Immunity\-Industrial locations per Table 2 of the EN 61326\-1 standard\. Performance is shown in table 1\-3 below\.
#
# Emissions\-Class A ISM equipment rating: Group 1, Class A
#
# <!-- PageFooter="\-continued\-" -->
#
# <!-- PageNumber="6" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Introduction December 2022
#
#
# # Table 1\-2\. Specifications \(continued\)
#
# Lightning and Surge Protection\-The degree of immunity to lightning is specified as Surge immunity in table 1\-3\. For additional surge protection commercially available transient protection devices can be used\.
#
# Vibration Testing Method
#
# Tested per ANSI/ISA\-S75\.13\.01 Section 5\.3\.5\. A resonant frequency search is performed on all three axes\. The instrument is subjected to the ISA specified 1/2 hour endurance test at each major resonance\.
#
# Input Impedance
#
# An equivalent impedance of 500 ohms may be used\. This value corresponds to 10V @ 20 mA\.
#
# Humidity Testing Method Tested per IEC 61514\-2
#
# Electrical Classification Hazardous Area Approvals CSA\- Intrinsically Safe, Explosion\-proof, Division 2, Dust Ignition\-proof FM\- Intrinsically Safe, Explosion\-proof, Dust Ignition\-proof, Non\-Incendive ATEX\- Intrinsically Safe, Flameproof, Type n Dust by intrinsic safety IECEx\- Intrinsically Safe, Flameproof, Type n Dust by intrinsic safety and enclosure
#
# Electrical Housing CSA\-Type 4X, IP66 FM\-Type 4X, IP66 ATEX\-IP66 IECEx\- IP66
#
# Other Classifications/Certifications
#
# Natural Gas Certified, Single Seal Device\- CSA, FM, ATEX, and IECEx
#
# ABS\- Marine Type Approval BV\- Marine Type Approval DNV\- Marine Type Approval Lloyds Register\- Marine Type Approval CCC\- China Compulsory Certification CML\- Certification Management Limited \(Japan\) CUTR\- Customs Union Technical Regulations \(Russia, Kazakhstan and Belarus\)
#
# ESMA\- Emirates Authority for Standardization and Metrology \- ECAS\-Ex \(UAE\)
#
# INMETRO\- National Institute of Metrology, Quality, and Technology \(Brazil\)
#
# KOSHA\- Korean Occupational Safety & Health Agency \(South Korea\) KTL\- Korea Testing Laboratory \(South Korea\) NEPSI\- National Supervision and Inspection Centre for Explosion Protection and Safety of Instrumentation \(China\)
#
# PESO CCOE\- Petroleum and Explosives Safety Organisation \- Chief Controller of Explosives \(India\)
#
# SANS\- South Africa National Standards Contact your Emerson sales office for classification/certification specific information\.
#
# Connections
#
# Supply Pressure: 1/4 NPT internal and integral pad for mounting 67CFR regulator Output Pressure: 1/4 NPT internal Tubing: 3/8\-inch recommended Vent: 3/8 NPT internal Electrical: 1/2 NPT internal or M20
#
# Actuator Compatibility
#
# Sliding\-Stem Linear Linear actuators with rated travel between 6\.35 mm \(0\.25 inch\) and 606 mm \(23\.375 inches\)
#
# Quarter\-Turn Rotary Rotary actuators with rated travel between 45 degrees and 180 degrees\(6\)
#
# Weight
#
# DVC6200 Aluminum: 3\.5 kg \(7\.7 lbs\) Stainless Steel: 8\.6 kg \(19 lbs\)
#
# DVC6205: 4\.1 kg \(9 lbs\) DVC6215: 1\.4 kg \(3\.1 lbs\)
#
# Construction Materials
#
# Housing, module base and terminal box: A03600 low copper aluminum alloy \(standard\) Stainless steel \(optional\) Cover: Thermoplastic polyester Elastomers: Nitrile \(standard\) Fluorosilicone \(extreme temperature\)
#
# <!-- PageFooter="\-continued\-" -->
#
# <!-- PageNumber="7" -->
#
# Introduction December 2022
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Table 1\-2\. Specifications \(continued\)
#
#
# # Options
#
# Supply and output pressure gauges or
#  :selected:
# Tire valves \_ Integral mounted filter regulator
#  :selected: :selected:
# Low\-Bleed Relay\(7\) :unselected: Extreme Temperature
#
# Remote Mount\(8\) \_ Stainless Steel
#  :selected:
# Integral 4\-20 mA Position Transmitter\(9\):
#
# 4\-20 mA output, isolated Supply Voltage: 8\-30 VDC Reference Accuracy: 1% of travel span
#
# The position transmitter meets the requirements of NAMUR NE43; selectable to show failure high \(\> 22\.5 mA\) or failure low \(\< 3\.6 mA\)\. Fail high only when the positioner is powered\.
#
# Integral Switch\(9\):
#  :selected:
# One isolated switch, configurable throughout the calibrated travel range or actuated from a device alert Off State: 0 mA \(nominal\)
#
# On State: up to 1 A Supply Voltage: 30 VDC maximum Reference Accuracy: 2% of travel span
#
# Contact your Emerson sales office or go to Fisher\.com for additional information
#
#
# # Declaration of SEP
#
# Fisher Controls International LLC declares this product to be in compliance with Article 4 paragraph 3 of the PED Directive 2014/68/EU\. It was designed and manufactured in accordance with Sound Engineering Practice \(SEP\) and cannot bear the CE marking related to PED compliance\.
#
# However, the product may bear the CE marking to indicate compliance with other applicable European Community Directives\.
#
# NOTE: Specialized instrument terms are defined in ANSI/ISA Standard 51\.1 \- Process Instrument Terminology\.
#
# 1\. The pressure/temperature limits in this document and any other applicable code or standard should not be exceeded\.
#
# 2\. Normal m3/hour \- Normal cubic meters per hour at 0°C and 1\.01325 bar, absolute\. Scfh \- Standard cubic feet per hour at 60ºF and 14\.7 psia\.
#
# 3\. Values at 1\.4 bar \(20 psig\) based on a single\-acting direct relay; values at 5\.5 bar \(80 psig\) based on double\-acting relay\.
#
# 4\. Temperature limits vary based on hazardous area approval\. Lower temperature limit for CUTR Ex d approval with fluorosilicone elastomers is \-53℃ \(\-63\.4ºF\)\.
#
# 5\. Not applicable for travels less than 19 mm \(0\.75 inch\) or for shaft rotation less than 60 degrees\. Also not applicable for digital valve controllers in long\-stroke applications\. 6\. Rotary actuators with 180 degree rated travel require a special mounting kit; contact your Emerson sales office for kit availability
#
# 7\. The Quad O steady\-state consumption requirement of 6 scfh can be met by a DVC6200 with low bleed relay A option, when used with up to 4\.8 bar \(70 psi\) supply of Natural Gas at 16°C \(60ºF\)\. The 6 scfh requirement can be met by low bleed relay B and C when used with up to 5\.2 bar \(75 psi\) supply of Natural Gas at 16℃ \(60ºF\)\. 8\. 4\-conductor shielded cable, 18 to 22 AWG minimum wire size, in rigid or flexible metal conduit, is required for connection between base unit and feedback unit\. Pneumatic tubing between base unit output connection and actuator has been tested to 91 meters \(300 feet\)\. At 15 meters \(50 feet\) there was no performance degradation\. At 91 meters there was minimal pneumatic lag\.
#
# 9\. The electronic output is available with either the position transmitter or the integral switch\.
#
# Table 1\-3\. EMC Summary Results\-Immunity
#
# | Port | Phenomenon | Basic Standard | Test Level | Performance Criteria\(1\) |
# | - | - | - | - | - |
# | Enclosure | Electrostatic discharge \(ESD\) | IEC 61000\-4\-2 | 4 kV contact 8 kV air | A :selected: |
# || Radiated EM field | IEC 61000\-4\-3 | 80 to 1000 MHz @ 10 V/m with 1 kHz AM at 80% 1400 to 2000 MHz @ 10 V/m with 1 kHz AM at 80% 2000 to 2700 MHz @ 10 V/m with 1 kHz AM at 80% 2700 to 6000 MHz @ 10V/m with 1 kHz AM at 80%\(2\) | A |
# || Rated power frequency magnetic field | IEC 61000\-4\-8 | 30 A/m at 50/60Hz | A |
# | I/O signal/control | Burst | IEC 61000\-4\-4 | 1 kV | A |
# || Surge | IEC 61000\-4\-5 | 1 kV | B |
# || Conducted RF | IEC 61000\-4\-6 | 150 kHz to 80 MHz at 3 Vrms | A |
#
# Performance criteria DVC6200: \+/\- 1% DVC6205 Remote Mount: \+/\- 2%
#
# 1\. A = No degradation during testing\. B = Temporary degradation during testing, but is self\-recovering\. 2\. Supplementary immunity testing performed from 1\.4 GHz to 10 GHz to meet EN 61326\-1:2021 requirements\.
#
#
# # Educational Services
#
# Emerson Automation Solutions
#
# Educational Services \- Registration Phone: \+1\-800\-338\-8158 e\-mail: education@emerson\.com emerson\.com/mytraining
#
# <!-- PageNumber="8" --> :selected: :selected: :unselected: :unselected:

# %% [markdown]
# It does a great job extracting the elements of the text including paragraph text, tables, but we'll need extra logic to extract meaningful text to feed later to our LLM. You can use the OCR feature through the Azure OpenAI service. The GPT-4 Turbo with Vision model lets you chat with an AI assistant that can analyze the images you share, and the Vision Enhancement option uses Image Analysis to give the AI assistance more details (readable text and object locations) about the image. For more information, see the GPT-4 Turbo with Vision quickstart.

# %% [markdown]
# ## Understanding Data Extracted from the Layout Model

# %% [markdown]
# ### Custom Logic for Processing Extracted Information
#
# To make sense of the extracted information and prepare it for indexing into Azure AI Search, we need to implement custom logic based on specific use cases and requirements. The following is a simple example of how to transform the data into a CSV format. However, this logic should be customized to accommodate the specific use case.

# %%
# Filtering out the relevant table and cells on page 33
tables_on_page_33 = [
    table
    for table in result_ocr.tables
    if any(region.page_number == 33 for region in table.bounding_regions)
]

for table_idx, table in enumerate(tables_on_page_33):
    regions_on_page_33 = [
        region for region in table.bounding_regions if region.page_number == 33
    ]
    for region in regions_on_page_33:
        print(
            f"Table # {table_idx} on Page: {region.page_number}, Location: {region.polygon}"
        )

        # Processing cells that are on page 33
        cells_on_page_33 = [
            cell
            for cell in table.cells
            if any(region.page_number == 33 for region in cell.bounding_regions)
        ]
        for cell in cells_on_page_33:
            cell_text = f"Cell[{cell.row_index}][{cell.column_index}]: '{cell.content}'"
            cell_polygons = [
                region.polygon
                for region in cell.bounding_regions
                if region.page_number == 33
            ]
            print(f"...{cell_text} located within bounding polygons: {cell_polygons}")

print("----------------------------------------")
# Out:
# Table # 0 on Page: 33, Location: [0.9037, 1.6301, 3.9986, 1.6291, 3.9993, 2.5992, 0.9037, 2.6006]
# ...Cell[0][0]: 'Relay Type' located within bounding polygons: [[0.9067, 1.6333, 2.1533, 1.6333, 2.15, 1.8633, 0.9067, 1.8633]]
# ...Cell[0][1]: 'Pressure Signal' located within bounding polygons: [[2.1533, 1.6333, 3.7267, 1.6333, 3.7267, 1.86, 2.15, 1.8633]]
# ...Cell[1][0]: 'A or C' located within bounding polygons: [[0.9067, 1.8633, 2.15, 1.8633, 2.15, 2.0333, 0.9067, 2.0333]]
# ...Cell[1][1]: 'Port A \- Port B' located within bounding polygons: [[2.15, 1.8633, 3.7267, 1.86, 3.7267, 2.0333, 2.15, 2.0333]]
# ...Cell[2][0]: 'B' located within bounding polygons: [[0.9067, 2.0333, 2.15, 2.0333, 2.15, 2.22, 0.9067, 2.22]]
# ...Cell[2][1]: 'Port B \- Port A' located within bounding polygons: [[2.15, 2.0333, 3.7267, 2.0333, 3.7267, 2.22, 2.15, 2.22]]
# ...Cell[3][0]: 'B Special App\.' located within bounding polygons: [[0.9067, 2.22, 2.15, 2.22, 2.15, 2.4167, 0.9067, 2.4167]]
# ...Cell[3][1]: 'Port B' located within bounding polygons: [[2.15, 2.22, 3.7267, 2.22, 3.7233, 2.4133, 2.15, 2.4167]]
# ...Cell[4][0]: 'C Special App\.' located within bounding polygons: [[0.9067, 2.4167, 2.15, 2.4167, 2.15, 2.6133, 0.9067, 2.6167]]
# ...Cell[4][1]: 'Port A' located within bounding polygons: [[2.15, 2.4167, 3.7233, 2.4133, 3.7233, 2.61, 2.15, 2.6133]]
# Table # 1 on Page: 33, Location: [0.7428, 5.0533, 7.759, 5.0556, 7.757, 8.7545, 0.7393, 8.7529]
# ...Cell[0][0]: 'Actuator Style' located within bounding polygons: [[0.7514, 5.0523, 1.8022, 5.0523, 1.8022, 5.2179, 0.7514, 5.2179]]
# ...Cell[0][1]: 'Relay Type' located within bounding polygons: [[1.8022, 5.0523, 2.6515, 5.0523, 2.6515, 5.2179, 1.8022, 5.2179]]
# ...Cell[0][2]: 'Zero Power Condition' located within bounding polygons: [[2.6515, 5.0523, 4.2133, 5.0523, 4.2133, 5.2107, 2.6515, 5.2179]]
# ...Cell[0][3]: 'PST Starting Point' located within bounding polygons: [[4.2133, 5.0523, 5.2785, 5.0523, 5.2785, 5.2107, 4.2133, 5.2107]]
# ...Cell[0][4]: 'Partial Stroke Pressure Limit' located within bounding polygons: [[5.2785, 5.0523, 7.7471, 5.0523, 7.7471, 5.2107, 5.2785, 5.2107]]
# ...Cell[1][0]: 'Spring and Diaphragm' located within bounding polygons: [[0.7514, 5.2179, 1.8022, 5.2179, 1.8022, 6.4994, 0.7514, 6.4994]]
# ...Cell[1][1]: 'A or C' located within bounding polygons: [[1.8022, 5.2179, 2.6515, 5.2179, 2.6515, 5.8586, 1.8022, 5.8586]]
# ...Cell[1][2]: 'Closed' located within bounding polygons: [[2.6515, 5.2179, 4.2133, 5.2107, 4.2133, 5.5418, 2.6515, 5.5418]]
# ...Cell[1][3]: 'Open' located within bounding polygons: [[4.2133, 5.2107, 5.2785, 5.2107, 5.2785, 5.3762, 4.2133, 5.3762]]
# ...Cell[1][4]: 'Pmin \- 0\.25 \* \(Bench Set High \- Bench Set Low\)' located within bounding polygons: [[5.2785, 5.2107, 7.7471, 5.2107, 7.7471, 5.369, 5.2785, 5.3762]]
# ...Cell[2][3]: 'Closed' located within bounding polygons: [[4.2133, 5.3762, 5.2785, 5.3762, 5.2785, 5.5418, 4.2133, 5.5418]]
# ...Cell[2][4]: 'Pmax \+ 0\.25 \* \(Bench Set High \- Bench Set Low\)' located within bounding polygons: [[5.2785, 5.3762, 7.7471, 5.369, 7.7471, 5.5418, 5.2785, 5.5418]]
# ...Cell[3][2]: 'Open' located within bounding polygons: [[2.6515, 5.5418, 4.2133, 5.5418, 4.2133, 5.8586, 2.6515, 5.8586]]
# ...Cell[3][3]: 'Open' located within bounding polygons: [[4.2133, 5.5418, 5.2785, 5.5418, 5.2785, 5.693, 4.2133, 5.693]]
# ...Cell[3][4]: 'Pmax \+ 0\.25 \* \(Bench Set High \- Bench Set Low\)' located within bounding polygons: [[5.2785, 5.5418, 7.7471, 5.5418, 7.7471, 5.693, 5.2785, 5.693]]
# ...Cell[4][3]: 'Closed' located within bounding polygons: [[4.2133, 5.693, 5.2785, 5.693, 5.2785, 5.8586, 4.2133, 5.8586]]
# ...Cell[4][4]: 'Pmin \- 0\.25 \* \(Bench Set High \- Bench Set Low\)' located within bounding polygons: [[5.2785, 5.693, 7.7471, 5.693, 7.7471, 5.8586, 5.2785, 5.8586]]
# ...Cell[5][1]: 'B' located within bounding polygons: [[1.8022, 5.8586, 2.6515, 5.8586, 2.6586, 6.4994, 1.8022, 6.4994]]
# ...Cell[5][2]: 'Closed' located within bounding polygons: [[2.6515, 5.8586, 4.2133, 5.8586, 4.2133, 6.1826, 2.6515, 6.1826]]
# ...Cell[5][3]: 'Open' located within bounding polygons: [[4.2133, 5.8586, 5.2785, 5.8586, 5.2785, 6.0098, 4.2133, 6.017]]
# ...Cell[5][4]: 'Pmax \+ 0\.25 \* \(Bench Set High \- Bench Set Low\)' located within bounding polygons: [[5.2785, 5.8586, 7.7471, 5.8586, 7.7471, 6.0098, 5.2785, 6.0098]]
# ...Cell[6][3]: 'Closed' located within bounding polygons: [[4.2133, 6.017, 5.2785, 6.0098, 5.2785, 6.1754, 4.2133, 6.1826]]
# ...Cell[6][4]: 'Pmin \- 0\.25 \* \(Bench Set High \- Bench Set Low\)' located within bounding polygons: [[5.2785, 6.0098, 7.7471, 6.0098, 7.7471, 6.1754, 5.2785, 6.1754]]
# ...Cell[7][2]: 'Open' located within bounding polygons: [[2.6515, 6.1826, 4.2133, 6.1826, 4.2133, 6.4994, 2.6586, 6.4994]]
# ...Cell[7][3]: 'Open' located within bounding polygons: [[4.2133, 6.1826, 5.2785, 6.1754, 5.2785, 6.3338, 4.2133, 6.3338]]
# ...Cell[7][4]: 'Pmin \- 0\.25 \* \(Bench Set High \- Bench Set Low\)' located within bounding polygons: [[5.2785, 6.1754, 7.7471, 6.1754, 7.7471, 6.3338, 5.2785, 6.3338]]
# ...Cell[8][3]: 'Closed' located within bounding polygons: [[4.2133, 6.3338, 5.2785, 6.3338, 5.2785, 6.4994, 4.2133, 6.4994]]
# ...Cell[8][4]: 'Pmax \+ 0\.25 \* \(Bench Set High \- Bench Set Low\)' located within bounding polygons: [[5.2785, 6.3338, 7.7471, 6.3338, 7.7471, 6.4922, 5.2785, 6.4994]]
# ...Cell[10][0]: 'Single Acting Piston' located within bounding polygons: [[0.7514, 6.665, 1.8022, 6.665, 1.8022, 7.9466, 0.7514, 7.9322]]
# ...Cell[10][1]: 'A or C' located within bounding polygons: [[1.8022, 6.665, 2.6586, 6.665, 2.6586, 7.313, 1.8022, 7.313]]
# ...Cell[10][2]: 'Closed' located within bounding polygons: [[2.6586, 6.665, 4.2133, 6.665, 4.2133, 6.9818, 2.6586, 6.9818]]
# ...Cell[10][3]: 'Open' located within bounding polygons: [[4.2133, 6.665, 5.2785, 6.665, 5.2785, 6.8162, 4.2133, 6.8162]]
# ...Cell[10][4]: '0\.5 \* Pmin' located within bounding polygons: [[5.2785, 6.665, 7.7471, 6.6578, 7.7471, 6.8162, 5.2785, 6.8162]]
# ...Cell[11][3]: 'Closed' located within bounding polygons: [[4.2133, 6.8162, 5.2785, 6.8162, 5.2785, 6.9818, 4.2133, 6.9818]]
# ...Cell[11][4]: 'Pmax \+ 0\.5 \* \(Psupply \- Pmax\)' located within bounding polygons: [[5.2785, 6.8162, 7.7471, 6.8162, 7.7471, 6.9818, 5.2785, 6.9818]]
# ...Cell[12][2]: 'Open' located within bounding polygons: [[2.6586, 6.9818, 4.2133, 6.9818, 4.2133, 7.313, 2.6586, 7.313]]
# ...Cell[12][3]: 'Open' located within bounding polygons: [[4.2133, 6.9818, 5.2785, 6.9818, 5.2785, 7.1402, 4.2133, 7.1402]]
# ...Cell[12][4]: 'Pmax \+ 0\.5 \* \(Psupply \- Pmax\)' located within bounding polygons: [[5.2785, 6.9818, 7.7471, 6.9818, 7.7471, 7.1402, 5.2785, 7.1402]]
# ...Cell[13][3]: 'Closed' located within bounding polygons: [[4.2133, 7.1402, 5.2785, 7.1402, 5.2785, 7.3058, 4.2133, 7.313]]
# ...Cell[13][4]: '0\.5 \* Pmin' located within bounding polygons: [[5.2785, 7.1402, 7.7471, 7.1402, 7.7471, 7.313, 5.2785, 7.3058]]
# ...Cell[14][1]: 'B' located within bounding polygons: [[1.8022, 7.313, 2.6586, 7.313, 2.6586, 7.9466, 1.8022, 7.9466]]
# ...Cell[14][2]: 'Closed' located within bounding polygons: [[2.6586, 7.313, 4.2133, 7.313, 4.2133, 7.6226, 2.6586, 7.6226]]
# ...Cell[14][3]: 'Open' located within bounding polygons: [[4.2133, 7.313, 5.2785, 7.3058, 5.2785, 7.457, 4.2133, 7.4642]]
# ...Cell[14][4]: 'Pmax \+ 0\.5 \* \(Psupply \- Pmax\)' located within bounding polygons: [[5.2785, 7.3058, 7.7471, 7.313, 7.7471, 7.4642, 5.2785, 7.457]]
# ...Cell[15][3]: 'Closed' located within bounding polygons: [[4.2133, 7.4642, 5.2785, 7.457, 5.2785, 7.6226, 4.2133, 7.6226]]
# ...Cell[15][4]: '0\.5 \* Pmin' located within bounding polygons: [[5.2785, 7.457, 7.7471, 7.4642, 7.7471, 7.6226, 5.2785, 7.6226]]
# ...Cell[16][2]: 'Open' located within bounding polygons: [[2.6586, 7.6226, 4.2133, 7.6226, 4.2133, 7.9394, 2.6586, 7.9466]]
# ...Cell[16][3]: 'Open' located within bounding polygons: [[4.2133, 7.6226, 5.2785, 7.6226, 5.2785, 7.7738, 4.2133, 7.7738]]
# ...Cell[16][4]: '0\.5 \* Pmin' located within bounding polygons: [[5.2785, 7.6226, 7.7471, 7.6226, 7.7471, 7.7738, 5.2785, 7.7738]]
# ...Cell[17][3]: 'Closed' located within bounding polygons: [[4.2133, 7.7738, 5.2785, 7.7738, 5.2785, 7.9394, 4.2133, 7.9394]]
# ...Cell[17][4]: 'Pmax \+ 0\.5 \* \(Psupply \- Pmax\)' located within bounding polygons: [[5.2785, 7.7738, 7.7471, 7.7738, 7.7471, 7.9466, 5.2785, 7.9394]]
# ...Cell[19][0]: 'Double Acting Piston' located within bounding polygons: [[0.7514, 8.0978, 1.8022, 8.1122, 1.8022, 8.7457, 0.7514, 8.7385]]
# ...Cell[19][1]: 'A' located within bounding polygons: [[1.8022, 8.1122, 2.6586, 8.1122, 2.6586, 8.7457, 1.8022, 8.7457]]
# ...Cell[19][2]: 'Closed' located within bounding polygons: [[2.6586, 8.1122, 4.2133, 8.105, 4.2133, 8.4361, 2.6586, 8.4361]]
# ...Cell[19][3]: 'Open' located within bounding polygons: [[4.2133, 8.105, 5.2785, 8.105, 5.2785, 8.2633, 4.2133, 8.2633]]
# ...Cell[19][4]: 'Pmin \- 0\.5 \* \(Psupply \+ Pmin\)' located within bounding polygons: [[5.2785, 8.105, 7.7471, 8.1122, 7.7471, 8.2633, 5.2785, 8.2633]]
# ...Cell[20][3]: 'Closed' located within bounding polygons: [[4.2133, 8.2633, 5.2785, 8.2633, 5.2785, 8.4361, 4.2133, 8.4361]]
# ...Cell[20][4]: 'Pmax \+ 0\.5 \* \(Psupply \- Pmax\)' located within bounding polygons: [[5.2785, 8.2633, 7.7471, 8.2633, 7.7471, 8.4361, 5.2785, 8.4361]]
# ...Cell[21][2]: 'Open' located within bounding polygons: [[2.6586, 8.4361, 4.2133, 8.4361, 4.2133, 8.7385, 2.6586, 8.7457]]
# ...Cell[21][3]: 'Open' located within bounding polygons: [[4.2133, 8.4361, 5.2785, 8.4361, 5.2785, 8.5801, 4.2133, 8.5801]]
# ...Cell[21][4]: 'Pmax \+ 0\.5 \* \(Psupply \- Pmax\)' located within bounding polygons: [[5.2785, 8.4361, 7.7471, 8.4361, 7.7471, 8.5873, 5.2785, 8.5801]]
# ...Cell[22][3]: 'Closed' located within bounding polygons: [[4.2133, 8.5801, 5.2785, 8.5801, 5.2785, 8.7385, 4.2133, 8.7385]]
# ...Cell[22][4]: 'Pmin \- 0\.5 \* \(Psupply \+ Pmin\)' located within bounding polygons: [[5.2785, 8.5801, 7.7471, 8.5873, 7.7471, 8.7457, 5.2785, 8.7385]]
# ----------------------------------------

# %% [markdown]
# More sophisticated logic needs to be developed to effectively extract information from complex and nested tables. This will involve handling various table structures and layouts, as well as dealing with merged cells and other complexities. The goal is to ensure accurate and reliable extraction of data, regardless of the complexity of the table.

# %% [markdown]
# ### Leveraging LangChain Integration
#
# Retrieval-Augmented Generation (RAG) combines a pretrained Large Language Model (LLM) with an external data retrieval system. This allows for dynamic interaction with documents and content generation using Azure OpenAI models.
#
# Key Features:
#
# - **Semantic Chunking**: Fragments text into coherent segments for optimized RAG responses. Supports fixed-sized and semantic chunking.
#
# - **Layout Model Integration**: The Layout model from Document Intelligence assists in semantic chunking, providing a solution for content extraction and document structure analysis. It's scalable, multilingual, and compatible with LLMs.
#
# - **Document Chat with Semantic Chunking**: Enabled by Azure OpenAI and LangChain integration, this feature allows for custom chunking strategies and effective document parsing.
#
# For more details, visit the [Microsoft Learn page on Retrieval-Augmented Generation with Azure AI Document Intelligence](https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/concept-retrieval-augumented-generation?view=doc-intel-4.0.0).

# %%
from langchain.text_splitter import MarkdownHeaderTextSplitter

# %%
docs = document_intelligence_client.load(result_ocr)

# %%
print(result_ocr.content)
# Out:
# <!-- PageHeader="DVC6200 Digital Valve Controller December 2022" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Fisher™ FIELDVUE™ DVC6200 Digital Valve Controller
# ===
#
# This manual applies to
#
# |||
# | - | - |
# | Instrument Level | HC, AD, PD, ODV |
# | Device Type | 1309 |
# | Hardware Revision | 2 |
# | Firmware Revision | 7 |
# | Device Revision | 1 3 |
# | DD Revision | 7 1 |
#
#
# # Contents
#
# Section 1 Introduction
#
# 3
#
# Installation, Pneumatic and Electrical Connections,
#
# and Initial Configuration
#
# 3
#
# Scope of Manual
#
# 3
#
# Conventions Used in this Manual
#
# 3
#
# Description
#
# 3
#
# Specifications
#
# 5
#
# Related Documents
#
# 5
#
# HART Filter
#
# 9
#
# Voltage Available
#
# 9
#
# Compliance Voltage
#
# 11
#
# Auxiliary Terminal Wiring Length Guidelines
#
# 12
#
# Maximum Cable Capacitance
#
# 12
#
# Installation in Conjunction with a Rosemount ™
#
# 333 HART Tri\-Loop ™ HART\-to\-Analog
#
# Signal Converter
#
# 13
#
# Section 3 Configuration
#
# 15
#
# Guided Setup
#
# 15
#
# Manual Setup
#
# 15
#
# Mode and Protection
#
# 16
#
# Instrument Mode
#
# 16
#
# Write Protection
#
# 16
#
# Instrument
#
# 16
#
# Identification
#
# 16
#
# Serial Numbers
#
# 17
#
# Units
#
# 17
#
# Terminal Box
#
# 17
#
# Input Range
#
# 17
#
# Spec Sheet
#
# 18
#
# Edit Instrument Time
#
# 18
#
# FIELDVUE Instruments
#
# FISHER
#
# W9713
#
# |||
# | - | - |
# | Travel/Pressure Control | 18 |
# | Travel/Pressure Select | 18 |
# | Cutoffs and Limits | 19 |
# | Pressure Control | 19 |
# | Pressure Fallback | 20 |
# | Control Mode | 20 |
# | Characterization | 21 |
# | Dynamic Response | 23 |
# | Tuning | 24 |
# | Travel Tuning | 24 |
# | Pressure Tuning | 27 |
# | Travel/Pressure Integral Settings | 27 |
# | Valve and Actuator | 28 |
# | Partial Stroke Test | 30 |
# | Outputs | 36 |
# | Output Terminal Configuration | 36 |
# | Switch Configuration | 36 |
# | HART Variable Assignments | 37 |
# | Transmitter Output | 37 |
# | Alert Setup | 38 |
# | Change to HART 5 / HART 7 | 38 |
#
# <!-- PageFooter="www\.Fisher\.com FISHER®" -->
#
# Educational Services
#
# 8
#
# Section 2 Wiring Practices
#
# 9
#
# Control System Requirements
#
# 9
#
# EMERSON TM
#
# DVC6200 Digital Valve Controller December 2022
#
# |||
# | - | - |
# | Contents \(continued\) ||
# | Section 4 Calibration | 39 |
# | Calibration Overview | 39 |
# | Travel Calibration | 40 |
# | Auto Calibration | 40 |
# | Manual Calibration | 41 |
# | Pushbutton Calibration | 42 |
# | Sensor Calibration | 43 |
# | Pressure Sensors | 43 |
# | Analog Input Calibration | 44 |
# | Relay Adjustment | 45 |
# | Double\-Acting Relay | 45 |
# | Single\-Acting Relays | 46 |
# | PST Calibration | 47 |
# | Section 5 Device Information, Alerts, | |
# | and Diagnostics | 48 |
# | Overview | 48 |
# | Status & Primary Purpose Variables | 48 |
# | Device Information | 48 |
# | Service Tools | 49 |
# | Device Status | 49 |
# | Alert Record | 49 |
# | Alert Reporting | 49 |
# | Deadband Principle of Operation | 52 |
# | Diagnostics \. | 54 |
# | Stroke Valve | 54 |
# | Partial Stroke Test \(ODV only\) | 54 |
# | Variables | 56 |
# | Section 6 Maintenance and | |
# | Troubleshooting | 57 |
# | Replacing the Magnetic Feedback Assembly | 58 |
# | Module Base Maintenance | 58 |
# | Tools Required \. | 58 |
# | Component Replacement | 59 |
# | Removing the Module Base | 59 |
# | Replacing the Module Base | 60 |
#
# |||
# | - | - |
# | Submodule Maintenance | 61 |
# | I/P Converter \. | 61 |
# | Printed Wiring Board \(PWB\) Assembly | 63 |
# | Pneumatic Relay | 65 |
# | Gauges, Pipe Plugs or Tire Valves | 65 |
# | Terminal Box | 66 |
# | Removing the Terminal Box | 66 |
# | Replacing the Terminal Box | 67 |
# | Troubleshooting | 67 |
# | Checking Voltage Available | 67 |
# | Restart Processor | 68 |
# | DVC6200 Technical Support Checklist | 70 |
# | Section 7 Parts | 71 |
# | Parts Ordering | 71 |
# | Parts Kits | 71 |
# | PWB Assembly | 71 |
# | Parts List | 73 |
# | Housing | 73 |
# | Common Parts | 73 |
# | Module Base | 73 |
# | I/P Converter Assembly | 73 |
# | Relay \. | 73 |
# | Terminal Box | 74 |
# | Feedback Connection Terminal Box | 74 |
# | Pressure Gauges, Pipe Plugs, or Tire Valve Assemblies | 74 |
# | DVC6215 Feedback Unit | 74 |
# | HART Filters | 74 |
# | Appendix A Principle of Operation | 81 |
# | HART Communication | 81 |
# | DVC6200 Digital Valve Controller | 81 |
# | Appendix B Handheld Communicator Menu Tree | 85 |
# | Glossary | 95 |
# | Index | 101 |
#
# <!-- PageNumber="2" -->
#
# Instruction Manual D103605X012
#
# <!-- PageHeader="Introduction December 2022" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Section 1 Introduction
# ===
#
# Installation, Pneumatic and Electrical Connections, and Initial Configuration
# ===
#
# Refer to the DVC6200 Series Quick Start Guide \(D103556X012\) for DVC6200 installation, connection and initial configuration information\. If a copy of this quick start guide is needed scan or click the QR code at the right, contact your Emerson sales office or visit our website at Fisher\.com\.
#
# Scan or click to access field support
#
#
# # Scope of Manual
#
# This instruction manual is a supplement to the DVC6200 Series Quick Start Guide \(D103556X012\) that ships with every instrument\. This instruction manual includes product specifications, reference materials, custom setup information, maintenance procedures, and replacement part details\.
#
# This instruction manual describes using an Emerson handheld communicator to set up and calibrate the instrument\. You can also use Fisher ValveLink™ software or ValveLink Mobile software to setup, calibrate, and diagnose the valve and instrument\. For information on using ValveLink software with the instrument refer to ValveLink software help or documentation\.
#
# \!
#
# Do not install, operate, or maintain a DVC6200 digital valve controller without being fully trained and qualified in valve, actuator, and accessory installation, operation, and maintenance\. To avoid personal injury or property damage, it is important to carefully read, understand, and follow all of the contents of this manual, including all safety cautions and warnings\. If you have any questions about these instructions, contact your Emerson sales office before proceeding\.
#
#
# # Conventions Used in this Manual
#
# Navigation paths and fast\-key sequences are included for procedures and parameters that can be accessed using the handheld communicator\.
#
# For example, to access Device Setup:
#
# Handheld Communicator
#
# Configure \> Guided Setup \> Device Setup \(2\-1\-1\)
#
# Refer to Appendix B for handheld communicator menu trees\.
#
# Note Fast\-key sequences are only applicable to the 475 Field Communicator\. They do not apply to the Trex™ Device Communicator\.
#
#
# # Description
#
# DVC6200 digital valve controllers \(figures 1\-1 and 1\-2\) are communicating, microprocessor\-based current\-to\-pneumatic instruments\. In addition to the traditional function of converting an input current signal to a pneumatic output pressure, the DVC6200 digital valve controller, using the HART® communications protocol, gives easy access to information critical to process operation\. You can gain information from the principal component of the process, the control valve itself, using the handheld communicator at the valve, or at a field junction box, or by using a
#
# <!-- PageNumber="3" -->
#
# <!-- PageHeader="Introduction December 2022" -->
#
# Figure 1\-1\. FIELDVUE DVC6200 Digital Valve Controller Mounted on a Fisher Sliding\-Stem Valve Actuator
#
# Figure 1\-2\. FIELDVUE DVC6200 Digital Valve Controller Integrally Mounted to a Fisher GX Control Valve
#
# ISHERR
#
# X1182\-1
#
# W9616
#
# personal computer or operator's console within the control room\. Additionally, an option is available which provides isolated circuitry for a valve position transmitter \(for separate valve position feedback\) or an integrated switch that can be set as a limit switch or an alert switch\.
#
# Using a personal computer and ValveLink software or AMS Suite: Intelligent Device Manager, or a handheld communicator, you can perform several operations with the DVC6200 digital valve controller\. You can obtain general information concerning software revision level, messages, tag, descriptor, and date\.
#
# Diagnostic information is available to aid you when troubleshooting\. Input and output configuration parameters can be set, and the digital valve controller can be calibrated\. Refer to table 1\-1 for details on the capabilities of each diagnostic tier\.
#
# Using the HART protocol, information from the field can be integrated into control systems or be received on a single loop basis\.
#
# The DVC6200 digital valve controller is designed to directly replace standard pneumatic and electro\-pneumatic valve mounted positioners\.
#
# Table 1\-1\. Instrument Level Capabilities
#
# | CAPABILITY | DIAGNOSTIC LEVEL\(2\) ||||
# || HC | AD | PD | ODV |
# | - | - | - | - | - |
# | Auto Calibration | X :selected: | X :selected: | X :selected: | X :selected: |
# | Custom Characterization | X :selected: | X :selected: | X :selected: | X :selected: |
# | Burst Communication | X :selected: | X :selected: | X :selected: | X :selected: |
# | Alerts | X :selected: | X :selected: | X :selected: | X :selected: |
# | Step Response, Drive Signal Test & Dynamic Error Band | :unselected: | X :selected: | X :selected: | X :selected: |
# | Advanced Diagnostics \(Valve Signature\) | :unselected: | X :selected: | X :selected: | X :selected: |
# | Performance Tuner\(3\) | :unselected: | X :selected: | X :selected: | X :selected: |
# | Travel Control \- Pressure Fallback | :unselected: | X :selected: | X :selected: | X :selected: |
# | Supply Pressure Sensor | X\(4\) :selected: | X :selected: | X :selected: | X :selected: |
# | Performance Diagnostics | :unselected: | :unselected: | X :selected: | X :selected: |
# | Solenoid Valve Testing | :unselected: | :unselected: | X :selected: | X :selected: |
# | Lead/Lag Set Point Filter\(1\) | :unselected: | :unselected: | :unselected: | X :selected: |
#
# 1\. Refer to brochure part \# D351146X012 for information on Fisher optimized digital valves for compressor antisurge applications\.
#
# 2\. HC = HART Communicating ; AD = Advanced Diagnostics ; PD = Performance Diagnostics ; ODV = Optimized Digital Valve\.
#
# 3\. Performance Tuner is only available in ValveLink software\.
#
# 4\. Supply Pressure Sensor available starting with Firmware 7\.
#
# <!-- PageNumber="4" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" --> :unselected:
#
# <!-- PageHeader="Introduction December 2022" -->
#
# Instruction Manual D103605X012
#
#
# # Specifications
#
#
# # WARNING A
#
# Refer to table 1\-2 for specifications\. Incorrect configuration of a positioning instrument could result in the malfunction of the product, property damage or personal injury\.
#
# Specifications for DVC6200 digital valve controllers are shown in table 1\-2\. Specifications for the Device Communicator can be found in the Device Communicator quick start guide\.
#
#
# # Related Documents
#
# This section lists other documents containing information related to the DVC6200 digital valve controller\. These documents include:
#
# \. Bulletin 62\.1:DVC6200 \- Fisher FIELDVUE DVC6200 Digital Valve Controller \(D103415X012\)
#
# \. Bulletin 62\.1:DVC6200\(S1\) Fisher FIELDUVE DVC6200 Digital Valve Controller Dimensions \(D103543X012\)
#
# \. Bulletin 62\.1:Digital Valve Controller \- Fisher FIELDVUE Digital Valve Controller Product Selection \(D104363X012\)
#
# \. Fisher FIELDVUE DVC6200 Series Digital Valve Controller Quick Start Guide \(D103556X012\)
#
# \. FIELDVUE Digital Valve Controller Split Ranging \(D103262X012\)
#
# \. Using FIELDVUE Instruments with the Smart HART Loop Interface and Monitor \(HIM\) \(D103263X012\)
#
# \. Using FIELDVUE Instruments with the Smart Wireless THUM Adapter and a HART Interface Module \(HIM\) \(D103469X012\)
#
# \. Audio Monitor for HART Communications \(D103265X012\)
#
# \. HART Field Device Specification \- Supplement to Fisher FIELDVUE DVC6200 Digital Valve Controller \(D103639X012\)
#
# \. Using the HART Tri\-Loop HART\-to\-Analog Signal Converter with FIELDVUE Digital Valve Controllers \(D103267X012\)
#
# \. Implementation of Lock\-in\-Last Strategy \(D103261X012\)
#
# \. Fisher HF340 Filter Instruction Manual \(D102796X012\)
#
# · AMS Trex Device Communicator User Guide
#
# · ValveLink Software Help or Documentation
#
# All documents are available from your Emerson sale office or at Fisher\.com\.
#
# <!-- PageNumber="5" -->
#
# Introduction December 2022
#
# Instruction Manual D103605X012
#
#
# # Table 1\-2\. Specifications
#
# Available Mounting
#
# DVC6200 digital valve controller or DVC6215 feedback unit: :selected: Integral mounting to Fisher 657/667 or GX actuators :selected: Window mounting to Fisher rotary actuators :selected: Sliding\-stem linear applications \_ Quarter\-turn rotary applications
#  :selected:
# DVC6205 base unit for 2 inch pipestand or wall mounting \(for remote\-mount\)
#
# The DVC6200 digital valve controller or DVC6215 feedback unit can also be mounted on other actuators that comply with IEC 60534\-6\-1, IEC 60534\-6\-2, VDI/VDE 3845 and NAMUR mounting standards\.
#
# Communication Protocol
#  :selected:
# HART 5 or :selected: HART 7
#
# Input Signal
#
# Point\-to\-Point Analog Input Signal: 4\-20 mA DC, nominal; split ranging available Minimum Voltage Available at Instrument Terminals must be 9\.5 VDC for analog control, 10 VDC for HART communication Minimum Control Current: 4\.0 mA Minimum Current w/o Microprocessor Restart: 3\.5 mA Maximum Voltage: 30 VDC Overcurrent protected Reverse Polarity protected
#
# Multi\-drop Instrument Power: 11 to 30 VDC at 10 mA Reverse Polarity protected
#
# Supply Pressure\(1\)
#
# Minimum Recommended: 0\.3 bar \(5 psig\) higher than maximum actuator requirements Maximum: 10\.0 bar \(145 psig\) or maximum pressure rating of the actuator, whichever is lower
#
# Medium: Air or Natural Gas Supply medium must be clean, dry and noncorrosive\.
#
# Per ISA Standard 7\.0\.01 A maximum 40 micrometer particle size in the air system is acceptable\. Further filtration down to 5 micrometer particle size is recommended\. Lubricant content is not to exceed 1 ppm weight \(w/w\) or volume \(v/v\) basis\. Condensation in the air supply should be minimized\.
#
# Per ISO 8573\-1
#
# Maximum particle density size: Class 7 Oil content: Class 3 Pressure Dew Point: Class 3 or at least 10°C less than the lowest ambient temperature expected
#
# Output Signal
#
# Pneumatic signal, up to full supply pressure Minimum Span: 0\.4 bar \(6 psig\) Maximum Span: 9\.5 bar \(140 psig\)
#
# Action: Double, Single Direct or :selected: :selected: :selected: Reverse
#
# Steady\-State Air Consumption\(2\)\(3\)
#
# Standard Relay At 1\.4 bar \(20 psig\) supply pressure: Less than 0\.38 normal m3/hr \(14 scfh\) At 5\.5 bar \(80 psig\) supply pressure: Less than 1\.3 normal m3/hr \(49 scfh\)
#
# Low Bleed Relay
#
# At 1\.4 bar \(20 psig\) supply pressure: Average value 0\.056 normal m3/hr \(2\.1 scfh\) At 5\.5 bar \(80 psig\) supply pressure: Average value 0\.184 normal m3/hr \(6\.9 scfh\)
#
# Maximum Output Capacity\(2\)\(3\)
#
# At 1\.4 bar \(20 psig\) supply pressure: 10\.0 normal m3/hr \(375 scfh\) At 5\.5 bar \(80 psig\) supply pressure: 29\.5 normal m3/hr \(1100 scfh\)
#
# Operating Ambient Temperature Limits\(1\)\(4\)
#
# \-40 to 85℃ \(\-40 to 185ºF\) \-52 to 85℃ \(\-62 to 185ºF\) for instruments utilizing the Extreme Temperature option \(fluorosilicone elastomers\) \-52 to 125℃ \(\-62 to 257ºF\) for remote\-mount feedback unit
#
# Independent Linearity\(5\)
#
# Typical Value: \+0\.50% of output span
#
# Electromagnetic Compatibility
#
# Meets EN 61326\-1:2021 Immunity\-Industrial locations per Table 2 of the EN 61326\-1 standard\. Performance is shown in table 1\-3 below\.
#
# Emissions\-Class A ISM equipment rating: Group 1, Class A
#
# <!-- PageFooter="\-continued\-" -->
#
# <!-- PageNumber="6" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Introduction December 2022
#
#
# # Table 1\-2\. Specifications \(continued\)
#
# Lightning and Surge Protection\-The degree of immunity to lightning is specified as Surge immunity in table 1\-3\. For additional surge protection commercially available transient protection devices can be used\.
#
# Vibration Testing Method
#
# Tested per ANSI/ISA\-S75\.13\.01 Section 5\.3\.5\. A resonant frequency search is performed on all three axes\. The instrument is subjected to the ISA specified 1/2 hour endurance test at each major resonance\.
#
# Input Impedance
#
# An equivalent impedance of 500 ohms may be used\. This value corresponds to 10V @ 20 mA\.
#
# Humidity Testing Method Tested per IEC 61514\-2
#
# Electrical Classification Hazardous Area Approvals CSA\- Intrinsically Safe, Explosion\-proof, Division 2, Dust Ignition\-proof FM\- Intrinsically Safe, Explosion\-proof, Dust Ignition\-proof, Non\-Incendive ATEX\- Intrinsically Safe, Flameproof, Type n Dust by intrinsic safety IECEx\- Intrinsically Safe, Flameproof, Type n Dust by intrinsic safety and enclosure
#
# Electrical Housing CSA\-Type 4X, IP66 FM\-Type 4X, IP66 ATEX\-IP66 IECEx\- IP66
#
# Other Classifications/Certifications
#
# Natural Gas Certified, Single Seal Device\- CSA, FM, ATEX, and IECEx
#
# ABS\- Marine Type Approval BV\- Marine Type Approval DNV\- Marine Type Approval Lloyds Register\- Marine Type Approval CCC\- China Compulsory Certification CML\- Certification Management Limited \(Japan\) CUTR\- Customs Union Technical Regulations \(Russia, Kazakhstan and Belarus\)
#
# ESMA\- Emirates Authority for Standardization and Metrology \- ECAS\-Ex \(UAE\)
#
# INMETRO\- National Institute of Metrology, Quality, and Technology \(Brazil\)
#
# KOSHA\- Korean Occupational Safety & Health Agency \(South Korea\) KTL\- Korea Testing Laboratory \(South Korea\) NEPSI\- National Supervision and Inspection Centre for Explosion Protection and Safety of Instrumentation \(China\)
#
# PESO CCOE\- Petroleum and Explosives Safety Organisation \- Chief Controller of Explosives \(India\)
#
# SANS\- South Africa National Standards Contact your Emerson sales office for classification/certification specific information\.
#
# Connections
#
# Supply Pressure: 1/4 NPT internal and integral pad for mounting 67CFR regulator Output Pressure: 1/4 NPT internal Tubing: 3/8\-inch recommended Vent: 3/8 NPT internal Electrical: 1/2 NPT internal or M20
#
# Actuator Compatibility
#
# Sliding\-Stem Linear Linear actuators with rated travel between 6\.35 mm \(0\.25 inch\) and 606 mm \(23\.375 inches\)
#
# Quarter\-Turn Rotary Rotary actuators with rated travel between 45 degrees and 180 degrees\(6\)
#
# Weight
#
# DVC6200 Aluminum: 3\.5 kg \(7\.7 lbs\) Stainless Steel: 8\.6 kg \(19 lbs\)
#
# DVC6205: 4\.1 kg \(9 lbs\) DVC6215: 1\.4 kg \(3\.1 lbs\)
#
# Construction Materials
#
# Housing, module base and terminal box: A03600 low copper aluminum alloy \(standard\) Stainless steel \(optional\) Cover: Thermoplastic polyester Elastomers: Nitrile \(standard\) Fluorosilicone \(extreme temperature\)
#
# <!-- PageFooter="\-continued\-" -->
#
# <!-- PageNumber="7" -->
#
# Introduction December 2022
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Table 1\-2\. Specifications \(continued\)
#
#
# # Options
#
# Supply and output pressure gauges or
#  :selected:
# Tire valves \_ Integral mounted filter regulator
#  :selected: :selected:
# Low\-Bleed Relay\(7\) :unselected: Extreme Temperature
#
# Remote Mount\(8\) \_ Stainless Steel
#  :selected:
# Integral 4\-20 mA Position Transmitter\(9\):
#
# 4\-20 mA output, isolated Supply Voltage: 8\-30 VDC Reference Accuracy: 1% of travel span
#
# The position transmitter meets the requirements of NAMUR NE43; selectable to show failure high \(\> 22\.5 mA\) or failure low \(\< 3\.6 mA\)\. Fail high only when the positioner is powered\.
#
# Integral Switch\(9\):
#  :selected:
# One isolated switch, configurable throughout the calibrated travel range or actuated from a device alert Off State: 0 mA \(nominal\)
#
# On State: up to 1 A Supply Voltage: 30 VDC maximum Reference Accuracy: 2% of travel span
#
# Contact your Emerson sales office or go to Fisher\.com for additional information
#
#
# # Declaration of SEP
#
# Fisher Controls International LLC declares this product to be in compliance with Article 4 paragraph 3 of the PED Directive 2014/68/EU\. It was designed and manufactured in accordance with Sound Engineering Practice \(SEP\) and cannot bear the CE marking related to PED compliance\.
#
# However, the product may bear the CE marking to indicate compliance with other applicable European Community Directives\.
#
# NOTE: Specialized instrument terms are defined in ANSI/ISA Standard 51\.1 \- Process Instrument Terminology\.
#
# 1\. The pressure/temperature limits in this document and any other applicable code or standard should not be exceeded\.
#
# 2\. Normal m3/hour \- Normal cubic meters per hour at 0°C and 1\.01325 bar, absolute\. Scfh \- Standard cubic feet per hour at 60ºF and 14\.7 psia\.
#
# 3\. Values at 1\.4 bar \(20 psig\) based on a single\-acting direct relay; values at 5\.5 bar \(80 psig\) based on double\-acting relay\.
#
# 4\. Temperature limits vary based on hazardous area approval\. Lower temperature limit for CUTR Ex d approval with fluorosilicone elastomers is \-53℃ \(\-63\.4ºF\)\.
#
# 5\. Not applicable for travels less than 19 mm \(0\.75 inch\) or for shaft rotation less than 60 degrees\. Also not applicable for digital valve controllers in long\-stroke applications\. 6\. Rotary actuators with 180 degree rated travel require a special mounting kit; contact your Emerson sales office for kit availability
#
# 7\. The Quad O steady\-state consumption requirement of 6 scfh can be met by a DVC6200 with low bleed relay A option, when used with up to 4\.8 bar \(70 psi\) supply of Natural Gas at 16°C \(60ºF\)\. The 6 scfh requirement can be met by low bleed relay B and C when used with up to 5\.2 bar \(75 psi\) supply of Natural Gas at 16℃ \(60ºF\)\. 8\. 4\-conductor shielded cable, 18 to 22 AWG minimum wire size, in rigid or flexible metal conduit, is required for connection between base unit and feedback unit\. Pneumatic tubing between base unit output connection and actuator has been tested to 91 meters \(300 feet\)\. At 15 meters \(50 feet\) there was no performance degradation\. At 91 meters there was minimal pneumatic lag\.
#
# 9\. The electronic output is available with either the position transmitter or the integral switch\.
#
# Table 1\-3\. EMC Summary Results\-Immunity
#
# | Port | Phenomenon | Basic Standard | Test Level | Performance Criteria\(1\) |
# | - | - | - | - | - |
# | Enclosure | Electrostatic discharge \(ESD\) | IEC 61000\-4\-2 | 4 kV contact 8 kV air | A :selected: |
# || Radiated EM field | IEC 61000\-4\-3 | 80 to 1000 MHz @ 10 V/m with 1 kHz AM at 80% 1400 to 2000 MHz @ 10 V/m with 1 kHz AM at 80% 2000 to 2700 MHz @ 10 V/m with 1 kHz AM at 80% 2700 to 6000 MHz @ 10V/m with 1 kHz AM at 80%\(2\) | A |
# || Rated power frequency magnetic field | IEC 61000\-4\-8 | 30 A/m at 50/60Hz | A |
# | I/O signal/control | Burst | IEC 61000\-4\-4 | 1 kV | A |
# || Surge | IEC 61000\-4\-5 | 1 kV | B |
# || Conducted RF | IEC 61000\-4\-6 | 150 kHz to 80 MHz at 3 Vrms | A |
#
# Performance criteria DVC6200: \+/\- 1% DVC6205 Remote Mount: \+/\- 2%
#
# 1\. A = No degradation during testing\. B = Temporary degradation during testing, but is self\-recovering\. 2\. Supplementary immunity testing performed from 1\.4 GHz to 10 GHz to meet EN 61326\-1:2021 requirements\.
#
#
# # Educational Services
#
# Emerson Automation Solutions
#
# Educational Services \- Registration Phone: \+1\-800\-338\-8158 e\-mail: education@emerson\.com emerson\.com/mytraining
#
# <!-- PageNumber="8" --> :selected: :selected: :unselected: :unselected:
#
# <!-- PageHeader="Wiring Practices December 2022" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Section 2 Wiring Practices
# ===
#
#
# # Control System Requirements
#
# There are several parameters that should be checked to ensure the control system is compatible with the DVC6200 digital valve controller\.
#
#
# # HART Filter
#
# Depending on the control system you are using, a HART filter may be needed to allow HART communication\. The HART filter is a passive device that is inserted in field wiring from the HART loop\. The filter is normally installed near the field wiring terminals of the control system I/O \(see figure 2\-1\)\. Its purpose is to effectively isolate the control system output from modulated HART communication signals and raise the impedance of the control system to allow HART communication\. For more information on the description and use of the HART filter, refer to the appropriate HART filter instruction manual\.
#
# To determine if your system requires a filter contact your Emerson sales office\.
#
# Note A HART filter is typically NOT required for any of the Emerson control systems, including PROVOX ™ , RS3 ™ , and DeltaV™ systems\.
#
# Figure 2\-1\. HART Filter Application
#
# NON\-HART BASED DCS
#
# I/O
#
# I/O
#
# HART FILTER
#
# 4\-20 mA \+ HART
#
# DIGITAL VALVE CONTROLLER
#  :selected:
# Tx
#  :selected:
# Tx
#
# VALVE
#
# A6188\-1
#
#
# # Voltage Available
#
# The voltage available at the DVC6200 digital valve controller must be at least 10 VDC\. The voltage available at the instrument is not the actual voltage measured at the instrument when the instrument is connected\. The voltage measured at the instrument is limited by the instrument and is typically less than the voltage available\.
#
# <!-- PageNumber="9" --> :unselected:
#
# Wiring Practices December 2022
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# As shown in figure 2\-2, the voltage available at the instrument depends upon:
#
# \. the control system compliance voltage
#
# \. if a filter, wireless THUM adapter, or intrinsic safety barrier is used, and
#
# \. the wire type and length\.
#
# The control system compliance voltage is the maximum voltage at the control system output terminals at which the control system can produce maximum loop current\.
#
# The voltage available at the instrument may be calculated from the following equation:
#
# Voltage Available = \[Control System Compliance Voltage \(at maximum current\)\] \- \[filter voltage drop \(if a HART filter is used\)\] \- \[total cable resistance x maximum current\] \- \[barrier resistance x maximum current\]\.
#
# The calculated voltage available should be greater than or equal to 10 volts DC\.
#
# Table 2\-1 lists the resistance of some typical cables\.
#
# The following example shows how to calculate the voltage available for a Honeywell ™ TDC2000 control system with a HF340 HART filter, and 1000 feet of Belden ™ 9501 cable:
#
# Voltage available = \[18\.5 volts \(at 21\.05 mA\)\] \- \[2\.3 volts\] \- \[48 ohms x 0\.02105 amps\]
#
# Voltage available = \[18\.5\] \- \[2\.3\] \- \[1\.01\]
#
# Voltage available = 15\.19 volts
#
# Figure 2\-2\. Determining Voltage Available at the Instrument
#
# TOTAL LOOP CABLE RESISTANCE
#
# THUM ADAPTER \(IF USED\)"
#
# COMPLIANCE VOLTAGE
#
# CONTROL SYSTEM
#
# HART FILTER \(if used\)
#
# INTRINSIC SAFETY BARRIER \(if used\)
#
# R \- :unselected: VOLTAGE \+ AVAILABLE AT THE INSTRUMENT
#
# \+
#
# \-
#
# Calculate Voltage Available at the Instrument as follows:
#
# Control system compliance voltage
#
# \- Filter voltage drop \(if used\) 1
#
# \- Intrinsic safety barrier resistance \(if used\) x maximum loop current \- Smart Wireless THUM adapter voltage drop \(if used\) 2
#
# \- Total loop cable resistance x maximum loop current
#
# Example Calculation 18\.5 volts \(at 21\.05 mA\)
#
# \- 2\.3 volts \(for HF300 filter\)
#
# \- 2\.55 volts \(121 ohms x 0\.02105 amps\)
#
# \- 1\.01 volts \(48 ohms x 0\.02105 amps for 1000 feet of Belden 9501 cable\)
#
# = 15\.19 volts, available\-if safety barrier \(2\.55 volts\) is not used
#
# NOTES: 1 Obtain filter voltage drop\. The measured drop will be different than this value\. The measured filter voltage drop depends upon control system output voltage, the intrinsic safety barrier \(if used\), and the instrument\. See note 3\. :selected: 2 The voltage drop of the THUM adapter is linear from 2\.25 volts at 3\.5 mA to 1\.2 volts at 25 mA\.
#
# The voltage available at the instrument is not the voltage measured at the instrument terminals\. Once the instrument is 3 connected, the instrument limits the measured voltage to approximately 8\.0 to 9\.5 volts\.
#
# <!-- PageNumber="10" -->
#
# = Voltage available at the instrument 3 :unselected: :unselected: :unselected: :unselected: :selected: :selected:
#
# <!-- PageHeader="Wiring Practices December 2022" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Table 2\-1\. Cable Characteristics
#
# | Cable Type | Capacitance\(1\) pF/Ft | Capacitance\(1\) pF/m | Resistance\(2\) Ohms/ft | Resistance\(2\) Ohms/m |
# | - | - | - | - | - |
# | BS5308/1, 0\.5 sq mm | 61\.0 | 200 | 0\.022 | 0\.074 |
# | BS5308/1, 1\.0 sq mm | 61\.0 | 200 | 0\.012 | 0\.037 |
# | BS5308/1, 1\.5 sq mm | 61\.0 | 200 | 0\.008 | 0\.025 |
# | BS5308/2, 0\.5 sq mm | 121\.9 | 400 | 0\.022 | 0\.074 |
# | BS5308/2, 0\.75 sq mm | 121\.9 | 400 | 0\.016 | 0\.053 |
# | BS5308/2, 1\.5 sq mm | 121\.9 | 400 | 0\.008 | 0\.025 |
# | BELDEN 8303, 22 awg | 63\.0 | 206\.7 | 0\.030 | 0\.098 |
# | BELDEN 8441, 22 awg | 83\.2 | 273 | 0\.030 | 0\.098 |
# | BELDEN 8767, 22 awg | 76\.8 | 252 | 0\.030 | 0\.098 |
# | BELDEN 8777, 22 awg | 54\.9 | 180 | 0\.030 | 0\.098 |
# | BELDEN 9501, 24 awg | 50\.0 | 164 | 0\.048 | 0\.157 |
# | BELDEN 9680, 24 awg | 27\.5 | 90\.2 | 0\.048 | 0\.157 |
# | BELDEN 9729, 24 awg | 22\.1 | 72\.5 | 0\.048 | 0\.157 |
# | BELDEN 9773, 18 awg | 54\.9 | 180 | 0\.012 | 0\.042 |
# | BELDEN 9829, 24 awg | 27\.1 | 88\.9 | 0\.048 | 0\.157 |
# | BELDEN 9873, 20 awg | 54\.9 | 180 | 0\.020 | 0\.069 |
#
# 1\. The capacitance values represent capacitance from one conductor to all other conductors and shield\. This is the appropriate value to use in the cable length calculations\.
#
# 2\. The resistance values include both wires of the twisted pair\.
#
#
# # Compliance Voltage
#
# If the compliance voltage of the control system is not known, perform the following compliance voltage test\.
#
# 1\. Disconnect the field wiring from the control system and connect equipment as shown in figure 2\-3 to the control system terminals\.
#
# Figure 2\-3\. Voltage Test Schematic
#
# 1 kQ POTENTIOMETER
#
# \+ 1
#
# MILLIAMMETER
#
# VOLTMETER
#  :unselected:
# CIRCUIT UNDER TEST
#
# \+ O :unselected: :unselected: 0
#
# A6192\-1 \- \)
#
# 2\. Set the control system to provide maximum output current\.
#
# 3\. Increase the resistance of the 1 k22 potentiometer, shown in figure 2\-3, until the current observed on the milliammeter begins to drop quickly\.
#
# 4\. Record the voltage shown on the voltmeter\. This is the control system compliance voltage\.
#
# <!-- Footnote="For specific parameter information relating to your control system, contact your Emerson sales office\." -->
#
# <!-- PageNumber="11" --> :unselected: :unselected:

# %%
# Split the document into chunks base on markdown headers.
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]
text_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

docs_string = docs[0].page_content
splits = text_splitter.split_text(docs_string)
splits
# Out:
# [Document(page_content='<!-- PageHeader="DVC6200 Digital Valve Controller December 2022" -->  \n<!-- PageHeader="Instruction Manual D103605X012" -->  \nFisher™ FIELDVUE™ DVC6200 Digital Valve Controller\n===  \nThis manual applies to  \n|||\n| - | - |\n| Instrument Level | HC, AD, PD, ODV |\n| Device Type | 1309 |\n| Hardware Revision | 2 |\n| Firmware Revision | 7 |\n| Device Revision | 1 3 |\n| DD Revision | 7 1 |'),
#  Document(page_content='Section 1 Introduction  \n3  \nInstallation, Pneumatic and Electrical Connections,  \nand Initial Configuration  \n3  \nScope of Manual  \n3  \nConventions Used in this Manual  \n3  \nDescription  \n3  \nSpecifications  \n5  \nRelated Documents  \n5  \nHART Filter  \n9  \nVoltage Available  \n9  \nCompliance Voltage  \n11  \nAuxiliary Terminal Wiring Length Guidelines  \n12  \nMaximum Cable Capacitance  \n12  \nInstallation in Conjunction with a Rosemount ™  \n333 HART Tri\\-Loop ™ HART\\-to\\-Analog  \nSignal Converter  \n13  \nSection 3 Configuration  \n15  \nGuided Setup  \n15  \nManual Setup  \n15  \nMode and Protection  \n16  \nInstrument Mode  \n16  \nWrite Protection  \n16  \nInstrument  \n16  \nIdentification  \n16  \nSerial Numbers  \n17  \nUnits  \n17  \nTerminal Box  \n17  \nInput Range  \n17  \nSpec Sheet  \n18  \nEdit Instrument Time  \n18  \nFIELDVUE Instruments  \nFISHER  \nW9713  \n|||\n| - | - |\n| Travel/Pressure Control | 18 |\n| Travel/Pressure Select | 18 |\n| Cutoffs and Limits | 19 |\n| Pressure Control | 19 |\n| Pressure Fallback | 20 |\n| Control Mode | 20 |\n| Characterization | 21 |\n| Dynamic Response | 23 |\n| Tuning | 24 |\n| Travel Tuning | 24 |\n| Pressure Tuning | 27 |\n| Travel/Pressure Integral Settings | 27 |\n| Valve and Actuator | 28 |\n| Partial Stroke Test | 30 |\n| Outputs | 36 |\n| Output Terminal Configuration | 36 |\n| Switch Configuration | 36 |\n| HART Variable Assignments | 37 |\n| Transmitter Output | 37 |\n| Alert Setup | 38 |\n| Change to HART 5 / HART 7 | 38 |  \n<!-- PageFooter="www\\.Fisher\\.com FISHER®" -->  \nEducational Services  \n8  \nSection 2 Wiring Practices  \n9  \nControl System Requirements  \n9  \nEMERSON TM  \nDVC6200 Digital Valve Controller December 2022  \n|||\n| - | - |\n| Contents \\(continued\\) ||\n| Section 4 Calibration | 39 |\n| Calibration Overview | 39 |\n| Travel Calibration | 40 |\n| Auto Calibration | 40 |\n| Manual Calibration | 41 |\n| Pushbutton Calibration | 42 |\n| Sensor Calibration | 43 |\n| Pressure Sensors | 43 |\n| Analog Input Calibration | 44 |\n| Relay Adjustment | 45 |\n| Double\\-Acting Relay | 45 |\n| Single\\-Acting Relays | 46 |\n| PST Calibration | 47 |\n| Section 5 Device Information, Alerts, | |\n| and Diagnostics | 48 |\n| Overview | 48 |\n| Status & Primary Purpose Variables | 48 |\n| Device Information | 48 |\n| Service Tools | 49 |\n| Device Status | 49 |\n| Alert Record | 49 |\n| Alert Reporting | 49 |\n| Deadband Principle of Operation | 52 |\n| Diagnostics \\. | 54 |\n| Stroke Valve | 54 |\n| Partial Stroke Test \\(ODV only\\) | 54 |\n| Variables | 56 |\n| Section 6 Maintenance and | |\n| Troubleshooting | 57 |\n| Replacing the Magnetic Feedback Assembly | 58 |\n| Module Base Maintenance | 58 |\n| Tools Required \\. | 58 |\n| Component Replacement | 59 |\n| Removing the Module Base | 59 |\n| Replacing the Module Base | 60 |  \n|||\n| - | - |\n| Submodule Maintenance | 61 |\n| I/P Converter \\. | 61 |\n| Printed Wiring Board \\(PWB\\) Assembly | 63 |\n| Pneumatic Relay | 65 |\n| Gauges, Pipe Plugs or Tire Valves | 65 |\n| Terminal Box | 66 |\n| Removing the Terminal Box | 66 |\n| Replacing the Terminal Box | 67 |\n| Troubleshooting | 67 |\n| Checking Voltage Available | 67 |\n| Restart Processor | 68 |\n| DVC6200 Technical Support Checklist | 70 |\n| Section 7 Parts | 71 |\n| Parts Ordering | 71 |\n| Parts Kits | 71 |\n| PWB Assembly | 71 |\n| Parts List | 73 |\n| Housing | 73 |\n| Common Parts | 73 |\n| Module Base | 73 |\n| I/P Converter Assembly | 73 |\n| Relay \\. | 73 |\n| Terminal Box | 74 |\n| Feedback Connection Terminal Box | 74 |\n| Pressure Gauges, Pipe Plugs, or Tire Valve Assemblies | 74 |\n| DVC6215 Feedback Unit | 74 |\n| HART Filters | 74 |\n| Appendix A Principle of Operation | 81 |\n| HART Communication | 81 |\n| DVC6200 Digital Valve Controller | 81 |\n| Appendix B Handheld Communicator Menu Tree | 85 |\n| Glossary | 95 |\n| Index | 101 |  \n<!-- PageNumber="2" -->  \nInstructi ...
#  Document(page_content='This instruction manual is a supplement to the DVC6200 Series Quick Start Guide \\(D103556X012\\) that ships with every instrument\\. This instruction manual includes product specifications, reference materials, custom setup information, maintenance procedures, and replacement part details\\.  \nThis instruction manual describes using an Emerson handheld communicator to set up and calibrate the instrument\\. You can also use Fisher ValveLink™ software or ValveLink Mobile software to setup, calibrate, and diagnose the valve and instrument\\. For information on using ValveLink software with the instrument refer to ValveLink software help or documentation\\.  \n\\!  \nDo not install, operate, or maintain a DVC6200 digital valve controller without being fully trained and qualified in valve, actuator, and accessory installation, operation, and maintenance\\. To avoid personal injury or property damage, it is important to carefully read, understand, and follow all of the contents of this manual, including all safety cautions and warnings\\. If you have any questions about these instructions, contact your Emerson sales office before proceeding\\.', metadata={'Header 1': 'Scope of Manual'}),
#  Document(page_content='Navigation paths and fast\\-key sequences are included for procedures and parameters that can be accessed using the handheld communicator\\.  \nFor example, to access Device Setup:  \nHandheld Communicator  \nConfigure \\> Guided Setup \\> Device Setup \\(2\\-1\\-1\\)  \nRefer to Appendix B for handheld communicator menu trees\\.  \nNote Fast\\-key sequences are only applicable to the 475 Field Communicator\\. They do not apply to the Trex™ Device Communicator\\.', metadata={'Header 1': 'Conventions Used in this Manual'}),
#  Document(page_content='DVC6200 digital valve controllers \\(figures 1\\-1 and 1\\-2\\) are communicating, microprocessor\\-based current\\-to\\-pneumatic instruments\\. In addition to the traditional function of converting an input current signal to a pneumatic output pressure, the DVC6200 digital valve controller, using the HART® communications protocol, gives easy access to information critical to process operation\\. You can gain information from the principal component of the process, the control valve itself, using the handheld communicator at the valve, or at a field junction box, or by using a  \n<!-- PageNumber="3" -->  \n<!-- PageHeader="Introduction December 2022" -->  \nFigure 1\\-1\\. FIELDVUE DVC6200 Digital Valve Controller Mounted on a Fisher Sliding\\-Stem Valve Actuator  \nFigure 1\\-2\\. FIELDVUE DVC6200 Digital Valve Controller Integrally Mounted to a Fisher GX Control Valve  \nISHERR  \nX1182\\-1  \nW9616  \npersonal computer or operator\'s console within the control room\\. Additionally, an option is available which provides isolated circuitry for a valve position transmitter \\(for separate valve position feedback\\) or an integrated switch that can be set as a limit switch or an alert switch\\.  \nUsing a personal computer and ValveLink software or AMS Suite: Intelligent Device Manager, or a handheld communicator, you can perform several operations with the DVC6200 digital valve controller\\. You can obtain general information concerning software revision level, messages, tag, descriptor, and date\\.  \nDiagnostic information is available to aid you when troubleshooting\\. Input and output configuration parameters can be set, and the digital valve controller can be calibrated\\. Refer to table 1\\-1 for details on the capabilities of each diagnostic tier\\.  \nUsing the HART protocol, information from the field can be integrated into control systems or be received on a single loop basis\\.  \nThe DVC6200 digital valve controller is designed to directly replace standard pneumatic and electro\\-pneumatic valve mounted positioners\\.  \nTable 1\\-1\\. Instrument Level Capabilities  \n| CAPABILITY | DIAGNOSTIC LEVEL\\(2\\) ||||\n|| HC | AD | PD | ODV |\n| - | - | - | - | - |\n| Auto Calibration | X :selected: | X :selected: | X :selected: | X :selected: |\n| Custom Characterization | X :selected: | X :selected: | X :selected: | X :selected: |\n| Burst Communication | X :selected: | X :selected: | X :selected: | X :selected: |\n| Alerts | X :selected: | X :selected: | X :selected: | X :selected: |\n| Step Response, Drive Signal Test & Dynamic Error Band | :unselected: | X :selected: | X :selected: | X :selected: |\n| Advanced Diagnostics \\(Valve Signature\\) | :unselected: | X :selected: | X :selected: | X :selected: |\n| Performance Tuner\\(3\\) | :unselected: | X :selected: | X :selected: | X :selected: |\n| Travel Control \\- Pressure Fallback | :unselected: | X :selected: | X :selected: | X :selected: |\n| Supply Pressure Sensor | X\\(4\\) :selected: | X :selected: | X :selected: | X :selected: |\n| Performance Diagnostics | :unselected: | :unselected: | X :selected: | X :selected: |\n| Solenoid Valve Testing | :unselected: | :unselected: | X :selected: | X :selected: |\n| Lead/Lag Set Point Filter\\(1\\) | :unselected: | :unselected: | :unselected: | X :selected: |  \n1\\. Refer to brochure part \\# D351146X012 for information on Fisher optimized digital valves for compressor antisurge applications\\.  \n2\\. HC = HART Communicating ; AD = Advanced Diagnostics ; PD = Performance Diagnostics ; ODV = Optimized Digital Valve\\.  \n3\\. Performance Tuner is only available in ValveLink software\\.  \n4\\. Supply Pressure Sensor available starting with Firmware 7\\.  \n<!-- PageNumber="4" -->  \n<!-- PageHeader="Instruction Manual D103605X012" --> :unselected:  \n<!-- PageHeader="Introduction December 2022" -->  \nInstruction Manual D103605X012', metadata={'Header 1': 'Description'}),
#  Document(page_content='Refer to table 1\\-2 for specifications\\. Incorrect configuration of a positioning instrument could result in the malfunction of the product, property damage or personal injury\\.  \nSpecifications for DVC6200 digital valve controllers are shown in table 1\\-2\\. Specifications for the Device Communicator can be found in the Device Communicator quick start guide\\.', metadata={'Header 1': 'WARNING A'}),
#  Document(page_content='This section lists other documents containing information related to the DVC6200 digital valve controller\\. These documents include:  \n\\. Bulletin 62\\.1:DVC6200 \\- Fisher FIELDVUE DVC6200 Digital Valve Controller \\(D103415X012\\)  \n\\. Bulletin 62\\.1:DVC6200\\(S1\\) Fisher FIELDUVE DVC6200 Digital Valve Controller Dimensions \\(D103543X012\\)  \n\\. Bulletin 62\\.1:Digital Valve Controller \\- Fisher FIELDVUE Digital Valve Controller Product Selection \\(D104363X012\\)  \n\\. Fisher FIELDVUE DVC6200 Series Digital Valve Controller Quick Start Guide \\(D103556X012\\)  \n\\. FIELDVUE Digital Valve Controller Split Ranging \\(D103262X012\\)  \n\\. Using FIELDVUE Instruments with the Smart HART Loop Interface and Monitor \\(HIM\\) \\(D103263X012\\)  \n\\. Using FIELDVUE Instruments with the Smart Wireless THUM Adapter and a HART Interface Module \\(HIM\\) \\(D103469X012\\)  \n\\. Audio Monitor for HART Communications \\(D103265X012\\)  \n\\. HART Field Device Specification \\- Supplement to Fisher FIELDVUE DVC6200 Digital Valve Controller \\(D103639X012\\)  \n\\. Using the HART Tri\\-Loop HART\\-to\\-Analog Signal Converter with FIELDVUE Digital Valve Controllers \\(D103267X012\\)  \n\\. Implementation of Lock\\-in\\-Last Strategy \\(D103261X012\\)  \n\\. Fisher HF340 Filter Instruction Manual \\(D102796X012\\)  \n· AMS Trex Device Communicator User Guide  \n· ValveLink Software Help or Documentation  \nAll documents are available from your Emerson sale office or at Fisher\\.com\\.  \n<!-- PageNumber="5" -->  \nIntroduction December 2022  \nInstruction Manual D103605X012', metadata={'Header 1': 'Related Documents'}),
#  Document(page_content='Available Mounting  \nDVC6200 digital valve controller or DVC6215 feedback unit: :selected: Integral mounting to Fisher 657/667 or GX actuators :selected: Window mounting to Fisher rotary actuators :selected: Sliding\\-stem linear applications \\_ Quarter\\-turn rotary applications\n:selected:\nDVC6205 base unit for 2 inch pipestand or wall mounting \\(for remote\\-mount\\)  \nThe DVC6200 digital valve controller or DVC6215 feedback unit can also be mounted on other actuators that comply with IEC 60534\\-6\\-1, IEC 60534\\-6\\-2, VDI/VDE 3845 and NAMUR mounting standards\\.  \nCommunication Protocol\n:selected:\nHART 5 or :selected: HART 7  \nInput Signal  \nPoint\\-to\\-Point Analog Input Signal: 4\\-20 mA DC, nominal; split ranging available Minimum Voltage Available at Instrument Terminals must be 9\\.5 VDC for analog control, 10 VDC for HART communication Minimum Control Current: 4\\.0 mA Minimum Current w/o Microprocessor Restart: 3\\.5 mA Maximum Voltage: 30 VDC Overcurrent protected Reverse Polarity protected  \nMulti\\-drop Instrument Power: 11 to 30 VDC at 10 mA Reverse Polarity protected  \nSupply Pressure\\(1\\)  \nMinimum Recommended: 0\\.3 bar \\(5 psig\\) higher than maximum actuator requirements Maximum: 10\\.0 bar \\(145 psig\\) or maximum pressure rating of the actuator, whichever is lower  \nMedium: Air or Natural Gas Supply medium must be clean, dry and noncorrosive\\.  \nPer ISA Standard 7\\.0\\.01 A maximum 40 micrometer particle size in the air system is acceptable\\. Further filtration down to 5 micrometer particle size is recommended\\. Lubricant content is not to exceed 1 ppm weight \\(w/w\\) or volume \\(v/v\\) basis\\. Condensation in the air supply should be minimized\\.  \nPer ISO 8573\\-1  \nMaximum particle density size: Class 7 Oil content: Class 3 Pressure Dew Point: Class 3 or at least 10°C less than the lowest ambient temperature expected  \nOutput Signal  \nPneumatic signal, up to full supply pressure Minimum Span: 0\\.4 bar \\(6 psig\\) Maximum Span: 9\\.5 bar \\(140 psig\\)  \nAction: Double, Single Direct or :selected: :selected: :selected: Reverse  \nSteady\\-State Air Consumption\\(2\\)\\(3\\)  \nStandard Relay At 1\\.4 bar \\(20 psig\\) supply pressure: Less than 0\\.38 normal m3/hr \\(14 scfh\\) At 5\\.5 bar \\(80 psig\\) supply pressure: Less than 1\\.3 normal m3/hr \\(49 scfh\\)  \nLow Bleed Relay  \nAt 1\\.4 bar \\(20 psig\\) supply pressure: Average value 0\\.056 normal m3/hr \\(2\\.1 scfh\\) At 5\\.5 bar \\(80 psig\\) supply pressure: Average value 0\\.184 normal m3/hr \\(6\\.9 scfh\\)  \nMaximum Output Capacity\\(2\\)\\(3\\)  \nAt 1\\.4 bar \\(20 psig\\) supply pressure: 10\\.0 normal m3/hr \\(375 scfh\\) At 5\\.5 bar \\(80 psig\\) supply pressure: 29\\.5 normal m3/hr \\(1100 scfh\\)  \nOperating Ambient Temperature Limits\\(1\\)\\(4\\)  \n\\-40 to 85℃ \\(\\-40 to 185ºF\\) \\-52 to 85℃ \\(\\-62 to 185ºF\\) for instruments utilizing the Extreme Temperature option \\(fluorosilicone elastomers\\) \\-52 to 125℃ \\(\\-62 to 257ºF\\) for remote\\-mount feedback unit  \nIndependent Linearity\\(5\\)  \nTypical Value: \\+0\\.50% of output span  \nElectromagnetic Compatibility  \nMeets EN 61326\\-1:2021 Immunity\\-Industrial locations per Table 2 of the EN 61326\\-1 standard\\. Performance is shown in table 1\\-3 below\\.  \nEmissions\\-Class A ISM equipment rating: Group 1, Class A  \n<!-- PageFooter="\\-continued\\-" -->  \n<!-- PageNumber="6" -->  \n<!-- PageHeader="Instruction Manual D103605X012" -->  \nIntroduction December 2022', metadata={'Header 1': 'Table 1\\-2\\. Specifications'}),
#  Document(page_content='Lightning and Surge Protection\\-The degree of immunity to lightning is specified as Surge immunity in table 1\\-3\\. For additional surge protection commercially available transient protection devices can be used\\.  \nVibration Testing Method  \nTested per ANSI/ISA\\-S75\\.13\\.01 Section 5\\.3\\.5\\. A resonant frequency search is performed on all three axes\\. The instrument is subjected to the ISA specified 1/2 hour endurance test at each major resonance\\.  \nInput Impedance  \nAn equivalent impedance of 500 ohms may be used\\. This value corresponds to 10V @ 20 mA\\.  \nHumidity Testing Method Tested per IEC 61514\\-2  \nElectrical Classification Hazardous Area Approvals CSA\\- Intrinsically Safe, Explosion\\-proof, Division 2, Dust Ignition\\-proof FM\\- Intrinsically Safe, Explosion\\-proof, Dust Ignition\\-proof, Non\\-Incendive ATEX\\- Intrinsically Safe, Flameproof, Type n Dust by intrinsic safety IECEx\\- Intrinsically Safe, Flameproof, Type n Dust by intrinsic safety and enclosure  \nElectrical Housing CSA\\-Type 4X, IP66 FM\\-Type 4X, IP66 ATEX\\-IP66 IECEx\\- IP66  \nOther Classifications/Certifications  \nNatural Gas Certified, Single Seal Device\\- CSA, FM, ATEX, and IECEx  \nABS\\- Marine Type Approval BV\\- Marine Type Approval DNV\\- Marine Type Approval Lloyds Register\\- Marine Type Approval CCC\\- China Compulsory Certification CML\\- Certification Management Limited \\(Japan\\) CUTR\\- Customs Union Technical Regulations \\(Russia, Kazakhstan and Belarus\\)  \nESMA\\- Emirates Authority for Standardization and Metrology \\- ECAS\\-Ex \\(UAE\\)  \nINMETRO\\- National Institute of Metrology, Quality, and Technology \\(Brazil\\)  \nKOSHA\\- Korean Occupational Safety & Health Agency \\(South Korea\\) KTL\\- Korea Testing Laboratory \\(South Korea\\) NEPSI\\- National Supervision and Inspection Centre for Explosion Protection and Safety of Instrumentation \\(China\\)  \nPESO CCOE\\- Petroleum and Explosives Safety Organisation \\- Chief Controller of Explosives \\(India\\)  \nSANS\\- South Africa National Standards Contact your Emerson sales office for classification/certification specific information\\.  \nConnections  \nSupply Pressure: 1/4 NPT internal and integral pad for mounting 67CFR regulator Output Pressure: 1/4 NPT internal Tubing: 3/8\\-inch recommended Vent: 3/8 NPT internal Electrical: 1/2 NPT internal or M20  \nActuator Compatibility  \nSliding\\-Stem Linear Linear actuators with rated travel between 6\\.35 mm \\(0\\.25 inch\\) and 606 mm \\(23\\.375 inches\\)  \nQuarter\\-Turn Rotary Rotary actuators with rated travel between 45 degrees and 180 degrees\\(6\\)  \nWeight  \nDVC6200 Aluminum: 3\\.5 kg \\(7\\.7 lbs\\) Stainless Steel: 8\\.6 kg \\(19 lbs\\)  \nDVC6205: 4\\.1 kg \\(9 lbs\\) DVC6215: 1\\.4 kg \\(3\\.1 lbs\\)  \nConstruction Materials  \nHousing, module base and terminal box: A03600 low copper aluminum alloy \\(standard\\) Stainless steel \\(optional\\) Cover: Thermoplastic polyester Elastomers: Nitrile \\(standard\\) Fluorosilicone \\(extreme temperature\\)  \n<!-- PageFooter="\\-continued\\-" -->  \n<!-- PageNumber="7" -->  \nIntroduction December 2022  \n<!-- PageHeader="Instruction Manual D103605X012" -->  \nTable 1\\-2\\. Specifications \\(continued\\)', metadata={'Header 1': 'Table 1\\-2\\. Specifications \\(continued\\)'}),
#  Document(page_content='Supply and output pressure gauges or\n:selected:\nTire valves \\_ Integral mounted filter regulator\n:selected: :selected:\nLow\\-Bleed Relay\\(7\\) :unselected: Extreme Temperature  \nRemote Mount\\(8\\) \\_ Stainless Steel\n:selected:\nIntegral 4\\-20 mA Position Transmitter\\(9\\):  \n4\\-20 mA output, isolated Supply Voltage: 8\\-30 VDC Reference Accuracy: 1% of travel span  \nThe position transmitter meets the requirements of NAMUR NE43; selectable to show failure high \\(\\> 22\\.5 mA\\) or failure low \\(\\< 3\\.6 mA\\)\\. Fail high only when the positioner is powered\\.  \nIntegral Switch\\(9\\):\n:selected:\nOne isolated switch, configurable throughout the calibrated travel range or actuated from a device alert Off State: 0 mA \\(nominal\\)  \nOn State: up to 1 A Supply Voltage: 30 VDC maximum Reference Accuracy: 2% of travel span  \nContact your Emerson sales office or go to Fisher\\.com for additional information', metadata={'Header 1': 'Options'}),
#  Document(page_content='Fisher Controls International LLC declares this product to be in compliance with Article 4 paragraph 3 of the PED Directive 2014/68/EU\\. It was designed and manufactured in accordance with Sound Engineering Practice \\(SEP\\) and cannot bear the CE marking related to PED compliance\\.  \nHowever, the product may bear the CE marking to indicate compliance with other applicable European Community Directives\\.  \nNOTE: Specialized instrument terms are defined in ANSI/ISA Standard 51\\.1 \\- Process Instrument Terminology\\.  \n1\\. The pressure/temperature limits in this document and any other applicable code or standard should not be exceeded\\.  \n2\\. Normal m3/hour \\- Normal cubic meters per hour at 0°C and 1\\.01325 bar, absolute\\. Scfh \\- Standard cubic feet per hour at 60ºF and 14\\.7 psia\\.  \n3\\. Values at 1\\.4 bar \\(20 psig\\) based on a single\\-acting direct relay; values at 5\\.5 bar \\(80 psig\\) based on double\\-acting relay\\.  \n4\\. Temperature limits vary based on hazardous area approval\\. Lower temperature limit for CUTR Ex d approval with fluorosilicone elastomers is \\-53℃ \\(\\-63\\.4ºF\\)\\.  \n5\\. Not applicable for travels less than 19 mm \\(0\\.75 inch\\) or for shaft rotation less than 60 degrees\\. Also not applicable for digital valve controllers in long\\-stroke applications\\. 6\\. Rotary actuators with 180 degree rated travel require a special mounting kit; contact your Emerson sales office for kit availability  \n7\\. The Quad O steady\\-state consumption requirement of 6 scfh can be met by a DVC6200 with low bleed relay A option, when used with up to 4\\.8 bar \\(70 psi\\) supply of Natural Gas at 16°C \\(60ºF\\)\\. The 6 scfh requirement can be met by low bleed relay B and C when used with up to 5\\.2 bar \\(75 psi\\) supply of Natural Gas at 16℃ \\(60ºF\\)\\. 8\\. 4\\-conductor shielded cable, 18 to 22 AWG minimum wire size, in rigid or flexible metal conduit, is required for connection between base unit and feedback unit\\. Pneumatic tubing between base unit output connection and actuator has been tested to 91 meters \\(300 feet\\)\\. At 15 meters \\(50 feet\\) there was no performance degradation\\. At 91 meters there was minimal pneumatic lag\\.  \n9\\. The electronic output is available with either the position transmitter or the integral switch\\.  \nTable 1\\-3\\. EMC Summary Results\\-Immunity  \n| Port | Phenomenon | Basic Standard | Test Level | Performance Criteria\\(1\\) |\n| - | - | - | - | - |\n| Enclosure | Electrostatic discharge \\(ESD\\) | IEC 61000\\-4\\-2 | 4 kV contact 8 kV air | A :selected: |\n|| Radiated EM field | IEC 61000\\-4\\-3 | 80 to 1000 MHz @ 10 V/m with 1 kHz AM at 80% 1400 to 2000 MHz @ 10 V/m with 1 kHz AM at 80% 2000 to 2700 MHz @ 10 V/m with 1 kHz AM at 80% 2700 to 6000 MHz @ 10V/m with 1 kHz AM at 80%\\(2\\) | A |\n|| Rated power frequency magnetic field | IEC 61000\\-4\\-8 | 30 A/m at 50/60Hz | A |\n| I/O signal/control | Burst | IEC 61000\\-4\\-4 | 1 kV | A |\n|| Surge | IEC 61000\\-4\\-5 | 1 kV | B |\n|| Conducted RF | IEC 61000\\-4\\-6 | 150 kHz to 80 MHz at 3 Vrms | A |  \nPerformance criteria DVC6200: \\+/\\- 1% DVC6205 Remote Mount: \\+/\\- 2%  \n1\\. A = No degradation during testing\\. B = Temporary degradation during testing, but is self\\-recovering\\. 2\\. Supplementary immunity testing performed from 1\\.4 GHz to 10 GHz to meet EN 61326\\-1:2021 requirements\\.', metadata={'Header 1': 'Declaration of SEP'}),
#  Document(page_content='Emerson Automation Solutions  \nEducational Services \\- Registration Phone: \\+1\\-800\\-338\\-8158 e\\-mail: education@emerson\\.com emerson\\.com/mytraining  \n<!-- PageNumber="8" --> :selected: :selected: :unselected: :unselected:  \n<!-- PageHeader="Wiring Practices December 2022" -->  \n<!-- PageHeader="Instruction Manual D103605X012" -->  \nSection 2 Wiring Practices\n===', metadata={'Header 1': 'Educational Services'}),
#  Document(page_content='There are several parameters that should be checked to ensure the control system is compatible with the DVC6200 digital valve controller\\.', metadata={'Header 1': 'Control System Requirements'}),
#  Document(page_content='Depending on the control system you are using, a HART filter may be needed to allow HART communication\\. The HART filter is a passive device that is inserted in field wiring from the HART loop\\. The filter is normally installed near the field wiring terminals of the control system I/O \\(see figure 2\\-1\\)\\. Its purpose is to effectively isolate the control system output from modulated HART communication signals and raise the impedance of the control system to allow HART communication\\. For more information on the description and use of the HART filter, refer to the appropriate HART filter instruction manual\\.  \nTo determine if your system requires a filter contact your Emerson sales office\\.  \nNote A HART filter is typically NOT required for any of the Emerson control systems, including PROVOX ™ , RS3 ™ , and DeltaV™ systems\\.  \nFigure 2\\-1\\. HART Filter Application  \nNON\\-HART BASED DCS  \nI/O  \nI/O  \nHART FILTER  \n4\\-20 mA \\+ HART  \nDIGITAL VALVE CONTROLLER\n:selected:\nTx\n:selected:\nTx  \nVALVE  \nA6188\\-1', metadata={'Header 1': 'HART Filter'}),
#  Document(page_content='The voltage available at the DVC6200 digital valve controller must be at least 10 VDC\\. The voltage available at the instrument is not the actual voltage measured at the instrument when the instrument is connected\\. The voltage measured at the instrument is limited by the instrument and is typically less than the voltage available\\.  \n<!-- PageNumber="9" --> :unselected:  \nWiring Practices December 2022  \n<!-- PageHeader="Instruction Manual D103605X012" -->  \nAs shown in figure 2\\-2, the voltage available at the instrument depends upon:  \n\\. the control system compliance voltage  \n\\. if a filter, wireless THUM adapter, or intrinsic safety barrier is used, and  \n\\. the wire type and length\\.  \nThe control system compliance voltage is the maximum voltage at the control system output terminals at which the control system can produce maximum loop current\\.  \nThe voltage available at the instrument may be calculated from the following equation:  \nVoltage Available = \\[Control System Compliance Voltage \\(at maximum current\\)\\] \\- \\[filter voltage drop \\(if a HART filter is used\\)\\] \\- \\[total cable resistance x maximum current\\] \\- \\[barrier resistance x maximum current\\]\\.  \nThe calculated voltage available should be greater than or equal to 10 volts DC\\.  \nTable 2\\-1 lists the resistance of some typical cables\\.  \nThe following example shows how to calculate the voltage available for a Honeywell ™ TDC2000 control system with a HF340 HART filter, and 1000 feet of Belden ™ 9501 cable:  \nVoltage available = \\[18\\.5 volts \\(at 21\\.05 mA\\)\\] \\- \\[2\\.3 volts\\] \\- \\[48 ohms x 0\\.02105 amps\\]  \nVoltage available = \\[18\\.5\\] \\- \\[2\\.3\\] \\- \\[1\\.01\\]  \nVoltage available = 15\\.19 volts  \nFigure 2\\-2\\. Determining Voltage Available at the Instrument  \nTOTAL LOOP CABLE RESISTANCE  \nTHUM ADAPTER \\(IF USED\\)"  \nCOMPLIANCE VOLTAGE  \nCONTROL SYSTEM  \nHART FILTER \\(if used\\)  \nINTRINSIC SAFETY BARRIER \\(if used\\)  \nR \\- :unselected: VOLTAGE \\+ AVAILABLE AT THE INSTRUMENT  \n\\+  \n\\-  \nCalculate Voltage Available at the Instrument as follows:  \nControl system compliance voltage  \n\\- Filter voltage drop \\(if used\\) 1  \n\\- Intrinsic safety barrier resistance \\(if used\\) x maximum loop current \\- Smart Wireless THUM adapter voltage drop \\(if used\\) 2  \n\\- Total loop cable resistance x maximum loop current  \nExample Calculation 18\\.5 volts \\(at 21\\.05 mA\\)  \n\\- 2\\.3 volts \\(for HF300 filter\\)  \n\\- 2\\.55 volts \\(121 ohms x 0\\.02105 amps\\)  \n\\- 1\\.01 volts \\(48 ohms x 0\\.02105 amps for 1000 feet of Belden 9501 cable\\)  \n= 15\\.19 volts, available\\-if safety barrier \\(2\\.55 volts\\) is not used  \nNOTES: 1 Obtain filter voltage drop\\. The measured drop will be different than this value\\. The measured filter voltage drop depends upon control system output voltage, the intrinsic safety barrier \\(if used\\), and the instrument\\. See note 3\\. :selected: 2 The voltage drop of the THUM adapter is linear from 2\\.25 volts at 3\\.5 mA to 1\\.2 volts at 25 mA\\.  \nThe voltage available at the instrument is not the voltage measured at the instrument terminals\\. Once the instrument is 3 connected, the instrument limits the measured voltage to approximately 8\\.0 to 9\\.5 volts\\.  \n<!-- PageNumber="10" -->  \n= Voltage available at the instrument 3 :unselected: :unselected: :unselected: :unselected: :selected: :selected:  \n<!-- PageHeader="Wiring Practices December 2022" -->  \n<!-- PageHeader="Instruction Manual D103605X012" -->  \nTable 2\\-1\\. Cable Characteristics  \n| Cable Type | Capacitance\\(1\\) pF/Ft | Capacitance\\(1\\) pF/m | Resistance\\(2\\) Ohms/ft | Resistance\\(2\\) Ohms/m |\n| - | - | - | - | - |\n| BS5308/1, 0\\.5 sq mm | 61\\.0 | 200 | 0\\.022 | 0\\.074 |\n| BS5308/1, 1\\.0 sq mm | 61\\.0 | 200 | 0\\.012 | 0\\.037 |\n| BS5308/1, 1\\.5 sq mm | 61\\.0 | 200 | 0\\.008 | 0\\.025 |\n| BS530 ...
#  Document(page_content='If the compliance voltage of the control system is not known, perform the following compliance voltage test\\.  \n1\\. Disconnect the field wiring from the control system and connect equipment as shown in figure 2\\-3 to the control system terminals\\.  \nFigure 2\\-3\\. Voltage Test Schematic  \n1 kQ POTENTIOMETER  \n\\+ 1  \nMILLIAMMETER  \nVOLTMETER\n:unselected:\nCIRCUIT UNDER TEST  \n\\+ O :unselected: :unselected: 0  \nA6192\\-1 \\- \\)  \n2\\. Set the control system to provide maximum output current\\.  \n3\\. Increase the resistance of the 1 k22 potentiometer, shown in figure 2\\-3, until the current observed on the milliammeter begins to drop quickly\\.  \n4\\. Record the voltage shown on the voltmeter\\. This is the control system compliance voltage\\.  \n<!-- Footnote="For specific parameter information relating to your control system, contact your Emerson sales office\\." -->  \n<!-- PageNumber="11" --> :unselected: :unselected:', metadata={'Header 1': 'Compliance Voltage'})]

# %%
splits
# Out:
# [Document(page_content='<!-- PageHeader="Instruction Manual D103605X012" -->  \nConfiguration December 2022'),
#  Document(page_content='TRAVEL  \nTRAVEL  \nNORMAL  \nNORMAL  \nOUTGOING RAMP RATE  \nINCOMING RAMP RATE  \nREDUCED PST TIME  \nRETURN LEAD  \n1 2  \n1 2  \nRETURN LEAD  \n3  \nTIME  \nBREAKOUT TIMEOUT  \nEARLY  \nPAUSE TIME  \nTIME TURNAROUND  \nSHORT DURATION PST DISABLED  \nSHORT DURATION PST ENABLED\n:selected:\n1 MINIMUM TRAVEL MOVEMENT :selected: 2 TRAVEL TARGET MOVEMENT  \n3 MAX\\. ALLOWABLE TRAVEL  \nOutgoing Ramp Rate is the rate at which the valve will move during the Outgoing stroke of the Partial Stroke test\\. The default value is 0\\.25%/second\\.  \nIncoming Ramp Rate is the rate at which the valve will move during the Incoming stroke of the Partial Stroke test\\. The default value is 0\\.25%/second\\.  \nReturn Lead defines the percent \\(%\\) change in setpoint to overcome the hysteresis in the valve assembly\\. The error between setpoint and actual error is added to this percent change\\. For example, if the Return Lead is set at 0\\.5% and there is a 1% error this will be set at 1\\.5%  \nBreakout Timeout is the user configured amount of time before which the valve must leave the normal end during a PST\\.  \nOutgoing Pressure Threshold defines the actuator pressure at which a partial stroke test will abort during the outgoing stroke \\(see figure 3\\-4\\)\\. This prevents the DVC6200 from exhausting \\(or building\\) excessive pressure from/to the actuator in an attempt to move a stuck valve\\. During PST Calibration, the Partial Stroke Outgoing Pressure Threshold will be set automatically as follows:  \nO :unselected: Single Acting Actuators \\- For those actuators that exhaust pressure from the partial test start point, the Outgoing Pressure Threshold will be a minimum value\\. For those actuators that build pressure from the partial test start point, the Outgoing Pressure Threshold will be a maximum value\\.  \no Double Acting Actuators \\- The Outgoing Pressure Threshold will be set to a negative value for actuators where the partial stroke start point is opposite of the Zero Power Condition \\(e\\.g\\., Partial Stroke Start Point = Open and Zero Power Condition = Closed\\) and to a positive value for actuators where the partial stroke start point is the same as the Zero Power Condition\\.\n:unselected:\n<!-- PageNumber="32" -->  \n<!-- PageHeader="Configuration December 2022" -->  \n<!-- PageHeader="Instruction Manual D103605X012" -->  \nThe pressure signal used to determine this parameter depends on relay type and is summarized below\\.  \n| Relay Type | Pressure Signal |\n| - | - |\n| A or C | Port A \\- Port B |\n| B | Port B \\- Port A |\n| B Special App\\. | Port B |\n| C Special App\\. | Port A |  \nTo manually set the partial stroke Outgoing Pressure Threshold, you must examine current partial stroke test results using ValveLink software\\. The following steps will guide you through the process:  \n1\\. Connect the DVC6200 to a system running ValveLink software\\.  \n2\\. Disable Partial Stroke Outgoing Pressure Limit by ensuring it is not selected as an evaluation criteria for PST Abnormal\\.  \n3\\. Run a partial stroke test\\.  \n4\\. Select the Press/Time radio button on the partial stroke graph \\(refer to the example in figure 3\\-6\\)\\. If the actuator pressure starts high and moves low, find the minimum actuator pressure \\(Pmin\\)\\. If the actuator pressure starts low and moves high, find the maximum actuator pressure \\(Pmax\\)\\. Double\\-acting actuators will display differential pressure\\. Use table 3\\-7 to estimate the Outgoing Pressure Threshold\\.  \n5\\. Enable the previously disabled Outgoing Pressure Limit \\- calculate the value using table 3\\-7\\.  \nTable 3\\-7\\. Estimates for Outgoing Partial Stroke Pressure Limits  \n| Actuator Style | Relay Type | Zero Power Condition | PST Starting Point | Partial Stroke Pressure Limit |\n| - | - | - | - | - |\n| Spring and Diaphragm | A or C | Closed | Open | Pmin \\- 0\\.25 \\* \\(Bench Set High \\- Bench Set Low\\) |\n|||| Clos ...

# %%
print(docs_string)
# Out:
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# Configuration December 2022
#
#
# # Figure 3\-5\. Time Series Representation of Short Duration PST
#
# TRAVEL
#
# TRAVEL
#
# NORMAL
#
# NORMAL
#
# OUTGOING RAMP RATE
#
# INCOMING RAMP RATE
#
# REDUCED PST TIME
#
# RETURN LEAD
#
# 1 2
#
# 1 2
#
# RETURN LEAD
#
# 3
#
# TIME
#
# BREAKOUT TIMEOUT
#
# EARLY
#
# PAUSE TIME
#
# TIME TURNAROUND
#
# SHORT DURATION PST DISABLED
#
# SHORT DURATION PST ENABLED
#  :selected:
# 1 MINIMUM TRAVEL MOVEMENT :selected: 2 TRAVEL TARGET MOVEMENT
#
# 3 MAX\. ALLOWABLE TRAVEL
#
# Outgoing Ramp Rate is the rate at which the valve will move during the Outgoing stroke of the Partial Stroke test\. The default value is 0\.25%/second\.
#
# Incoming Ramp Rate is the rate at which the valve will move during the Incoming stroke of the Partial Stroke test\. The default value is 0\.25%/second\.
#
# Return Lead defines the percent \(%\) change in setpoint to overcome the hysteresis in the valve assembly\. The error between setpoint and actual error is added to this percent change\. For example, if the Return Lead is set at 0\.5% and there is a 1% error this will be set at 1\.5%
#
# Breakout Timeout is the user configured amount of time before which the valve must leave the normal end during a PST\.
#
# Outgoing Pressure Threshold defines the actuator pressure at which a partial stroke test will abort during the outgoing stroke \(see figure 3\-4\)\. This prevents the DVC6200 from exhausting \(or building\) excessive pressure from/to the actuator in an attempt to move a stuck valve\. During PST Calibration, the Partial Stroke Outgoing Pressure Threshold will be set automatically as follows:
#
# O :unselected: Single Acting Actuators \- For those actuators that exhaust pressure from the partial test start point, the Outgoing Pressure Threshold will be a minimum value\. For those actuators that build pressure from the partial test start point, the Outgoing Pressure Threshold will be a maximum value\.
#
# o Double Acting Actuators \- The Outgoing Pressure Threshold will be set to a negative value for actuators where the partial stroke start point is opposite of the Zero Power Condition \(e\.g\., Partial Stroke Start Point = Open and Zero Power Condition = Closed\) and to a positive value for actuators where the partial stroke start point is the same as the Zero Power Condition\.
#  :unselected:
# <!-- PageNumber="32" -->
#
# <!-- PageHeader="Configuration December 2022" -->
#
# <!-- PageHeader="Instruction Manual D103605X012" -->
#
# The pressure signal used to determine this parameter depends on relay type and is summarized below\.
#
# | Relay Type | Pressure Signal |
# | - | - |
# | A or C | Port A \- Port B |
# | B | Port B \- Port A |
# | B Special App\. | Port B |
# | C Special App\. | Port A |
#
# To manually set the partial stroke Outgoing Pressure Threshold, you must examine current partial stroke test results using ValveLink software\. The following steps will guide you through the process:
#
# 1\. Connect the DVC6200 to a system running ValveLink software\.
#
# 2\. Disable Partial Stroke Outgoing Pressure Limit by ensuring it is not selected as an evaluation criteria for PST Abnormal\.
#
# 3\. Run a partial stroke test\.
#
# 4\. Select the Press/Time radio button on the partial stroke graph \(refer to the example in figure 3\-6\)\. If the actuator pressure starts high and moves low, find the minimum actuator pressure \(Pmin\)\. If the actuator pressure starts low and moves high, find the maximum actuator pressure \(Pmax\)\. Double\-acting actuators will display differential pressure\. Use table 3\-7 to estimate the Outgoing Pressure Threshold\.
#
# 5\. Enable the previously disabled Outgoing Pressure Limit \- calculate the value using table 3\-7\.
#
# Table 3\-7\. Estimates for Outgoing Partial Stroke Pressure Limits
#
# | Actuator Style | Relay Type | Zero Power Condition | PST Starting Point | Partial Stroke Pressure Limit |
# | - | - | - | - | - |
# | Spring and Diaphragm | A or C | Closed | Open | Pmin \- 0\.25 \* \(Bench Set High \- Bench Set Low\) |
# |||| Closed | Pmax \+ 0\.25 \* \(Bench Set High \- Bench Set Low\) |
# ||| Open | Open | Pmax \+ 0\.25 \* \(Bench Set High \- Bench Set Low\) |
# |||| Closed | Pmin \- 0\.25 \* \(Bench Set High \- Bench Set Low\) |
# || B | Closed | Open | Pmax \+ 0\.25 \* \(Bench Set High \- Bench Set Low\) |
# |||| Closed | Pmin \- 0\.25 \* \(Bench Set High \- Bench Set Low\) |
# ||| Open | Open | Pmin \- 0\.25 \* \(Bench Set High \- Bench Set Low\) |
# |||| Closed | Pmax \+ 0\.25 \* \(Bench Set High \- Bench Set Low\) |
# | |||||
# | Single Acting Piston | A or C | Closed | Open | 0\.5 \* Pmin |
# |||| Closed | Pmax \+ 0\.5 \* \(Psupply \- Pmax\) |
# ||| Open | Open | Pmax \+ 0\.5 \* \(Psupply \- Pmax\) |
# |||| Closed | 0\.5 \* Pmin |
# || B | Closed | Open | Pmax \+ 0\.5 \* \(Psupply \- Pmax\) |
# |||| Closed | 0\.5 \* Pmin |
# ||| Open | Open | 0\.5 \* Pmin |
# |||| Closed | Pmax \+ 0\.5 \* \(Psupply \- Pmax\) |
# | |||||
# | Double Acting Piston | A | Closed | Open | Pmin \- 0\.5 \* \(Psupply \+ Pmin\) |
# |||| Closed | Pmax \+ 0\.5 \* \(Psupply \- Pmax\) |
# ||| Open | Open | Pmax \+ 0\.5 \* \(Psupply \- Pmax\) |
# |||| Closed | Pmin \- 0\.5 \* \(Psupply \+ Pmin\) |
#
# <!-- PageNumber="33" -->
